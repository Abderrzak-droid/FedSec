# %% [markdown]
# # Fusion of malicious CSV files

# %%
import pandas as pd
import glob
import os

def filter_and_combine_csv_files(file_paths, output_file):
    data_frames = []
    
    for file in file_paths:
        print(f"Processing: {file}")  # Debugging
        
        # Read CSV with error handling
        try:
            df = pd.read_csv(file, encoding="utf-8", on_bad_lines="skip")
        except Exception as e:
            print(f"Error reading {file}: {e}")
            continue  # Skip this file
        
        # Ensure 'Stage' column exists
        if 'Stage' not in df.columns:
            print(f"Skipping {file}: 'Stage' column missing")
            continue
        
        # Add a new column with the filename (without the full path)
        df["source_file"] = os.path.basename(file)

        # Filter out rows where 'Stage' == "begnign"
        df['Stage'] = df['Stage'].astype(str)
        filtered_df = df[df['Stage'].str.lower() != "benign"]
        
        data_frames.append(filtered_df)
    
    if not data_frames:
        print("No valid data found!")
        return None
    
    # Merge all filtered data
    combined_df = pd.concat(data_frames, ignore_index=True)
    
    # Drop rows with missing values (optional)
    combined_df.dropna(inplace=True)
    
    # Save to CSV
    combined_df.to_csv(output_file, index=False)
    print(f"Combined CSV saved: {output_file}")

# %%
import pandas as pd
import glob
import os

def process_filtered_flux_files(base_directory, output_directory):
    # Create output directory if it doesn't exist
    os.makedirs(output_directory, exist_ok=True)
    
    # Look for all filtered_flux_non_correspondants.csv files in subdirectories
    file_pattern = os.path.join(base_directory, "**/filtered_flux_non_correspondants.csv")
    file_paths = glob.glob(file_pattern, recursive=True)
    
    total_processed = 0
    
    for file in file_paths:
        try:
            print(f"Processing: {file}")
            
            # Read the CSV file
            df = pd.read_csv(file, encoding="utf-8", on_bad_lines="skip")
            
            # Ensure 'Stage' column exists
            if 'Stage' not in df.columns:
                print(f"Skipping {file}: 'Stage' column missing")
                continue
            
            # Get the parent folder name
            parent_folder = os.path.basename(os.path.dirname(file))
            
            # Filter out benign entries (case insensitive)
            df['Stage'] = df['Stage'].astype(str)
            filtered_df = df[df['Stage'].str.lower() != "benign"]
            
            # Skip if no non-benign entries found
            if len(filtered_df) == 0:
                print(f"No non-benign entries found in {parent_folder}")
                continue
            
            # Create output filename
            output_file = os.path.join(output_directory, f"{parent_folder}_non_benign.csv")
            
            # Save to CSV
            filtered_df.to_csv(output_file, index=False)
            print(f"Saved {len(filtered_df)} non-benign entries from {parent_folder} to: {output_file}")
            total_processed += len(filtered_df)
            
        except Exception as e:
            print(f"Error processing {file}: {e}")
            continue
    
    print(f"\nProcessing complete!")
    print(f"Total non-benign entries processed: {total_processed}")
    print(f"Output files saved in: {output_directory}")

# Usage example:
base_dir = "E:\PFE2025\Hamza"  # or provide the full path to the parent directory
output_dir = "E:\PFE2025\Hamza"  # folder where results will be saved
process_filtered_flux_files(base_dir, output_dir)
# Out:
# Processing: E:\PFE2025\Hamza\enp0s3-monday-pvt.pcap_Flow\filtered_flux_non_correspondants.csv
# No non-benign entries found in enp0s3-monday-pvt.pcap_Flow
# Processing: E:\PFE2025\Hamza\enp0s3-monday.pcap_Flow\filtered_flux_non_correspondants.csv
# No non-benign entries found in enp0s3-monday.pcap_Flow
# Processing: E:\PFE2025\Hamza\enp0s3-public-thursday.pcap_Flow\filtered_flux_non_correspondants.csv
# Saved 137 non-benign entries from enp0s3-public-thursday.pcap_Flow to: E:\PFE2025\Hamza\enp0s3-public-thursday.pcap_Flow_non_benign.csv
# Processing: E:\PFE2025\Hamza\enp0s3-public-tuesday.pcap_Flow\filtered_flux_non_correspondants.csv
# Saved 11865 non-benign entries from enp0s3-public-tuesday.pcap_Flow to: E:\PFE2025\Hamza\enp0s3-public-tuesday.pcap_Flow_non_benign.csv
# Processing: E:\PFE2025\Hamza\enp0s3-public-wednesday.pcap_Flow\filtered_flux_non_correspondants.csv
# Saved 8632 non-benign entries from enp0s3-public-wednesday.pcap_Flow to: E:\PFE2025\Hamza\enp0s3-public-wednesday.pcap_Flow_non_benign.csv
# Processing: E:\PFE2025\Hamza\enp0s3-pvt-thursday.pcap_Flow\filtered_flux_non_correspondants.csv
# Saved 2314 non-benign entries from enp0s3-pvt-thursday.pcap_Flow to: E:\PFE2025\Hamza\enp0s3-pvt-thursday.pcap_Flow_non_benign.csv
# Processing: E:\PFE2025\Hamza\enp0s3-pvt-tuesday.pcap_Flow\filtered_flux_non_correspondants.csv
# No non-benign entries found in enp0s3-pvt-tuesday.pcap_Flow
# Processing: E:\PFE2025\Hamza\enp0s3-pvt-wednesday.pcap_Flow\filtered_flux_non_correspondants.csv
# Saved 4 non-benign entries from enp0s3-pvt-wednesday.pcap_Flow to: E:\PFE2025\Hamza\enp0s3-pvt-wednesday.pcap_Flow_non_benign.csv
# Processing: E:\PFE2025\Hamza\enp0s3-tcpdump-friday.pcap_Flow\filtered_flux_non_correspondants.csv
# Saved 21 non-benign entries from enp0s3-tcpdump-friday.pcap_Flow to: E:\PFE2025\Hamza\enp0s3-tcpdump-friday.pcap_Flow_non_benign.csv
# Processing: E:\PFE2025\Hamza\enp0s3-tcpdump-pvt-friday.pcap_Flow\filtered_flux_non_correspondants.csv
# Saved 6 non-benign entries from enp0s3-tcpdump-pvt-friday.pcap_Flow to: E:\PFE2025\Hamza\enp0s3-tcpdump-pvt-friday.pcap_Flow_non_benign.csv
#
# Processing complete!
# Total non-benign entries processed: 22979
# Output files saved in: E:\PFE2025\Hamza

# %%
directory = "E:\\DAPT\\csv"
file_pattern = os.path.join(directory, "*.csv")
data_files = glob.glob(file_pattern)
print(data_files)
output_file = "E:\\DAPT\\combined_output.csv"
filtered_data = filter_and_combine_csv_files(data_files,output_file)
# Out:
# ['E:\\DAPT\\csv\\enp0s3-monday-pvt.pcap_Flow.csv', 'E:\\DAPT\\csv\\enp0s3-monday.pcap_Flow.csv', 'E:\\DAPT\\csv\\enp0s3-public-thursday.pcap_Flow.csv', 'E:\\DAPT\\csv\\enp0s3-public-tuesday.pcap_Flow.csv', 'E:\\DAPT\\csv\\enp0s3-public-wednesday.pcap_Flow.csv', 'E:\\DAPT\\csv\\enp0s3-pvt-thursday.pcap_Flow.csv', 'E:\\DAPT\\csv\\enp0s3-pvt-tuesday.pcap_Flow.csv', 'E:\\DAPT\\csv\\enp0s3-pvt-wednesday.pcap_Flow.csv', 'E:\\DAPT\\csv\\enp0s3-tcpdump-friday.pcap_Flow.csv', 'E:\\DAPT\\csv\\enp0s3-tcpdump-pvt-friday.pcap_Flow.csv']
# Processing: E:\DAPT\csv\enp0s3-monday-pvt.pcap_Flow.csv
# Processing: E:\DAPT\csv\enp0s3-monday.pcap_Flow.csv
# Processing: E:\DAPT\csv\enp0s3-public-thursday.pcap_Flow.csv
# Processing: E:\DAPT\csv\enp0s3-public-tuesday.pcap_Flow.csv
# Processing: E:\DAPT\csv\enp0s3-public-wednesday.pcap_Flow.csv
# Processing: E:\DAPT\csv\enp0s3-pvt-thursday.pcap_Flow.csv
# Skipping E:\DAPT\csv\enp0s3-pvt-thursday.pcap_Flow.csv: 'Stage' column missing
# Processing: E:\DAPT\csv\enp0s3-pvt-tuesday.pcap_Flow.csv
# Processing: E:\DAPT\csv\enp0s3-pvt-wednesday.pcap_Flow.csv
# Processing: E:\DAPT\csv\enp0s3-tcpdump-friday.pcap_Flow.csv
# Processing: E:\DAPT\csv\enp0s3-tcpdump-pvt-friday.pcap_Flow.csv
# Combined CSV saved: E:\DAPT\combined_output.csv

# %%
import pandas as pd

def clean_csv(input_file, output_file):
    """
    Remove rows containing NaN values from a CSV file and save to a new file.
    
    Parameters:
    input_file (str): Path to input CSV file
    output_file (str): Path to save cleaned CSV file
    
    Returns:
    tuple: (rows_before, rows_after) - Number of rows before and after cleaning
    """
    # Read the CSV file
    df = pd.read_csv(input_file)
    
    # Store original number of rows
    rows_before = len(df)
    
    # Remove rows with NaN values
    df_cleaned = df.dropna()
    
    # Store number of rows after cleaning
    rows_after = len(df_cleaned)
    
    # Save cleaned data to new CSV file
    df_cleaned.to_csv(output_file, index=False)
    
    return rows_before, rows_after

# Example usage
if __name__ == "__main__":
    input_file = "E:\PFE2025\Dataset\Dataset_1\combined_output.csv"
    output_file = "E:\PFE2025\Dataset\Dataset_1\combined_output.csv"
    
    rows_before, rows_after = clean_csv(input_file, output_file)
    print(f"Rows before cleaning: {rows_before}")
    print(f"Rows after cleaning: {rows_after}")
    print(f"Removed {rows_before - rows_after} rows containing NaN values")
# Out:
# Rows before cleaning: 39293
# Rows after cleaning: 39215
# Removed 78 rows containing NaN values

# %% [markdown]
# # Convert malicious flow to packets

# %%
import pandas as pd
import os
from scapy.all import rdpcap, wrpcap
from datetime import datetime

# Paths
csv_file = "E:\\Dataset\\Dataset_1\\combined_output.csv"
pcap_directory = "E:\\DAPT\\pcap-data\\"

# Read CSV file
df = pd.read_csv(csv_file)

# Convert timestamp to UNIX time
def convert_to_unix(timestamp_str):
    try:
        dt_object = datetime.strptime(timestamp_str, "%d/%m/%Y %I:%M:%S %p")  # Handle AM/PM format
        return dt_object.timestamp()
    except ValueError:
        print(f"Invalid timestamp format: {timestamp_str}")
        return None

# %%
import os
import pandas as pd
from scapy.all import wrpcap
from scapy.utils import PcapReader
from tqdm import tqdm
from datetime import datetime
from concurrent.futures import ThreadPoolExecutor
import numpy as np
from typing import Dict, List, Tuple
from dataclasses import dataclass
from scapy.layers.l2 import Ether
from scapy.packet import Packet

@dataclass
class FlowWindow:
    start_time: float
    end_time: float
    packets: List[Packet]

def convert_to_unix(timestamp_str: str) -> float:
    """Convert timestamp string to Unix timestamp using cached format."""
    try:
        return datetime.strptime(timestamp_str, "%d/%m/%Y %I:%M:%S %p").timestamp()
    except ValueError:
        print(f"Invalid timestamp format: {timestamp_str}")
        return np.nan

def process_pcap_file(args: Tuple[str, pd.DataFrame, str, str]) -> None:
    """Process a single PCAP file and extract flows."""
    pcap_filename, group, pcap_directory, extracted_directory = args
    pcap_path = os.path.join(pcap_directory, pcap_filename)
    
    if not os.path.exists(pcap_path):
        print(f"\nPCAP file not found: {pcap_path}")
        return

    # Pre-allocate flow windows with numpy arrays for faster comparison
    flow_windows: Dict[int, FlowWindow] = {
        idx: FlowWindow(
            start_time=row["Timestamp"],
            end_time=row["end_time"],
            packets=[]
        )
        for idx, row in group.iterrows()
    }

    try:
        with PcapReader(pcap_path) as pcap_reader:
            # Use numpy arrays for faster comparison
            flow_indices = np.array(list(flow_windows.keys()))
            start_times = np.array([fw.start_time for fw in flow_windows.values()])
            end_times = np.array([fw.end_time for fw in flow_windows.values()])

            for pkt in pcap_reader:
                pkt_time = float(pkt.time)
                # Vectorized comparison
                matches = (start_times <= pkt_time) & (pkt_time <= end_times)
                matching_indices = flow_indices[matches]
                
                # Add packet to all matching flows
                for idx in matching_indices:
                    flow_windows[idx].packets.append(pkt)

    except Exception as e:
        print(f"\nError reading packets from {pcap_path}: {e}")
        return

    # Save flows with packets
    base_name = pcap_filename.replace('.pcap', '')
    for idx, flow_window in flow_windows.items():
        if flow_window.packets:
            output_pcap = os.path.join(extracted_directory, f"{base_name}_{idx}.pcap")
            os.makedirs(os.path.dirname(output_pcap), exist_ok=True)
            wrpcap(output_pcap, flow_window.packets)
            print(f"\nSaved {len(flow_window.packets)} packets to {output_pcap}")

def main():
    # Paths
    csv_file = "E:\\Dataset\\Dataset_1\\combined_output.csv"
    pcap_directory = "E:\\DAPT\\pcap-data\\"
    extracted_directory = "E:\\Dataset\\Dataset_1\\extracted\\"

    # Read CSV file with optimized dtypes
    df = pd.read_csv(
        csv_file,
        dtype={
            'source_file': 'category',
            'Flow Duration': 'float64',
            'Timestamp': 'str'
        }
    )

    # Optimize timestamp conversion
    df["Timestamp"] = df["Timestamp"].apply(convert_to_unix)
    df["Flow Duration"] = df["Flow Duration"] / 1e6
    df = df.dropna(subset=["Timestamp", "Flow Duration"])

    # Optimize filename processing
    df["pcap_filename"] = df["source_file"].str.replace("_Flow.csv", "")
    df["end_time"] = df["Timestamp"] + df["Flow Duration"]

    # Group flows
    grouped = df.groupby("pcap_filename")

    # Process PCAP files in parallel
    with ThreadPoolExecutor(max_workers=os.cpu_count()) as executor:
        args = [(pcap_filename, group, pcap_directory, extracted_directory) 
                for pcap_filename, group in grouped]
        list(tqdm(
            executor.map(process_pcap_file, args),
            total=len(args),
            desc="Processing PCAP files"
        ))

if __name__ == "__main__":
    main()
# Out:
# Processing PCAP files:   0%|          | 0/7 [00:00<?, ?it/s]
# Saved 366 packets to E:\Dataset\Dataset_1\extracted\enp0s3-tcpdump-pvt-friday_22974.pcap
#
# Saved 1 packets to E:\Dataset\Dataset_1\extracted\enp0s3-tcpdump-friday_22967.pcap
#
# Saved 296 packets to E:\Dataset\Dataset_1\extracted\enp0s3-public-thursday_88.pcap
#
# Saved 341 packets to E:\Dataset\Dataset_1\extracted\enp0s3-public-thursday_89.pcap
#
# Saved 418 packets to E:\Dataset\Dataset_1\extracted\enp0s3-public-thursday_91.pcap
#
# Saved 375 packets to E:\Dataset\Dataset_1\extracted\enp0s3-public-thursday_93.pcap
#
# Saved 31 packets to E:\Dataset\Dataset_1\extracted\enp0s3-public-thursday_96.pcap
#
# Saved 14 packets to E:\Dataset\Dataset_1\extracted\enp0s3-public-thursday_97.pcap
#
# Saved 14 packets to E:\Dataset\Dataset_1\extracted\enp0s3-public-thursday_98.pcap
#
# Saved 14 packets to E:\Dataset\Dataset_1\extracted\enp0s3-public-thursday_99.pcap
#
# Saved 9 packets to E:\Dataset\Dataset_1\extracted\enp0s3-public-thursday_100.pcap
#
# Saved 21 packets to E:\Dataset\Dataset_1\extracted\enp0s3-public-thursday_101.pcap
#
# Saved 10 packets to E:\Dataset\Dataset_1\extracted\enp0s3-public-thursday_103.pcap
#
# Saved 158 packets to E:\Dataset\Dataset_1\extracted\enp0s3-public-thursday_105.pcap
#
# Saved 26 packets to E:\Dataset\Dataset_1\extracted\enp0s3-public-thursday_106.pcap
#
# Saved 32 packets to E:\Dataset\Dataset_1\extracted\enp0s3-public-thursday_107.pcap
#
# Saved 13 packets to E:\Dataset\Dataset_1\extracted\enp0s3-public-thursday_108.pcap
#
# Saved 13 packets to E:\Dataset\Dataset_1\extracted\enp0s3-public-thursday_109.pcap
#
# Saved 13 packets to E:\Dataset\Dataset_1\extracted\enp0s3-public-thursday_110.pcap
#
# Saved 9 packets to E:\Dataset\Dataset_1\extracted\enp0s3-public-thursday_111.pcap
#
# Saved 263 packets to E:\Dataset\Dataset_1\extracted\enp0s3-public-thursday_112.pcap
#
# Saved 15 packets to E:\Dataset\Dataset_1\extracted\enp0s3-public-thursday_113.pcap
#
# Saved 17 packets to E:\Dataset\Dataset_1\extracted\enp0s3-public-thursday_114.pcap
#
# Saved 27 packets to E:\Dataset\Dataset_1\extracted\enp0s3-public-thursday_115.pcap
#
# Saved 157 packets to E:\Dataset\Dataset_1\extracted\enp0s3-public-thursday_116.pcap
#
# Saved 388 packets to E:\Dataset\Dataset_1\extracted\enp0s3-public-thursday_117.pcap
#
# Saved 292 packets to E:\Dataset\Dataset_1\extracted\enp0s3-public-thursday_118.pcap
#
# Saved 29 packets to E:\Dataset\Dataset_1\extracted\enp0s3-public-thursday_119.pcap
# Processing PCAP files:  14%|█▍        | 1/7 [03:46<22:38, 226.46s/it]
# Saved 20 packets to E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9402.pcap
#
# Saved 4 packets to E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9403.pcap
#
# Saved 46 packets to E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9404.pcap
#
# Saved 2 packets to E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9405.pcap
#
# Saved 35 packets to E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9406.pcap
#
# Saved 20 packets to E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9407.pcap
#
# Saved 14 packets to E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9408.pcap
#
# Saved 67 packets to E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9409.pcap
#
# Saved 7 packets to E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9410.pcap
#
# Saved 45 packets to E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9411.pcap
#
# Saved 2 packets to E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9412.pcap
#
# Saved 2 packets to E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9414.pcap
#
# Saved 16 packets to E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9416.pcap
#
# Saved 23 packets to E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9417.pcap
#
# Saved 23 packets to E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9418.pcap
#
# Saved 17 packets to E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9419.pcap
#
# Saved 29 packets to E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9420.pcap
#
# Saved 29 packets to E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9421.pcap
#
# Saved 18 packets to E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9422.pcap
#
# Saved 18 packets to E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9423.pcap
#
# Saved 22 packets to E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9424.pcap
#
# Saved 15 packets to E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9426.pcap
#
# Saved 38 packets to E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9427.pcap
#
# Saved 39 packets to E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9429.pcap
#
# Saved 35 packets to E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9430.pcap
#
# Saved 52 packets to E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9431.pcap
#
# Saved 39 packets to E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9437.pcap
#
# Saved 39 packets to E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9438.pcap
#
# Saved 9 packets to E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9440.pcap
#
# Saved 66 packets to E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9442.pcap
#
# Saved 30 packets to E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9444.pcap
#
# Saved 43 packets to E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9446.pcap
#
# Saved 48 packets to E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9448.pcap
#
# Saved 18 packets to E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9449.pcap
#
# Saved 59 packets to E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9450.pcap
#
# Saved 59 packets to E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9451.pcap
#
# Saved 59 packets to E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9452.pcap
#
# Saved 59 packets to E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9453.pcap
#
# Saved 20 packets to E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9460.pcap
#
# Saved 3 packets to E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9463.pcap
#
# Saved 4 packets to E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9464.pcap
#
# Saved 3 packets to E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9465.pcap
#
# Saved 3 packets to E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9466.pcap
#
# Saved 3 packets to E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9467.pcap
#
# Saved 3 packets to E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9468.pcap
#
# Saved 3 packets to E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9469.pcap
#
# Saved 3 packets to E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9470.pcap
#
# Saved 3 packets to E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9471.pcap
#
# Saved 23 packets to E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9472.pcap
#
# Saved 23 packets to E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9473.pcap
#
# Saved 23 packets to E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9474.pcap
#
# Saved 23 packets to E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9475.pcap
#
# Saved 23 packets to E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9476.pcap
#
# Saved 23 packets to E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9477.pcap
#
# Saved 23 packets to E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9478.pcap
#
# Saved 23 packets to E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9479.pcap
#
# Saved 2 packets to E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9480.pcap
#
# Saved 2 packets to E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9481.pcap
#
# Saved 2 packets to E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9482.pcap
#
# Saved 2 packets to E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9483.pcap
#
# Saved 2 packets to E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9484.pcap
#
# Saved 2 packets to E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9485.pcap
#
# Saved 2 packets to E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9486.pcap
#
# Saved 2 packets to E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9487.pcap
#
# Saved 2 packets to E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9488.pcap
#
# Saved 2 packets to E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9489.pcap
#
# Saved 2 packets to E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9490.pcap
#
# Saved 16 packets to E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9491.pcap
#
# Saved 16 packets to E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9492.pcap
#
# Saved 23 packets to E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9493.pcap
#
# Saved 16 packets to E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9494.pcap
#
# Saved 1 packets to E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9495.pcap
#
# Saved 1 packets to E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9496.pcap
#
# Saved 1 packets to E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9497.pcap
#
# Saved 1 packets to E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9498.pcap
#
# Saved 1 packets to E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9499.pcap
#
# Saved 1 packets to E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9500.pcap
#
# Saved 1 packets to E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9501.pcap
#
# Saved 1 packets to E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9502.pcap
#
# Saved 1 packets to E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9503.pcap
#
# Saved 1 packets to E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9504.pcap
#
# Saved 1 packets to E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9505.pcap
#
# Saved 1 packets to E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9506.pcap
#
# Saved 1 packets to E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9507.pcap
#
# Saved 1 packets to E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9508.pcap
#
# Saved 1 packets to E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9509.pcap
#
# Saved 1 packets to E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9510.pcap
#
# Saved 1 packets to E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9511.pcap
#
# Saved 2 packets to E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9512.pcap
#
# Saved 1 packets to E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9513.pcap
#
# Saved 1 packets to E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9514.pcap
#
# Saved 1 packets to E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9515.pcap
#
# Saved 1 packets to E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9516.pcap
#
# Saved 2 packets to E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9517.pcap
#
# Saved 1 packets to E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9518.pcap
#
# Saved 1 packets to E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9519.pcap
#
# Saved 1 packets to E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9520.pcap
#
# Saved 1 packets to E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9521.pcap
#
# Saved 1 packets to E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9522.pcap
#
# Saved 1 packets to E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9523.pcap
#
# Saved 1 packets to E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9524.pcap
#
# Saved 1 packets to E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9525.pcap
#
# Saved 1 packets to E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9526.pcap
#
# Saved 1 packets to E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9527.pcap
#
# Saved 1 packets to E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9528.pcap
#
# Saved 1 packets to E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9529.pcap
#
# Saved 1 packets to E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9530.pcap
#
# Saved 1 packets to E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9533.pcap
#
# Saved 1 packets to E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9535.pcap
#
# Saved 1 packets to E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9536.pcap
#
# Saved 1 packets to E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9537.pcap
#
# Saved 1 packets to E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9538.pcap
#
# Saved 1 packets to E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9539.pcap
#
# Saved 1 packets to E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9540.pcap
#
# Saved 1 packets to E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9541.pcap
#
# Saved 1 packets to E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9542.pcap
#
# Saved 1 packets to E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9543.pcap
#
# Saved 1 packets to E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9544.pcap
#
# Saved 1 packets to E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9545.pcap
#
# Saved 1 packets to E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9546.pcap
#
# Saved 1 packets to E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9547.pcap
#
# Saved 1 packets to E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9548.pcap
#
# Saved 1 packets to E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9552.pcap
#
# Saved 1 packets to E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9553.pcap
#
# Saved 1 packets to E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9554.pcap
#
# Saved 1 packets to E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9555.pcap
#
# Saved 1 packets to E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9556.pcap
#
# Saved 1 packets to E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9557.pcap
#
# Saved 1 packets to E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9558.pcap
#
# Saved 1 packets to E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9559.pcap
#
# Saved 1 packets to E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9560.pcap
#
# Saved 1 packets to E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9561.pcap
#
# Saved 1 packets to E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9562.pcap
#
# Saved 1 packets to E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9563.pcap
#
# Saved 1 packets to E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9564.pcap
#
# Saved 1 packets to E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9565.pcap
#
# Saved 1 packets to E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9566.pcap
#
# Saved 1 packets to E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9567.pcap
#
# Saved 1 packets to E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9568.pcap
#
# Saved 1 packets to E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9569.pcap
#
# Saved 1 packets to E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9570.pcap
#
# Saved 1 packets to E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9571.pcap
#
# Saved 1 packets to E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9572.pcap
#
# Saved 1 packets to E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9573.pcap
#
# Saved 1 packets to E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9574.pcap
#
# Saved 1 packets to E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9575.pcap
#
# Saved 1 packets to E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9576.pcap
#
# Saved 1 packets to E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9577.pcap
#
# Saved 1 packets to E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9578.pcap
#
# Saved 1 packets to E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9579.pcap
#
# Saved 1 packets to E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9580.pcap
#
# Saved 1 packets to E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9581.pcap
#
# Saved 1 packets to E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9582.pcap
#
# Saved 1 packets to E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9583.pcap
#
# Saved 1 packets to E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9584.pcap
#
# Saved 1 packets to E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9585.pcap
#
# Saved 1 packets to E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9586.pcap
#
# Saved 1 packets to E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9587.pcap
#
# Saved 1 packets to E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9588.pcap
#
# Saved 1 packets to E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9589.pcap
#
# Saved 1 packets to E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9590.pcap
#
# Saved 1 packets to E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9591.pcap
#
# Saved 1 packets to E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9592.pcap
#
# Saved 1 packets to E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9593.pcap
#
# Saved 1 packets to E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9594.pcap
#
# Saved 1 packets to E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9595.pcap
#
# Saved 1 packets to E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9596.pcap
#
# Saved 1 packets to E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9597.pcap
#
# Saved 1 packets to E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9598.pcap
#
# Saved 1 packets to E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9599.pcap
#
# Saved 1 packets to E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9600.pcap
#
# Saved 1 packets to E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9601.pcap
#
# Saved 1 packets to E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9602.pcap
#
# Saved 1 packets to E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9603.pcap
#
# Saved 1 packets to E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9604.pcap
#
# Saved 1 packets to E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9605.pcap
#
# Saved 1 packets to E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9606.pcap
#
# Saved 1 packets to E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9607.pcap
#
# Saved 1 packets to E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9608.pcap
#
# Saved 1 packets to E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9609.pcap
#
# Saved 1 packets to E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9610.pcap
#
# Saved 1 packets to E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9611.pcap
#
# Saved 1 packets to E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9612.pcap
#
# Saved 1 packets to E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9613.pcap
#
# Saved 1 packets to E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9614.pcap
#
# Saved 1 packets to E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9615.pcap
#
# Saved 1 packets to E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9616.pcap
#
# Saved 1 packets to E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9617.pcap
#
# Saved 1 packets to E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9618.pcap
#
# Saved 1 packets to E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9619.pcap
#
# Saved 1 packets to E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9620.pcap
#
# Saved 1 packets to E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9621.pcap
#
# Saved 1 packets to E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9622.pcap
#
# Saved 1 packets to E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9623.pcap
#
# Saved 1 packets to E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9624.pcap
#
# Saved 1 packets to E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9625.pcap
#
# Saved 1 packets to E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9626.pcap
#
# Saved 1 packets to E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9627.pcap
#
# Saved 1 packets to E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9629.pcap
#
# Saved 1 packets to E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9630.pcap
#
# Saved 1 packets to E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9631.pcap
#
# Saved 1 packets to E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9632.pcap
#
# Saved 1 packets to E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9633.pcap
#
# Saved 1 packets to E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9637.pcap
#
# Saved 1 packets to E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9639.pcap
#
# Saved 1 packets to E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9640.pcap
#
# Saved 1 packets to E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9641.pcap
#
# Saved 1 packets to E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9642.pcap
#
# Saved 1 packets to E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9643.pcap
#
# Saved 1 packets to E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9644.pcap
#
# Saved 1 packets to E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9645.pcap
#
# Saved 1 packets to E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9646.pcap
#
# Saved 1 packets to E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9647.pcap
#
# Saved 1 packets to E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9648.pcap
#
# Saved 1 packets to E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9649.pcap
#
# Saved 1 packets to E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9650.pcap
#
# Saved 1 packets to E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9651.pcap
#
# Saved 1 packets to E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9652.pcap
#
# Saved 1 packets to E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9653.pcap
#
# Saved 1 packets to E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9654.pcap
#
# Saved 1 packets to E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9655.pcap
#
# Saved 1 packets to E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9656.pcap
#
# Saved 1 packets to E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9657.pcap
#
# Saved 1 packets to E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9658.pcap
#
# Saved 1 packets to E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9659.pcap
#
# Saved 1 packets to E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9660.pcap
#
# Saved 1 packets to E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9661.pcap
#
# Saved 1 packets to E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9662.pcap
#
# Saved 1 packets to E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9663.pcap
#
# Saved 1 packets to E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9664.pcap
#
# Saved 1 packets to E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9665.pcap
#
# Saved 1 packets to E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9666.pcap
#
# Saved 1 packets to E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9667.pcap
#
# Saved 1 packets to E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9668.pcap
#
# Saved 1 packets to E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9669.pcap
#
# Saved 1 packets to E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9672.pcap
#
# Saved 1 packets to E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9673.pcap
#
# Saved 1 packets to E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9677.pcap
#
# Saved 1 packets to E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9784.pcap
#
# Saved 1 packets to E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9785.pcap
#
# Saved 1 packets to E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9786.pcap
#
# Saved 1 packets to E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9788.pcap
#
# Saved 1 packets to E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9789.pcap
#
# Saved 1 packets to E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9790.pcap
#
# Saved 1 packets to E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9791.pcap
#
# Saved 1 packets to E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9793.pcap
#
# Saved 1 packets to E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9795.pcap
#
# Saved 1 packets to E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9796.pcap
#
# Saved 1 packets to E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9797.pcap
#
# Saved 21 packets to E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9803.pcap
#
# Saved 21 packets to E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9804.pcap
#
# Saved 21 packets to E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9805.pcap
#
# Saved 21 packets to E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9806.pcap
#
# Saved 21 packets to E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9807.pcap
#
# Saved 12 packets to E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9808.pcap
#
# Saved 14 packets to E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9810.pcap
#
# Saved 14 packets to E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9812.pcap
#
# Saved 14 packets to E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9814.pcap
#
# Saved 14 packets to E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9816.pcap
#
# Saved 22 packets to E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9818.pcap
#
# Saved 22 packets to E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9820.pcap
#
# Saved 24 packets to E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9821.pcap
#
# Saved 24 packets to E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9822.pcap
#
# Saved 24 packets to E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9823.pcap
#
# Saved 18 packets to E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9824.pcap
#
# Saved 19 packets to E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9825.pcap
#
# Saved 17 packets to E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9827.pcap
#
# Saved 18 packets to E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9828.pcap
#
# Saved 18 packets to E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9830.pcap
#
# Saved 21 packets to E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9832.pcap
#
# Saved 19 packets to E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9833.pcap
#
# Saved 19 packets to E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9834.pcap
#
# Saved 20 packets to E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9835.pcap
#
# Saved 19 packets to E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9836.pcap
#
# Saved 17 packets to E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9837.pcap
#
# Saved 17 packets to E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9838.pcap
#
# Saved 18 packets to E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9839.pcap
#
# Saved 18 packets to E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9840.pcap
#
# Saved 18 packets to E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9841.pcap
#
# Saved 34 packets to E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9842.pcap
#
# Saved 34 packets to E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9844.pcap
#
# Saved 34 packets to E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9845.pcap
#
# Saved 34 packets to E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9846.pcap
#
# Saved 38 packets to E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9847.pcap
#
# Saved 22 packets to E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9848.pcap
#
# Saved 33 packets to E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9849.pcap
#
# Saved 25 packets to E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9850.pcap
#
# Saved 26 packets to E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9853.pcap
#
# Saved 25 packets to E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9855.pcap
#
# Saved 38 packets to E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9856.pcap
#
# Saved 36 packets to E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9857.pcap
#
# Saved 34 packets to E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9858.pcap
#
# Saved 33 packets to E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9859.pcap
#
# Saved 34 packets to E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9860.pcap
#
# Saved 40 packets to E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9861.pcap
#
# Saved 40 packets to E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9862.pcap
#
# Saved 40 packets to E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9863.pcap
#
# Saved 13 packets to E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9864.pcap
#
# Saved 15 packets to E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9865.pcap
#
# Saved 38 packets to E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9866.pcap
#
# Saved 12 packets to E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9867.pcap
#
# Saved 14 packets to E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9868.pcap
#
# Saved 38 packets to E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9869.pcap
#
# Saved 25 packets to E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9870.pcap
#
# Saved 16 packets to E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9871.pcap
#
# Saved 50 packets to E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9872.pcap
#
# Saved 50 packets to E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9874.pcap
#
# Saved 174 packets to E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9875.pcap
#
# Saved 51 packets to E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9876.pcap
#
# Saved 51 packets to E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9877.pcap
#
# Saved 51 packets to E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9879.pcap
#
# Saved 18 packets to E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9880.pcap
#
# Saved 17 packets to E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9881.pcap
#
# Saved 18 packets to E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9882.pcap
#
# Saved 19 packets to E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9884.pcap
#
# Saved 19 packets to E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9886.pcap
#
# Saved 28 packets to E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9888.pcap
#
# Saved 28 packets to E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9889.pcap
#
# Saved 3 packets to E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9891.pcap
#
# Saved 29 packets to E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9892.pcap
#
# Saved 27 packets to E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9894.pcap
#
# Saved 27 packets to E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9895.pcap
#
# Saved 26 packets to E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9897.pcap
#
# Saved 25 packets to E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9898.pcap
#
# Saved 28 packets to E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9899.pcap
#
# Saved 25 packets to E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9900.pcap
#
# Saved 29 packets to E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9901.pcap
# Processing PCAP files:  29%|██▊       | 2/7 [39:17<1:52:14, 1346.97s/it]
# Saved 128047 packets to E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_20860.pcap
#
# Saved 574221 packets to E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_20862.pcap
#
# Saved 6 packets to E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_20863.pcap
#
# Saved 5 packets to E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_20864.pcap
#
# Saved 51 packets to E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_20865.pcap
#
# Saved 128 packets to E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_20866.pcap
#
# Saved 7 packets to E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_20867.pcap
#
# Saved 33 packets to E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_20868.pcap
#
# Saved 85 packets to E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_20869.pcap
#
# Saved 144 packets to E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_20870.pcap
#
# Saved 4 packets to E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_20871.pcap
#
# Saved 26 packets to E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_20872.pcap
#
# Saved 18 packets to E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_20873.pcap
#
# Saved 68 packets to E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_20874.pcap
#
# Saved 61 packets to E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_20875.pcap
#
# Saved 13 packets to E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_20877.pcap
#
# Saved 70 packets to E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_20878.pcap
#
# Saved 69 packets to E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_20879.pcap
#
# Saved 13 packets to E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_20881.pcap
#
# Saved 100 packets to E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_20882.pcap
#
# Saved 88 packets to E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_20884.pcap
#
# Saved 19 packets to E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_20885.pcap
#
# Saved 142 packets to E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_20886.pcap
#
# Saved 3 packets to E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_20887.pcap
#
# Saved 20 packets to E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_20888.pcap
#
# Saved 34 packets to E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_20889.pcap
#
# Saved 42 packets to E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_20890.pcap
#
# Saved 40 packets to E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_20891.pcap
#
# Saved 39 packets to E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_20892.pcap
#
# Saved 97 packets to E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_20893.pcap
#
# Saved 48 packets to E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_20894.pcap
#
# Saved 10 packets to E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_20895.pcap
#
# Saved 3 packets to E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_20896.pcap
#
# Saved 22 packets to E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_20897.pcap
#
# Saved 54 packets to E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_20898.pcap
#
# Saved 10 packets to E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_20900.pcap
#
# Saved 38 packets to E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_20901.pcap
#
# Saved 42 packets to E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_20902.pcap
#
# Saved 59 packets to E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_20903.pcap
#
# Saved 42 packets to E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_20904.pcap
#
# Saved 45 packets to E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_20905.pcap
#
# Saved 19 packets to E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_20906.pcap
#
# Saved 51 packets to E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_20907.pcap
#
# Saved 101 packets to E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_20908.pcap
#
# Saved 33 packets to E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_20909.pcap
#
# Saved 4 packets to E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_20910.pcap
#
# Saved 16 packets to E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_20911.pcap
#
# Saved 4 packets to E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_20912.pcap
#
# Saved 163 packets to E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_20913.pcap
#
# Saved 90 packets to E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_20914.pcap
#
# Saved 55 packets to E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_20915.pcap
#
# Saved 37 packets to E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_20916.pcap
#
# Saved 16 packets to E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_20917.pcap
#
# Saved 108 packets to E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_20918.pcap
#
# Saved 109 packets to E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_20919.pcap
#
# Saved 58 packets to E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_20920.pcap
#
# Saved 6 packets to E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_20921.pcap
#
# Saved 158 packets to E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_20922.pcap
#
# Saved 40 packets to E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_20923.pcap
#
# Saved 71 packets to E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_20924.pcap
#
# Saved 30 packets to E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_20925.pcap
#
# Saved 141 packets to E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_20926.pcap
#
# Saved 46 packets to E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_20927.pcap
#
# Saved 24 packets to E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_20928.pcap
#
# Saved 166 packets to E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_20929.pcap
#
# Saved 23 packets to E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_20930.pcap
#
# Saved 12 packets to E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_20931.pcap
#
# Saved 39 packets to E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_20932.pcap
#
# Saved 60 packets to E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_20933.pcap
#
# Saved 5 packets to E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_20934.pcap
#
# Saved 110 packets to E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_20935.pcap
#
# Saved 12 packets to E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_20936.pcap
#
# Saved 28 packets to E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_20937.pcap
#
# Saved 80 packets to E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_20938.pcap
#
# Saved 5 packets to E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_20939.pcap
#
# Saved 60 packets to E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_20940.pcap
#
# Saved 4 packets to E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_20941.pcap
#
# Saved 82 packets to E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_20942.pcap
#
# Saved 38 packets to E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_20943.pcap
#
# Saved 9 packets to E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_20944.pcap
#
# Saved 24 packets to E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_20945.pcap
#
# Saved 24 packets to E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_20946.pcap
#
# Saved 6 packets to E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_20947.pcap
#
# Saved 24 packets to E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_20948.pcap
#
# Saved 73 packets to E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_20949.pcap
#
# Saved 4 packets to E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_20950.pcap
#
# Saved 41 packets to E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_20951.pcap
#
# Saved 20 packets to E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_20952.pcap
#
# Saved 67 packets to E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_20953.pcap
#
# Saved 80 packets to E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_20954.pcap
#
# Saved 63 packets to E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_20955.pcap
#
# Saved 73 packets to E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_20956.pcap
#
# Saved 70 packets to E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_20957.pcap
#
# Saved 5 packets to E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_20958.pcap
#
# Saved 51 packets to E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_20959.pcap
#
# Saved 108 packets to E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_20960.pcap
#
# Saved 132 packets to E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_20961.pcap
#
# Saved 11 packets to E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_20962.pcap
#
# Saved 11 packets to E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_20963.pcap
#
# Saved 105 packets to E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_20964.pcap
#
# Saved 13 packets to E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_20965.pcap
#
# Saved 240 packets to E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_20966.pcap
#
# Saved 10 packets to E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_20968.pcap
#
# Saved 24 packets to E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_20969.pcap
#
# Saved 64 packets to E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_20970.pcap
#
# Saved 5 packets to E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_20972.pcap
#
# Saved 50 packets to E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_20973.pcap
#
# Saved 11 packets to E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_20974.pcap
#
# Saved 41 packets to E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_20975.pcap
#
# Saved 29 packets to E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_20976.pcap
#
# Saved 14 packets to E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_20977.pcap
#
# Saved 24 packets to E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_20978.pcap
#
# Saved 69 packets to E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_20979.pcap
#
# Saved 65 packets to E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_20980.pcap
#
# Saved 63 packets to E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_20981.pcap
#
# Saved 56 packets to E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_20982.pcap
#
# Saved 171 packets to E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_20983.pcap
#
# Saved 6 packets to E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_20984.pcap
#
# Saved 111 packets to E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_20985.pcap
#
# Saved 11 packets to E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_20986.pcap
#
# Saved 50 packets to E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_20987.pcap
#
# Saved 5 packets to E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_20988.pcap
#
# Saved 11 packets to E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_20989.pcap
#
# Saved 35 packets to E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_20990.pcap
#
# Saved 128 packets to E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_20991.pcap
#
# Saved 25 packets to E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_20992.pcap
#
# Saved 50 packets to E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_20993.pcap
#
# Saved 41 packets to E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_20994.pcap
#
# Saved 17 packets to E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_20995.pcap
#
# Saved 21 packets to E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_20996.pcap
#
# Saved 8 packets to E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_20997.pcap
#
# Saved 61 packets to E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_20998.pcap
#
# Saved 1 packets to E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_20999.pcap
#
# Saved 114 packets to E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_21000.pcap
#
# Saved 9 packets to E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_21001.pcap
#
# Saved 39 packets to E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_21002.pcap
#
# Saved 1 packets to E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_21003.pcap
#
# Saved 13 packets to E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_21004.pcap
#
# Saved 79 packets to E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_21005.pcap
#
# Saved 138 packets to E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_21006.pcap
#
# Saved 179 packets to E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_21007.pcap
#
# Saved 156 packets to E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_21008.pcap
#
# Saved 234 packets to E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_21009.pcap
#
# Saved 3 packets to E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_21010.pcap
#
# Saved 100 packets to E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_21011.pcap
#
# Saved 87 packets to E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_21012.pcap
#
# Saved 31 packets to E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_21013.pcap
#
# Saved 6 packets to E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_21014.pcap
#
# Saved 34 packets to E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_21015.pcap
#
# Saved 105 packets to E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_21016.pcap
#
# Saved 6 packets to E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_21017.pcap
#
# Saved 136 packets to E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_21018.pcap
#
# Saved 49 packets to E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_21019.pcap
#
# Saved 21 packets to E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_21020.pcap
#
# Saved 144 packets to E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_21021.pcap
#
# Saved 52 packets to E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_21022.pcap
#
# Saved 194 packets to E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_21023.pcap
#
# Saved 6 packets to E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_21024.pcap
#
# Saved 82 packets to E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_21025.pcap
#
# Saved 12 packets to E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_21026.pcap
#
# Saved 5 packets to E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_21027.pcap
#
# Saved 5 packets to E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_21028.pcap
#
# Saved 26 packets to E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_21029.pcap
#
# Saved 68 packets to E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_21030.pcap
#
# Saved 117 packets to E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_21031.pcap
#
# Saved 29 packets to E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_21032.pcap
#
# Saved 15 packets to E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_21033.pcap
#
# Saved 97 packets to E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_21034.pcap
#
# Saved 136 packets to E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_21035.pcap
#
# Saved 21 packets to E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_21036.pcap
#
# Saved 9 packets to E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_21037.pcap
#
# Saved 14 packets to E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_21038.pcap
#
# Saved 14 packets to E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_21039.pcap
#
# Saved 7 packets to E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_21040.pcap
#
# Saved 144 packets to E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_21041.pcap
#
# Saved 14 packets to E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_21042.pcap
#
# Saved 5 packets to E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_21043.pcap
#
# Saved 82 packets to E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_21044.pcap
#
# Saved 129 packets to E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_21045.pcap
#
# Saved 71 packets to E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_21046.pcap
#
# Saved 103 packets to E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_21047.pcap
#
# Saved 11 packets to E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_21048.pcap
#
# Saved 119 packets to E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_21049.pcap
#
# Saved 44 packets to E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_21050.pcap
#
# Saved 20 packets to E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_21051.pcap
#
# Saved 7 packets to E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_21053.pcap
#
# Saved 8 packets to E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_21054.pcap
#
# Saved 54 packets to E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_21055.pcap
#
# Saved 109 packets to E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_21056.pcap
#
# Saved 53 packets to E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_21057.pcap
#
# Saved 142 packets to E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_21058.pcap
#
# Saved 13 packets to E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_21059.pcap
#
# Saved 53 packets to E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_21060.pcap
#
# Saved 59 packets to E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_21061.pcap
#
# Saved 68 packets to E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_21062.pcap
#
# Saved 61 packets to E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_21063.pcap
#
# Saved 9 packets to E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_21064.pcap
#
# Saved 26 packets to E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_21065.pcap
#
# Saved 11 packets to E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_21066.pcap
#
# Saved 46 packets to E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_21067.pcap
#
# Saved 73 packets to E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_21068.pcap
#
# Saved 6 packets to E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_21069.pcap
#
# Saved 70 packets to E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_21070.pcap
#
# Saved 11 packets to E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_21071.pcap
#
# Saved 55 packets to E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_21072.pcap
#
# Saved 59 packets to E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_21073.pcap
#
# Saved 7 packets to E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_21074.pcap
#
# Saved 22 packets to E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_21076.pcap
#
# Saved 46 packets to E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_21077.pcap
#
# Saved 102 packets to E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_21078.pcap
#
# Saved 58 packets to E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_21079.pcap
#
# Saved 60 packets to E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_21080.pcap
#
# Saved 13 packets to E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_21081.pcap
#
# Saved 59 packets to E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_21082.pcap
#
# Saved 68 packets to E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_21084.pcap
#
# Saved 69 packets to E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_21085.pcap
#
# Saved 4 packets to E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_21086.pcap
#
# Saved 10 packets to E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_21087.pcap
#
# Saved 33 packets to E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_21088.pcap
#
# Saved 49 packets to E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_21089.pcap
#
# Saved 8 packets to E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_21090.pcap
#
# Saved 24 packets to E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_21091.pcap
#
# Saved 14 packets to E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_21092.pcap
#
# Saved 75 packets to E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_21094.pcap
#
# Saved 6 packets to E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_21095.pcap
#
# Saved 41 packets to E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_21096.pcap
#
# Saved 7 packets to E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_21097.pcap
#
# Saved 36 packets to E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_21098.pcap
#
# Saved 9 packets to E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_21099.pcap
#
# Saved 9 packets to E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_21100.pcap
#
# Saved 81 packets to E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_21101.pcap
#
# Saved 22 packets to E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_21102.pcap
#
# Saved 16 packets to E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_21103.pcap
#
# Saved 123 packets to E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_21104.pcap
#
# Saved 58 packets to E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_21105.pcap
#
# Saved 1 packets to E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_21106.pcap
#
# Saved 67 packets to E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_21107.pcap
#
# Saved 10 packets to E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_21108.pcap
#
# Saved 19 packets to E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_21109.pcap
#
# Saved 81 packets to E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_21110.pcap
#
# Saved 90 packets to E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_21111.pcap
#
# Saved 80 packets to E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_21112.pcap
#
# Saved 37 packets to E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_21113.pcap
#
# Saved 57 packets to E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_21114.pcap
#
# Saved 42 packets to E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_21115.pcap
#
# Saved 19 packets to E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_21116.pcap
#
# Saved 124 packets to E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_21117.pcap
#
# Saved 31 packets to E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_21118.pcap
#
# Saved 64 packets to E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_21119.pcap
#
# Saved 161 packets to E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_21120.pcap
#
# Saved 53 packets to E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_21121.pcap
#
# Saved 77 packets to E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_21122.pcap
#
# Saved 143 packets to E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_21123.pcap
#
# Saved 54 packets to E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_21124.pcap
#
# Saved 5 packets to E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_21125.pcap
#
# Saved 24 packets to E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_21126.pcap
#
# Saved 28 packets to E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_21127.pcap
#
# Saved 9 packets to E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_21128.pcap
#
# Saved 131 packets to E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_21129.pcap
#
# Saved 4 packets to E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_21130.pcap
#
# Saved 96 packets to E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_21131.pcap
#
# Saved 4 packets to E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_21132.pcap
#
# Saved 9 packets to E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_21133.pcap
#
# Saved 22 packets to E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_21134.pcap
#
# Saved 114 packets to E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_21135.pcap
#
# Saved 64 packets to E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_21136.pcap
#
# Saved 40 packets to E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_21137.pcap
#
# Saved 172 packets to E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_21138.pcap
#
# Saved 4 packets to E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_21139.pcap
#
# Saved 106 packets to E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_21140.pcap
#
# Saved 193 packets to E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_21141.pcap
#
# Saved 4 packets to E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_21142.pcap
#
# Saved 26 packets to E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_21143.pcap
#
# Saved 11 packets to E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_21144.pcap
#
# Saved 139 packets to E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_21145.pcap
#
# Saved 43 packets to E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_21146.pcap
#
# Saved 16 packets to E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_21147.pcap
#
# Saved 4 packets to E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_21148.pcap
#
# Saved 43 packets to E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_21149.pcap
#
# Saved 28 packets to E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_21150.pcap
#
# Saved 97 packets to E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_21151.pcap
#
# Saved 3 packets to E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_21152.pcap
#
# Saved 25150 packets to E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_21162.pcap
#
# Saved 1 packets to E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_21187.pcap
#
# Saved 1 packets to E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_21196.pcap
#
# Saved 1 packets to E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_21200.pcap
#
# Saved 1 packets to E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_21205.pcap
#
# Saved 98318 packets to E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_21212.pcap
#
# Saved 3 packets to E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_21213.pcap
#
# Saved 289 packets to E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_21214.pcap
#
# Saved 67945 packets to E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_21216.pcap
#
# Saved 1 packets to E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_21226.pcap
#
# Saved 1 packets to E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_21252.pcap
#
# Saved 1 packets to E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_21293.pcap
#
# Saved 1 packets to E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_21298.pcap
#
# Saved 1 packets to E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_21300.pcap
#
# Saved 1 packets to E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_21362.pcap
#
# Saved 2 packets to E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_21400.pcap
#
# Saved 1 packets to E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_21406.pcap
#
# Saved 1 packets to E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_21425.pcap
#
# Saved 1 packets to E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_21452.pcap
#
# Saved 1 packets to E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_21470.pcap
#
# Saved 1 packets to E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_21488.pcap
#
# Saved 1 packets to E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_21518.pcap
#
# Saved 1 packets to E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_21570.pcap
#
# Saved 1 packets to E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_21601.pcap
#
# Saved 1 packets to E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_21609.pcap
#
# Saved 1 packets to E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_21632.pcap
#
# Saved 1 packets to E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_21663.pcap
#
# Saved 1 packets to E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_21673.pcap
#
# Saved 1 packets to E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_21697.pcap
#
# Saved 1 packets to E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_21739.pcap
#
# Saved 1 packets to E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_21756.pcap
#
# Saved 1 packets to E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_21762.pcap
#
# Saved 1 packets to E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_21780.pcap
#
# Saved 1 packets to E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_21884.pcap
#
# Saved 1 packets to E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_21886.pcap
#
# Saved 70091 packets to E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_21955.pcap
#
# Saved 1 packets to E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_21969.pcap
#
# Saved 1 packets to E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_21970.pcap
#
# Saved 1 packets to E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_21973.pcap
#
# Saved 1 packets to E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_21982.pcap
#
# Saved 1 packets to E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_22112.pcap
#
# Saved 99226 packets to E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_22163.pcap
#
# Saved 1 packets to E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_22167.pcap
#
# Saved 1 packets to E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_22172.pcap
#
# Saved 1 packets to E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_22242.pcap
#
# Saved 1 packets to E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_22285.pcap
#
# Saved 1 packets to E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_22292.pcap
#
# Saved 1 packets to E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_22334.pcap
#
# Saved 1 packets to E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_22343.pcap
#
# Saved 1 packets to E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_22419.pcap
#
# Saved 1 packets to E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_22428.pcap
#
# Saved 1 packets to E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_22429.pcap
#
# Saved 1 packets to E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_22487.pcap
#
# Saved 1 packets to E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_22491.pcap
#
# Saved 1 packets to E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_22602.pcap
#
# Saved 1 packets to E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_22617.pcap
#
# Saved 1 packets to E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_22649.pcap
#
# Saved 1 packets to E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_22653.pcap
#
# Saved 1 packets to E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_22674.pcap
#
# Saved 1 packets to E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_22710.pcap
#
# Saved 1 packets to E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_22718.pcap
#
# Saved 1 packets to E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_22720.pcap
#
# Saved 1 packets to E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_22733.pcap
#
# Saved 1 packets to E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_22813.pcap
#
# Saved 1 packets to E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_22830.pcap
#
# Saved 1 packets to E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_22841.pcap
#
# Saved 1 packets to E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_22844.pcap
#
# Saved 420814 packets to E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_22879.pcap
# Processing PCAP files: 100%|██████████| 7/7 [3:37:52<00:00, 1867.45s/it]

# %% [markdown]
# # Merge malicious pcap files into one 'Deprecated'

# %%
from scapy.all import PcapReader, PcapWriter
import glob
import os

# Define the directory containing the PCAP files and the output file
pcap_directory = "E:\\Dataset\\Dataset_1\\extracted\\"  # Adjust as needed
output_file = "E:\\Dataset\\Dataset_1\\merged_output.pcap"

# Get a list of all PCAP files in the specified directory
pcap_files = glob.glob(os.path.join(pcap_directory, "*.pcap"))

# Create a PcapWriter object for the output file
# Set sync=True to ensure packets are written immediately.
with PcapWriter(output_file, append=False, sync=True) as writer:
    for pcap_file in pcap_files:
        print(f"Processing: {pcap_file}")
        # Use PcapReader to iterate through packets one at a time
        try:
            with PcapReader(pcap_file) as reader:
                for pkt in reader:
                    writer.write(pkt)
        except Exception as e:
            print(f"Error processing {pcap_file}: {e}")

print(f"\nAll PCAP files have been merged into: {output_file}")
# Out:
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-public-thursday_100.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-public-thursday_101.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-public-thursday_103.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-public-thursday_105.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-public-thursday_106.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-public-thursday_107.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-public-thursday_108.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-public-thursday_109.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-public-thursday_110.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-public-thursday_111.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-public-thursday_112.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-public-thursday_113.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-public-thursday_114.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-public-thursday_115.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-public-thursday_116.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-public-thursday_117.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-public-thursday_118.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-public-thursday_119.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-public-thursday_88.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-public-thursday_89.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-public-thursday_91.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-public-thursday_93.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-public-thursday_96.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-public-thursday_97.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-public-thursday_98.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-public-thursday_99.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9402.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9403.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9404.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9405.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9406.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9407.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9408.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9409.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9410.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9411.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9412.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9414.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9416.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9417.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9418.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9419.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9420.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9421.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9422.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9423.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9424.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9426.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9427.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9429.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9430.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9431.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9437.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9438.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9440.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9442.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9444.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9446.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9448.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9449.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9450.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9451.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9452.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9453.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9460.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9463.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9464.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9465.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9466.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9467.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9468.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9469.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9470.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9471.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9472.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9473.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9474.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9475.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9476.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9477.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9478.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9479.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9480.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9481.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9482.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9483.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9484.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9485.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9486.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9487.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9488.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9489.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9490.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9491.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9492.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9493.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9494.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9495.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9496.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9497.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9498.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9499.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9500.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9501.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9502.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9503.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9504.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9505.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9506.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9507.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9508.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9509.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9510.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9511.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9512.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9513.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9514.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9515.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9516.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9517.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9518.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9519.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9520.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9521.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9522.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9523.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9524.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9525.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9526.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9527.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9528.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9529.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9530.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9533.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9535.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9536.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9537.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9538.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9539.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9540.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9541.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9542.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9543.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9544.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9545.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9546.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9547.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9548.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9552.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9553.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9554.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9555.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9556.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9557.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9558.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9559.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9560.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9561.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9562.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9563.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9564.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9565.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9566.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9567.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9568.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9569.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9570.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9571.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9572.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9573.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9574.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9575.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9576.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9577.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9578.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9579.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9580.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9581.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9582.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9583.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9584.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9585.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9586.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9587.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9588.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9589.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9590.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9591.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9592.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9593.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9594.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9595.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9596.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9597.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9598.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9599.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9600.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9601.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9602.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9603.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9604.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9605.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9606.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9607.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9608.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9609.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9610.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9611.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9612.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9613.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9614.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9615.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9616.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9617.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9618.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9619.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9620.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9621.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9622.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9623.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9624.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9625.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9626.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9627.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9629.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9630.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9631.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9632.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9633.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9637.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9639.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9640.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9641.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9642.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9643.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9644.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9645.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9646.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9647.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9648.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9649.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9650.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9651.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9652.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9653.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9654.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9655.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9656.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9657.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9658.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9659.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9660.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9661.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9662.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9663.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9664.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9665.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9666.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9667.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9668.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9669.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9672.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9673.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9677.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9784.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9785.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9786.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9788.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9789.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9790.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9791.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9793.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9795.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9796.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9797.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9803.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9804.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9805.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9806.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9807.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9808.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9810.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9812.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9814.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9816.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9818.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9820.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9821.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9822.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9823.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9824.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9825.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9827.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9828.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9830.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9832.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9833.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9834.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9835.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9836.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9837.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9838.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9839.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9840.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9841.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9842.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9844.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9845.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9846.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9847.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9848.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9849.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9850.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9853.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9855.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9856.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9857.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9858.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9859.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9860.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9861.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9862.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9863.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9864.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9865.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9866.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9867.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9868.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9869.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9870.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9871.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9872.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9874.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9875.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9876.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9877.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9879.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9880.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9881.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9882.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9884.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9886.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9888.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9889.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9891.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9892.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9894.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9895.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9897.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9898.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9899.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9900.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-public-tuesday_9901.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_20860.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_20862.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_20863.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_20864.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_20865.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_20866.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_20867.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_20868.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_20869.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_20870.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_20871.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_20872.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_20873.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_20874.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_20875.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_20877.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_20878.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_20879.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_20881.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_20882.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_20884.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_20885.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_20886.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_20887.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_20888.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_20889.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_20890.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_20891.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_20892.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_20893.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_20894.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_20895.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_20896.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_20897.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_20898.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_20900.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_20901.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_20902.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_20903.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_20904.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_20905.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_20906.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_20907.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_20908.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_20909.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_20910.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_20911.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_20912.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_20913.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_20914.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_20915.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_20916.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_20917.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_20918.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_20919.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_20920.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_20921.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_20922.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_20923.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_20924.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_20925.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_20926.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_20927.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_20928.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_20929.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_20930.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_20931.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_20932.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_20933.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_20934.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_20935.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_20936.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_20937.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_20938.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_20939.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_20940.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_20941.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_20942.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_20943.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_20944.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_20945.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_20946.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_20947.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_20948.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_20949.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_20950.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_20951.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_20952.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_20953.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_20954.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_20955.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_20956.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_20957.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_20958.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_20959.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_20960.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_20961.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_20962.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_20963.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_20964.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_20965.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_20966.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_20968.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_20969.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_20970.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_20972.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_20973.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_20974.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_20975.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_20976.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_20977.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_20978.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_20979.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_20980.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_20981.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_20982.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_20983.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_20984.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_20985.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_20986.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_20987.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_20988.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_20989.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_20990.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_20991.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_20992.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_20993.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_20994.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_20995.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_20996.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_20997.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_20998.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_20999.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_21000.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_21001.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_21002.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_21003.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_21004.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_21005.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_21006.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_21007.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_21008.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_21009.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_21010.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_21011.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_21012.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_21013.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_21014.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_21015.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_21016.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_21017.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_21018.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_21019.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_21020.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_21021.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_21022.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_21023.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_21024.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_21025.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_21026.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_21027.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_21028.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_21029.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_21030.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_21031.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_21032.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_21033.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_21034.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_21035.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_21036.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_21037.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_21038.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_21039.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_21040.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_21041.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_21042.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_21043.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_21044.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_21045.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_21046.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_21047.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_21048.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_21049.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_21050.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_21051.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_21053.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_21054.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_21055.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_21056.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_21057.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_21058.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_21059.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_21060.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_21061.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_21062.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_21063.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_21064.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_21065.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_21066.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_21067.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_21068.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_21069.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_21070.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_21071.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_21072.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_21073.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_21074.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_21076.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_21077.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_21078.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_21079.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_21080.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_21081.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_21082.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_21084.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_21085.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_21086.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_21087.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_21088.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_21089.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_21090.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_21091.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_21092.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_21094.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_21095.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_21096.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_21097.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_21098.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_21099.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_21100.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_21101.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_21102.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_21103.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_21104.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_21105.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_21106.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_21107.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_21108.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_21109.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_21110.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_21111.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_21112.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_21113.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_21114.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_21115.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_21116.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_21117.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_21118.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_21119.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_21120.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_21121.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_21122.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_21123.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_21124.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_21125.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_21126.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_21127.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_21128.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_21129.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_21130.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_21131.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_21132.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_21133.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_21134.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_21135.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_21136.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_21137.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_21138.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_21139.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_21140.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_21141.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_21142.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_21143.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_21144.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_21145.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_21146.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_21147.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_21148.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_21149.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_21150.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_21151.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_21152.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_21162.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_21187.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_21196.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_21200.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_21205.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_21212.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_21213.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_21214.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_21216.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_21226.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_21252.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_21293.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_21298.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_21300.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_21362.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_21400.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_21406.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_21425.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_21452.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_21470.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_21488.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_21518.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_21570.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_21601.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_21609.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_21632.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_21663.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_21673.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_21697.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_21739.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_21756.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_21762.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_21780.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_21884.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_21886.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_21955.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_21969.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_21970.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_21973.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_21982.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_22112.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_22163.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_22167.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_22172.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_22242.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_22285.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_22292.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_22334.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_22343.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_22419.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_22428.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_22429.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_22487.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_22491.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_22602.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_22617.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_22649.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_22653.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_22674.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_22710.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_22718.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_22720.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_22733.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_22813.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_22830.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_22841.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_22844.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-pvt-thursday_22879.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-tcpdump-friday_22967.pcap
# Processing: E:\Dataset\Dataset_1\extracted\enp0s3-tcpdump-pvt-friday_22974.pcap
#
# All PCAP files have been merged into: E:\Dataset\Dataset_1\merged_output.pcap

# %% [markdown]
# # Change "Stage" feature value to 1 (malicious)

# %%
import pandas as pd

# Specify input and output file paths
input_csv = "E:\PFE2025\Dataset\Dataset_1\combined_output.csv"
output_csv = "E:\PFE2025\Dataset\Dataset_1\combined_output.csv"

# Read the CSV file
df = pd.read_csv(input_csv)

# Set every value in the "Label" column to 1
df["Label"] = 1

# Save the modified DataFrame back to a CSV file
df.to_csv(output_csv, index=False)

print(f"Updated CSV saved as {output_csv}")
# Out:
# Updated CSV saved as E:\PFE2025\Dataset\Dataset_1\combined_output.csv

# %% [markdown]
# # Delete pcap files containing only 1 packet

# %%
import os
from scapy.utils import PcapReader
from tqdm import tqdm

def count_packets(pcap_path):
    """
    Count the number of packets in a PCAP file.
    Returns -1 if the file is corrupted or unreadable.
    """
    try:
        with PcapReader(pcap_path) as pcap:
            # Read just the first two packets
            first_packet = next(pcap, None)
            if first_packet is None:
                return 0
            second_packet = next(pcap, None)
            if second_packet is None:
                return 1
            return 2  # If we found two packets, no need to count more
            
    except Exception as e:
        print(f"Error reading {pcap_path}: {e}")
        return -1

def cleanup_pcap_folder(folder_path):
    """
    Delete PCAP files containing only one packet from the specified folder.
    Returns statistics about the operation.
    """
    stats = {
        'total_files': 0,
        'deleted_files': 0,
        'error_files': 0,
        'skipped_files': 0
    }
    
    # Get list of all PCAP files
    pcap_files = [f for f in os.listdir(folder_path) 
                  if f.lower().endswith(('.pcap', '.pcapng'))]
    stats['total_files'] = len(pcap_files)
    
    # Process each file with a progress bar
    for filename in tqdm(pcap_files, desc="Processing PCAP files"):
        file_path = os.path.join(folder_path, filename)
        
        # Skip if not a file
        if not os.path.isfile(file_path):
            stats['skipped_files'] += 1
            continue
            
        # Count packets
        packet_count = count_packets(file_path)
        
        if packet_count == 1:
            try:
                os.remove(file_path)
                stats['deleted_files'] += 1
                print(f"\nDeleted: {filename} (1 packet)")
            except Exception as e:
                print(f"\nError deleting {filename}: {e}")
                stats['error_files'] += 1
        elif packet_count == -1:
            stats['error_files'] += 1

    return stats

# %%
def main():
    # Get folder path from user
    folder_path = input("Enter the path to the folder containing PCAP files: ").strip()
    
    # Verify folder exists
    if not os.path.isdir(folder_path):
        print("Error: Invalid folder path!")
        return
    
    # Confirm with user
    print(f"\nWARNING: This will delete all PCAP files containing only one packet in:")
    print(f"  {folder_path}")
    confirmation = input("\nDo you want to continue? (yes/no): ").strip().lower()
    
    if confirmation != 'yes':
        print("Operation cancelled.")
        return
    
    # Process the folder
    print("\nStarting cleanup...")
    stats = cleanup_pcap_folder(folder_path)
    
    # Print summary
    print("\nCleanup Summary:")
    print(f"Total PCAP files found: {stats['total_files']}")
    print(f"Files deleted: {stats['deleted_files']}")
    print(f"Files with errors: {stats['error_files']}")
    print(f"Files skipped: {stats['skipped_files']}")
    print(f"Files retained: {stats['total_files'] - stats['deleted_files'] - stats['error_files']}")


main()
# Out:
# WARNING: This will delete all PCAP files containing only one packet in:
#   E:\Dataset\Dataset_1\extracted
#
# Starting cleanup...
# Processing PCAP files:   0%|          | 0/705 [00:00<?, ?it/s]WARNING: PcapReader: unknown LL type [1]/[0x1]. Using Raw packets
# Processing PCAP files:   0%|          | 1/705 [00:00<02:25,  4.83it/s]WARNING: PcapReader: unknown LL type [1]/[0x1]. Using Raw packets
# WARNING: more PcapReader: unknown LL type [1]/[0x1]. Using Raw packets
# Processing PCAP files:  13%|█▎        | 90/705 [00:00<00:03, 201.34it/s]
# Deleted: enp0s3-public-tuesday_9495.pcap (1 packet)
#
# Deleted: enp0s3-public-tuesday_9496.pcap (1 packet)
#
# Deleted: enp0s3-public-tuesday_9497.pcap (1 packet)
#
# Deleted: enp0s3-public-tuesday_9498.pcap (1 packet)
#
# Deleted: enp0s3-public-tuesday_9499.pcap (1 packet)
#
# Deleted: enp0s3-public-tuesday_9500.pcap (1 packet)
#
# Deleted: enp0s3-public-tuesday_9501.pcap (1 packet)
#
# Deleted: enp0s3-public-tuesday_9502.pcap (1 packet)
#
# Deleted: enp0s3-public-tuesday_9503.pcap (1 packet)
#
# Deleted: enp0s3-public-tuesday_9504.pcap (1 packet)
#
# Deleted: enp0s3-public-tuesday_9505.pcap (1 packet)
#
# Deleted: enp0s3-public-tuesday_9506.pcap (1 packet)
#
# Deleted: enp0s3-public-tuesday_9507.pcap (1 packet)
#
# Deleted: enp0s3-public-tuesday_9508.pcap (1 packet)
#
# Deleted: enp0s3-public-tuesday_9509.pcap (1 packet)
#
# Deleted: enp0s3-public-tuesday_9510.pcap (1 packet)
# Processing PCAP files:  16%|█▌        | 113/705 [00:00<00:02, 207.76it/s]
# Deleted: enp0s3-public-tuesday_9511.pcap (1 packet)
#
# Deleted: enp0s3-public-tuesday_9513.pcap (1 packet)
#
# Deleted: enp0s3-public-tuesday_9514.pcap (1 packet)
#
# Deleted: enp0s3-public-tuesday_9515.pcap (1 packet)
#
# Deleted: enp0s3-public-tuesday_9516.pcap (1 packet)
#
# Deleted: enp0s3-public-tuesday_9518.pcap (1 packet)
#
# Deleted: enp0s3-public-tuesday_9519.pcap (1 packet)
#
# Deleted: enp0s3-public-tuesday_9520.pcap (1 packet)
#
# Deleted: enp0s3-public-tuesday_9521.pcap (1 packet)
#
# Deleted: enp0s3-public-tuesday_9522.pcap (1 packet)
#
# Deleted: enp0s3-public-tuesday_9523.pcap (1 packet)
#
# Deleted: enp0s3-public-tuesday_9524.pcap (1 packet)
#
# Deleted: enp0s3-public-tuesday_9525.pcap (1 packet)
#
# Deleted: enp0s3-public-tuesday_9526.pcap (1 packet)
#
# Deleted: enp0s3-public-tuesday_9527.pcap (1 packet)
#
# Deleted: enp0s3-public-tuesday_9528.pcap (1 packet)
#
# Deleted: enp0s3-public-tuesday_9529.pcap (1 packet)
#
# Deleted: enp0s3-public-tuesday_9530.pcap (1 packet)
#
# Deleted: enp0s3-public-tuesday_9533.pcap (1 packet)
#
# Deleted: enp0s3-public-tuesday_9535.pcap (1 packet)
#
# Deleted: enp0s3-public-tuesday_9536.pcap (1 packet)
#
# Deleted: enp0s3-public-tuesday_9537.pcap (1 packet)
#
# Deleted: enp0s3-public-tuesday_9538.pcap (1 packet)
# Processing PCAP files:  20%|█▉        | 138/705 [00:00<00:02, 219.60it/s]
# Deleted: enp0s3-public-tuesday_9539.pcap (1 packet)
#
# Deleted: enp0s3-public-tuesday_9540.pcap (1 packet)
#
# Deleted: enp0s3-public-tuesday_9541.pcap (1 packet)
#
# Deleted: enp0s3-public-tuesday_9542.pcap (1 packet)
#
# Deleted: enp0s3-public-tuesday_9543.pcap (1 packet)
#
# Deleted: enp0s3-public-tuesday_9544.pcap (1 packet)
#
# Deleted: enp0s3-public-tuesday_9545.pcap (1 packet)
#
# Deleted: enp0s3-public-tuesday_9546.pcap (1 packet)
#
# Deleted: enp0s3-public-tuesday_9547.pcap (1 packet)
#
# Deleted: enp0s3-public-tuesday_9548.pcap (1 packet)
#
# Deleted: enp0s3-public-tuesday_9552.pcap (1 packet)
#
# Deleted: enp0s3-public-tuesday_9553.pcap (1 packet)
#
# Deleted: enp0s3-public-tuesday_9554.pcap (1 packet)
#
# Deleted: enp0s3-public-tuesday_9555.pcap (1 packet)
#
# Deleted: enp0s3-public-tuesday_9556.pcap (1 packet)
#
# Deleted: enp0s3-public-tuesday_9557.pcap (1 packet)
#
# Deleted: enp0s3-public-tuesday_9558.pcap (1 packet)
#
# Deleted: enp0s3-public-tuesday_9559.pcap (1 packet)
#
# Deleted: enp0s3-public-tuesday_9560.pcap (1 packet)
#
# Deleted: enp0s3-public-tuesday_9561.pcap (1 packet)
#
# Deleted: enp0s3-public-tuesday_9562.pcap (1 packet)
#
# Deleted: enp0s3-public-tuesday_9563.pcap (1 packet)
#
# Deleted: enp0s3-public-tuesday_9564.pcap (1 packet)
#
# Deleted: enp0s3-public-tuesday_9565.pcap (1 packet)
#
# Deleted: enp0s3-public-tuesday_9566.pcap (1 packet)
# Processing PCAP files:  23%|██▎       | 163/705 [00:00<00:02, 222.87it/s]
# Deleted: enp0s3-public-tuesday_9567.pcap (1 packet)
#
# Deleted: enp0s3-public-tuesday_9568.pcap (1 packet)
#
# Deleted: enp0s3-public-tuesday_9569.pcap (1 packet)
#
# Deleted: enp0s3-public-tuesday_9570.pcap (1 packet)
#
# Deleted: enp0s3-public-tuesday_9571.pcap (1 packet)
#
# Deleted: enp0s3-public-tuesday_9572.pcap (1 packet)
#
# Deleted: enp0s3-public-tuesday_9573.pcap (1 packet)
#
# Deleted: enp0s3-public-tuesday_9574.pcap (1 packet)
#
# Deleted: enp0s3-public-tuesday_9575.pcap (1 packet)
#
# Deleted: enp0s3-public-tuesday_9576.pcap (1 packet)
#
# Deleted: enp0s3-public-tuesday_9577.pcap (1 packet)
#
# Deleted: enp0s3-public-tuesday_9578.pcap (1 packet)
#
# Deleted: enp0s3-public-tuesday_9579.pcap (1 packet)
#
# Deleted: enp0s3-public-tuesday_9580.pcap (1 packet)
#
# Deleted: enp0s3-public-tuesday_9581.pcap (1 packet)
#
# Deleted: enp0s3-public-tuesday_9582.pcap (1 packet)
#
# Deleted: enp0s3-public-tuesday_9583.pcap (1 packet)
#
# Deleted: enp0s3-public-tuesday_9584.pcap (1 packet)
#
# Deleted: enp0s3-public-tuesday_9585.pcap (1 packet)
#
# Deleted: enp0s3-public-tuesday_9586.pcap (1 packet)
#
# Deleted: enp0s3-public-tuesday_9587.pcap (1 packet)
#
# Deleted: enp0s3-public-tuesday_9588.pcap (1 packet)
#
# Deleted: enp0s3-public-tuesday_9589.pcap (1 packet)
#
# Deleted: enp0s3-public-tuesday_9590.pcap (1 packet)
#
# Deleted: enp0s3-public-tuesday_9591.pcap (1 packet)
#
# Deleted: enp0s3-public-tuesday_9592.pcap (1 packet)
#
# Deleted: enp0s3-public-tuesday_9593.pcap (1 packet)
# Processing PCAP files:  27%|██▋       | 190/705 [00:01<00:02, 235.67it/s]
# Deleted: enp0s3-public-tuesday_9594.pcap (1 packet)
#
# Deleted: enp0s3-public-tuesday_9595.pcap (1 packet)
#
# Deleted: enp0s3-public-tuesday_9596.pcap (1 packet)
#
# Deleted: enp0s3-public-tuesday_9597.pcap (1 packet)
#
# Deleted: enp0s3-public-tuesday_9598.pcap (1 packet)
#
# Deleted: enp0s3-public-tuesday_9599.pcap (1 packet)
#
# Deleted: enp0s3-public-tuesday_9600.pcap (1 packet)
#
# Deleted: enp0s3-public-tuesday_9601.pcap (1 packet)
#
# Deleted: enp0s3-public-tuesday_9602.pcap (1 packet)
#
# Deleted: enp0s3-public-tuesday_9603.pcap (1 packet)
#
# Deleted: enp0s3-public-tuesday_9604.pcap (1 packet)
#
# Deleted: enp0s3-public-tuesday_9605.pcap (1 packet)
#
# Deleted: enp0s3-public-tuesday_9606.pcap (1 packet)
#
# Deleted: enp0s3-public-tuesday_9607.pcap (1 packet)
#
# Deleted: enp0s3-public-tuesday_9608.pcap (1 packet)
#
# Deleted: enp0s3-public-tuesday_9609.pcap (1 packet)
#
# Deleted: enp0s3-public-tuesday_9610.pcap (1 packet)
#
# Deleted: enp0s3-public-tuesday_9611.pcap (1 packet)
#
# Deleted: enp0s3-public-tuesday_9612.pcap (1 packet)
#
# Deleted: enp0s3-public-tuesday_9613.pcap (1 packet)
#
# Deleted: enp0s3-public-tuesday_9614.pcap (1 packet)
#
# Deleted: enp0s3-public-tuesday_9615.pcap (1 packet)
#
# Deleted: enp0s3-public-tuesday_9616.pcap (1 packet)
#
# Deleted: enp0s3-public-tuesday_9617.pcap (1 packet)
#
# Deleted: enp0s3-public-tuesday_9618.pcap (1 packet)
# Processing PCAP files:  30%|███       | 215/705 [00:01<00:02, 234.93it/s]
# Deleted: enp0s3-public-tuesday_9619.pcap (1 packet)
#
# Deleted: enp0s3-public-tuesday_9620.pcap (1 packet)
#
# Deleted: enp0s3-public-tuesday_9621.pcap (1 packet)
#
# Deleted: enp0s3-public-tuesday_9622.pcap (1 packet)
#
# Deleted: enp0s3-public-tuesday_9623.pcap (1 packet)
#
# Deleted: enp0s3-public-tuesday_9624.pcap (1 packet)
#
# Deleted: enp0s3-public-tuesday_9625.pcap (1 packet)
#
# Deleted: enp0s3-public-tuesday_9626.pcap (1 packet)
#
# Deleted: enp0s3-public-tuesday_9627.pcap (1 packet)
#
# Deleted: enp0s3-public-tuesday_9629.pcap (1 packet)
#
# Deleted: enp0s3-public-tuesday_9630.pcap (1 packet)
#
# Deleted: enp0s3-public-tuesday_9631.pcap (1 packet)
#
# Deleted: enp0s3-public-tuesday_9632.pcap (1 packet)
#
# Deleted: enp0s3-public-tuesday_9633.pcap (1 packet)
#
# Deleted: enp0s3-public-tuesday_9637.pcap (1 packet)
#
# Deleted: enp0s3-public-tuesday_9639.pcap (1 packet)
#
# Deleted: enp0s3-public-tuesday_9640.pcap (1 packet)
#
# Deleted: enp0s3-public-tuesday_9641.pcap (1 packet)
#
# Deleted: enp0s3-public-tuesday_9642.pcap (1 packet)
#
# Deleted: enp0s3-public-tuesday_9643.pcap (1 packet)
#
# Deleted: enp0s3-public-tuesday_9644.pcap (1 packet)
#
# Deleted: enp0s3-public-tuesday_9645.pcap (1 packet)
#
# Deleted: enp0s3-public-tuesday_9646.pcap (1 packet)
#
# Deleted: enp0s3-public-tuesday_9647.pcap (1 packet)
#
# Deleted: enp0s3-public-tuesday_9648.pcap (1 packet)
#
# Deleted: enp0s3-public-tuesday_9649.pcap (1 packet)
#
# Deleted: enp0s3-public-tuesday_9650.pcap (1 packet)
#
# Deleted: enp0s3-public-tuesday_9651.pcap (1 packet)
#
# Deleted: enp0s3-public-tuesday_9652.pcap (1 packet)
#
# Deleted: enp0s3-public-tuesday_9653.pcap (1 packet)
# Processing PCAP files:  35%|███▍      | 245/705 [00:01<00:01, 247.08it/s]
# Deleted: enp0s3-public-tuesday_9654.pcap (1 packet)
#
# Deleted: enp0s3-public-tuesday_9655.pcap (1 packet)
#
# Deleted: enp0s3-public-tuesday_9656.pcap (1 packet)
#
# Deleted: enp0s3-public-tuesday_9657.pcap (1 packet)
#
# Deleted: enp0s3-public-tuesday_9658.pcap (1 packet)
#
# Deleted: enp0s3-public-tuesday_9659.pcap (1 packet)
#
# Deleted: enp0s3-public-tuesday_9660.pcap (1 packet)
#
# Deleted: enp0s3-public-tuesday_9661.pcap (1 packet)
#
# Deleted: enp0s3-public-tuesday_9662.pcap (1 packet)
#
# Deleted: enp0s3-public-tuesday_9663.pcap (1 packet)
#
# Deleted: enp0s3-public-tuesday_9664.pcap (1 packet)
#
# Deleted: enp0s3-public-tuesday_9665.pcap (1 packet)
#
# Deleted: enp0s3-public-tuesday_9666.pcap (1 packet)
#
# Deleted: enp0s3-public-tuesday_9667.pcap (1 packet)
#
# Deleted: enp0s3-public-tuesday_9668.pcap (1 packet)
#
# Deleted: enp0s3-public-tuesday_9669.pcap (1 packet)
#
# Deleted: enp0s3-public-tuesday_9672.pcap (1 packet)
#
# Deleted: enp0s3-public-tuesday_9673.pcap (1 packet)
#
# Deleted: enp0s3-public-tuesday_9677.pcap (1 packet)
#
# Deleted: enp0s3-public-tuesday_9784.pcap (1 packet)
#
# Deleted: enp0s3-public-tuesday_9785.pcap (1 packet)
#
# Deleted: enp0s3-public-tuesday_9786.pcap (1 packet)
#
# Deleted: enp0s3-public-tuesday_9788.pcap (1 packet)
#
# Deleted: enp0s3-public-tuesday_9789.pcap (1 packet)
#
# Deleted: enp0s3-public-tuesday_9790.pcap (1 packet)
# Processing PCAP files:  38%|███▊      | 270/705 [00:01<00:01, 231.45it/s]
# Deleted: enp0s3-public-tuesday_9791.pcap (1 packet)
#
# Deleted: enp0s3-public-tuesday_9793.pcap (1 packet)
#
# Deleted: enp0s3-public-tuesday_9795.pcap (1 packet)
#
# Deleted: enp0s3-public-tuesday_9796.pcap (1 packet)
#
# Deleted: enp0s3-public-tuesday_9797.pcap (1 packet)
# Processing PCAP files:  66%|██████▌   | 465/705 [00:02<00:01, 161.97it/s]
# Deleted: enp0s3-pvt-thursday_20999.pcap (1 packet)
# Processing PCAP files:  69%|██████▉   | 486/705 [00:02<00:01, 170.60it/s]
# Deleted: enp0s3-pvt-thursday_21003.pcap (1 packet)
# Processing PCAP files:  82%|████████▏ | 577/705 [00:03<00:00, 174.32it/s]
# Deleted: enp0s3-pvt-thursday_21106.pcap (1 packet)
# Processing PCAP files:  90%|████████▉ | 634/705 [00:03<00:00, 182.93it/s]
# Deleted: enp0s3-pvt-thursday_21187.pcap (1 packet)
#
# Deleted: enp0s3-pvt-thursday_21196.pcap (1 packet)
#
# Deleted: enp0s3-pvt-thursday_21200.pcap (1 packet)
#
# Deleted: enp0s3-pvt-thursday_21205.pcap (1 packet)
#
# Deleted: enp0s3-pvt-thursday_21226.pcap (1 packet)
#
# Deleted: enp0s3-pvt-thursday_21252.pcap (1 packet)
#
# Deleted: enp0s3-pvt-thursday_21293.pcap (1 packet)
#
# Deleted: enp0s3-pvt-thursday_21298.pcap (1 packet)
#
# Deleted: enp0s3-pvt-thursday_21300.pcap (1 packet)
#
# Deleted: enp0s3-pvt-thursday_21362.pcap (1 packet)
#
# Deleted: enp0s3-pvt-thursday_21406.pcap (1 packet)
#
# Deleted: enp0s3-pvt-thursday_21425.pcap (1 packet)
# Processing PCAP files:  93%|█████████▎| 653/705 [00:03<00:00, 158.62it/s]
# Deleted: enp0s3-pvt-thursday_21452.pcap (1 packet)
#
# Deleted: enp0s3-pvt-thursday_21470.pcap (1 packet)
#
# Deleted: enp0s3-pvt-thursday_21488.pcap (1 packet)
#
# Deleted: enp0s3-pvt-thursday_21518.pcap (1 packet)
#
# Deleted: enp0s3-pvt-thursday_21570.pcap (1 packet)
#
# Deleted: enp0s3-pvt-thursday_21601.pcap (1 packet)
#
# Deleted: enp0s3-pvt-thursday_21609.pcap (1 packet)
#
# Deleted: enp0s3-pvt-thursday_21632.pcap (1 packet)
#
# Deleted: enp0s3-pvt-thursday_21663.pcap (1 packet)
#
# Deleted: enp0s3-pvt-thursday_21673.pcap (1 packet)
#
# Deleted: enp0s3-pvt-thursday_21697.pcap (1 packet)
#
# Deleted: enp0s3-pvt-thursday_21739.pcap (1 packet)
#
# Deleted: enp0s3-pvt-thursday_21756.pcap (1 packet)
#
# Deleted: enp0s3-pvt-thursday_21762.pcap (1 packet)
#
# Deleted: enp0s3-pvt-thursday_21780.pcap (1 packet)
#
# Deleted: enp0s3-pvt-thursday_21884.pcap (1 packet)
#
# Deleted: enp0s3-pvt-thursday_21886.pcap (1 packet)
# Processing PCAP files:  95%|█████████▌| 670/705 [00:03<00:00, 161.38it/s]
# Deleted: enp0s3-pvt-thursday_21969.pcap (1 packet)
#
# Deleted: enp0s3-pvt-thursday_21970.pcap (1 packet)
#
# Deleted: enp0s3-pvt-thursday_21973.pcap (1 packet)
#
# Deleted: enp0s3-pvt-thursday_21982.pcap (1 packet)
#
# Deleted: enp0s3-pvt-thursday_22112.pcap (1 packet)
#
# Deleted: enp0s3-pvt-thursday_22167.pcap (1 packet)
#
# Deleted: enp0s3-pvt-thursday_22172.pcap (1 packet)
#
# Deleted: enp0s3-pvt-thursday_22242.pcap (1 packet)
#
# Deleted: enp0s3-pvt-thursday_22285.pcap (1 packet)
#
# Deleted: enp0s3-pvt-thursday_22292.pcap (1 packet)
#
# Deleted: enp0s3-pvt-thursday_22334.pcap (1 packet)
#
# Deleted: enp0s3-pvt-thursday_22343.pcap (1 packet)
#
# Deleted: enp0s3-pvt-thursday_22419.pcap (1 packet)
#
# Deleted: enp0s3-pvt-thursday_22428.pcap (1 packet)
#
# Deleted: enp0s3-pvt-thursday_22429.pcap (1 packet)
# Processing PCAP files:  97%|█████████▋| 687/705 [00:03<00:00, 163.18it/s]
# Deleted: enp0s3-pvt-thursday_22487.pcap (1 packet)
#
# Deleted: enp0s3-pvt-thursday_22491.pcap (1 packet)
#
# Deleted: enp0s3-pvt-thursday_22602.pcap (1 packet)
#
# Deleted: enp0s3-pvt-thursday_22617.pcap (1 packet)
#
# Deleted: enp0s3-pvt-thursday_22649.pcap (1 packet)
#
# Deleted: enp0s3-pvt-thursday_22653.pcap (1 packet)
#
# Deleted: enp0s3-pvt-thursday_22674.pcap (1 packet)
#
# Deleted: enp0s3-pvt-thursday_22710.pcap (1 packet)
#
# Deleted: enp0s3-pvt-thursday_22718.pcap (1 packet)
#
# Deleted: enp0s3-pvt-thursday_22720.pcap (1 packet)
#
# Deleted: enp0s3-pvt-thursday_22733.pcap (1 packet)
#
# Deleted: enp0s3-pvt-thursday_22813.pcap (1 packet)
#
# Deleted: enp0s3-pvt-thursday_22830.pcap (1 packet)
#
# Deleted: enp0s3-pvt-thursday_22841.pcap (1 packet)
#
# Deleted: enp0s3-pvt-thursday_22844.pcap (1 packet)
#
# Deleted: enp0s3-tcpdump-friday_22967.pcap (1 packet)
# Processing PCAP files: 100%|██████████| 705/705 [00:03<00:00, 180.45it/s]
# Cleanup Summary:
# Total PCAP files found: 705
# Files deleted: 239
# Files with errors: 0
# Files skipped: 0
# Files retained: 466

# %% [markdown]
# # Change CSV folder "Stage" feature to 1

# %%
import pandas as pd
from pathlib import Path
import os
from tqdm import tqdm
import logging
from concurrent.futures import ThreadPoolExecutor
from typing import Dict, Any

# Set up logging
logging.basicConfig(
    level=logging.INFO,
    format='%(asctime)s - %(levelname)s - %(message)s',
    handlers=[
        logging.FileHandler('csv_processing.log'),
        logging.StreamHandler()
    ]
)

def process_single_csv(args: tuple) -> Dict[str, Any]:
    """Process a single CSV file and update its labels."""
    input_file, output_dir = args
    
    try:
        # Create output filename
        output_file = os.path.join(
            output_dir,
            f"Adv_{os.path.basename(input_file)}"
        )
        
        # Skip if output file already exists
        if os.path.exists(output_file):
            logging.info(f"Skipping {input_file} - output already exists")
            return {
                'file': input_file,
                'status': 'skipped',
                'rows_processed': 0
            }
        
        # Read CSV file
        df = pd.read_csv(input_file)
        initial_rows = len(df)
        
        # Update Label column
        if 'Label' in df.columns:
            df['Label'] = 1
        else:
            logging.warning(f"'Label' column not found in {input_file}")
            return {
                'file': input_file,
                'status': 'warning',
                'rows_processed': 0,
                'error': 'Label column not found'
            }
        
        # Save modified DataFrame
        df.to_csv(output_file, index=False)
        
        return {
            'file': input_file,
            'status': 'success',
            'rows_processed': initial_rows
        }
        
    except Exception as e:
        logging.error(f"Failed to process {input_file}: {e}")
        return {
            'file': input_file,
            'status': 'failed',
            'error': str(e),
            'rows_processed': 0
        }

def process_csv_directory(
    input_dir: str,
    output_dir: str,
    pattern: str = "*_Flow.csv",
    max_workers: int = None
) -> Dict[str, Any]:
    """Process all CSV files in a directory and update their labels."""
    
    # Create output directory if it doesn't exist
    os.makedirs(output_dir, exist_ok=True)
    
    # Get list of CSV files
    csv_files = list(Path(input_dir).glob(pattern))
    
    if not csv_files:
        logging.warning(f"No CSV files matching pattern '{pattern}' found in {input_dir}")
        return {
            'total_files': 0,
            'successful': 0,
            'failed': 0,
            'skipped': 0,
            'total_rows_processed': 0
        }
    
    # Process files in parallel
    with ThreadPoolExecutor(max_workers=max_workers) as executor:
        args = [(str(f), output_dir) for f in csv_files]
        results = list(tqdm(
            executor.map(process_single_csv, args),
            total=len(args),
            desc="Processing CSV files"
        ))
    
    # Compile statistics
    stats = {
        'total_files': len(csv_files),
        'successful': len([r for r in results if r['status'] == 'success']),
        'failed': len([r for r in results if r['status'] == 'failed']),
        'skipped': len([r for r in results if r['status'] == 'skipped']),
        'warnings': len([r for r in results if r['status'] == 'warning']),
        'total_rows_processed': sum(r['rows_processed'] for r in results)
    }
    
    # Log results
    logging.info("\nProcessing Summary:")
    logging.info(f"Total files processed: {stats['total_files']}")
    logging.info(f"Successfully processed: {stats['successful']}")
    logging.info(f"Failed: {stats['failed']}")
    logging.info(f"Skipped: {stats['skipped']}")
    logging.info(f"Files with warnings: {stats['warnings']}")
    logging.info(f"Total rows processed: {stats['total_rows_processed']}")
    
    # Log failures if any
    failures = [r for r in results if r['status'] in ['failed', 'warning']]
    if failures:
        logging.info("\nFailures and Warnings:")
        for f in failures:
            logging.info(f"File: {f['file']}")
            logging.info(f"Error: {f.get('error', 'Unknown error')}")
            logging.info("---")
    
    return stats

def main():
    # Example usage
    input_dir = "E:\\PFE2025\\Dataset\\Dataset_1\\CSV Flow by Flow Adversarial"
    output_dir = "E:\\PFE2025\\Dataset\\Dataset_1\\CSV Flow by Flow Adversarial"
    
    # Process all CSV files ending with _Flow.csv
    stats = process_csv_directory(
        input_dir=input_dir,
        output_dir=output_dir,
        pattern="*_Flow.csv",  # Pattern to match your CSV files
        max_workers=os.cpu_count()  # Use all available CPU cores
    )
    
    # You can use the stats dictionary for further processing if needed
    if stats['failed'] > 0:
        logging.warning(f"⚠️ {stats['failed']} files failed to process")
    if stats['successful'] > 0:
        logging.info(f"✅ Successfully processed {stats['successful']} files")

if __name__ == "__main__":
    main()

# %% [markdown]
# # Fuse CSV files into one

# %%
import os
import pandas as pd

def merge_csv_files(input_folder, output_file):
    """
    Merges all CSV files in the specified folder into a single CSV file.
    
    :param input_folder: Path to the folder containing CSV files.
    :param output_file: Path to the output merged CSV file.
    """
    csv_files = [f for f in os.listdir(input_folder) if f.endswith('.csv')]
    
    if not csv_files:
        print("No CSV files found in the directory.")
        return
    
    df_list = [pd.read_csv(os.path.join(input_folder, file)) for file in csv_files]
    merged_df = pd.concat(df_list, ignore_index=True)
    
    merged_df.to_csv(output_file, index=False)
    print(f"Merged {len(csv_files)} CSV files into {output_file}")

# Example usage
input_folder = "E:\\PFE2025\\Dataset\\Dataset_1\\CSV Flow by Flow Adversarial"  # Change this to your folder path
output_file = "E:\\PFE2025\\Dataset\\Dataset_1\\Merged_Adversarial_Flow.csv"  # Change this to your desired output file path
merge_csv_files(input_folder, output_file)
# Out:
# Merged 932 CSV files into E:\PFE2025\Dataset\Dataset_1\Merged_Adversarial_Flow.csv
# C:\Users\brahim\AppData\Local\Temp\ipykernel_22560\2444853645.py:18: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   merged_df = pd.concat(df_list, ignore_index=True)

# %%
import os
import pandas as pd
from scapy.all import wrpcap, IP, TCP, UDP, ICMP
from scapy.utils import PcapReader
from tqdm import tqdm
from datetime import datetime
from concurrent.futures import ThreadPoolExecutor
import numpy as np
from typing import Dict, List, Tuple, Optional
from dataclasses import dataclass
from scapy.packet import Packet
import logging

# Set up logging
logging.basicConfig(level=logging.INFO)
logger = logging.getLogger(__name__)


PCAP_DIR = r"E:\DAPT\pcap-data"

@dataclass
class Flow:
    """Data class to store flow information"""
    flow_id: str
    src_ip: str
    dst_ip: str
    src_port: int
    dst_port: int
    protocol: int
    timestamp: float
    duration: float
    fwd_packets: int
    bwd_packets: int
    pcap_file: str

@dataclass
class FlowStats:
    """Data class to track flow packet statistics"""
    fwd_count: int = 0
    bwd_count: int = 0
    packets: List[Packet] = None

    def __post_init__(self):
        self.packets = []

def convert_to_unix(timestamp_str: str) -> float:
    """Convert timestamp string to Unix timestamp."""
    try:
        dt = datetime.strptime(timestamp_str, "%d/%m/%Y %I:%M:%S %p")
        return dt.timestamp()
    except ValueError as e:
        logger.error(f"Invalid timestamp format: {timestamp_str}, Error: {e}")
        return np.nan

def is_packet_match(
    pkt: Packet,
    flow: Flow,
    pkt_time: float
) -> Tuple[bool, Optional[bool]]:
    """
    Check if packet matches flow criteria.
    Returns (is_match, is_forward) tuple, where is_forward is None if no match.
    """
    try:
        if not (IP in pkt and (TCP in pkt or UDP in pkt or ICMP in pkt)):
            return False, None

        # Time check
        if not (flow.timestamp <= pkt_time <= flow.timestamp + flow.duration):
            return False, None

        ip_layer = pkt[IP]
        
        # Protocol check
        if flow.protocol == 6 and TCP not in pkt:
            return False, None
        elif flow.protocol == 17 and UDP not in pkt:
            return False, None
        elif flow.protocol == 1 and ICMP not in pkt:
            return False, None

        # Forward direction check
        is_forward = (
            ip_layer.src == flow.src_ip and 
            ip_layer.dst == flow.dst_ip
        )
        
        # Backward direction check
        is_backward = (
            ip_layer.src == flow.dst_ip and 
            ip_layer.dst == flow.src_ip
        )

        if not (is_forward or is_backward):
            return False, None

        # Port check for TCP/UDP
        if flow.protocol in (6, 17):
            transport_layer = pkt[TCP] if TCP in pkt else pkt[UDP]
            if is_forward and (transport_layer.sport != flow.src_port or 
                             transport_layer.dport != flow.dst_port):
                return False, None
            elif is_backward and (transport_layer.sport != flow.dst_port or 
                                transport_layer.dport != flow.src_port):
                return False, None

        return True, is_forward

    except Exception as e:
        logger.error(f"Error matching packet: {e}")
        return False, None

def process_pcap_file(args: Tuple[str, List[Flow], str, str]) -> Dict[str, FlowStats]:
    """Process a single PCAP file and extract matching flow packets."""
    pcap_filename, flows, pcap_directory, extracted_directory = args
    pcap_path = os.path.join(pcap_directory, pcap_filename)
    
    if not os.path.exists(pcap_path):
        logger.error(f"PCAP file not found: {pcap_path}")
        return {}

    # Initialize flow statistics
    flow_stats: Dict[str, FlowStats] = {
        flow.flow_id: FlowStats() for flow in flows
    }

    try:
        with PcapReader(pcap_path) as pcap_reader:
            for pkt in pcap_reader:
                pkt_time = float(pkt.time)
                
                # Check packet against each flow
                for flow in flows:
                    is_match, is_forward = is_packet_match(pkt, flow, pkt_time)
                    
                    if is_match:
                        stats = flow_stats[flow.flow_id]
                        if is_forward:
                            stats.fwd_count += 1
                        else:
                            stats.bwd_count += 1
                        stats.packets.append(pkt)

    except Exception as e:
        logger.error(f"Error reading packets from {pcap_path}: {e}")
        return flow_stats

    # Save extracted packets
    for flow in flows:
        stats = flow_stats[flow.flow_id]
        if stats.packets:
            output_path = os.path.join(
                extracted_directory,
                f"flow_{flow.flow_id}_{int(flow.timestamp)}.pcap"
            )
            os.makedirs(os.path.dirname(output_path), exist_ok=True)
            
            try:
                wrpcap(output_path, stats.packets)
                logger.info(
                    f"Saved {len(stats.packets)} packets for flow {flow.flow_id}"
                    f" (Fwd: {stats.fwd_count}, Bwd: {stats.bwd_count})"
                )
            except Exception as e:
                logger.error(f"Error saving packets for flow {flow.flow_id}: {e}")

    return flow_stats

def main():
    # Configuration
    csv_file = "E:\\Dataset\\Dataset_1\\combined_output.csv"
    pcap_directory = "E:\\DAPT\\pcap-data\\"
    extracted_directory = "E:\\Dataset\\Dataset_1\\extracted\\"

    # Read CSV file with optimized dtypes
    dtype_dict = {
        'Flow ID': str,
        'Src IP': str,
        'Dst IP': str,
        'Src Port': np.int32,
        'Dst Port': np.int32,
        'Protocol': np.int8,
        'Flow Duration': np.float64,
        'Total Fwd Packet': np.int32,
        'Total Bwd packets': np.int32,
        'source_file': 'category'
    }

    try:
        df = pd.read_csv(csv_file, dtype=dtype_dict)
        logger.info(f"Loaded {len(df)} flows from CSV")

        # Convert timestamps and durations
        df['Timestamp'] = df['Timestamp'].apply(convert_to_unix)
        df['Flow Duration'] = df['Flow Duration'] / 1e6  # Convert to seconds
        df = df.dropna(subset=['Timestamp', 'Flow Duration'])

        # Create Flow objects
        flows_by_pcap: Dict[str, List[Flow]] = {}
        for _, row in df.iterrows():
            pcap_file = row['source_file'].replace('_Flow.csv', '')
            flow = Flow(
                flow_id=row['Flow ID'],
                src_ip=row['Src IP'],
                dst_ip=row['Dst IP'],
                src_port=row['Src Port'],
                dst_port=row['Dst Port'],
                protocol=row['Protocol'],
                timestamp=row['Timestamp'],
                duration=row['Flow Duration'],
                fwd_packets=row['Total Fwd Packet'],
                bwd_packets=row['Total Bwd packets'],
                pcap_file=pcap_file
            )
            flows_by_pcap.setdefault(pcap_file, []).append(flow)

        # Process PCAP files in parallel
        with ThreadPoolExecutor(max_workers=os.cpu_count()) as executor:
            args = [
                (pcap_file, flows, pcap_directory, extracted_directory)
                for pcap_file, flows in flows_by_pcap.items()
            ]
            
            results = list(tqdm(
                executor.map(process_pcap_file, args),
                total=len(args),
                desc="Processing PCAP files"
            ))

        # Print summary
        total_flows = 0
        total_packets = 0
        for flow_stats in results:
            for flow_id, stats in flow_stats.items():
                if stats.packets:
                    total_flows += 1
                    total_packets += len(stats.packets)

        logger.info(f"\nExtraction complete:")
        logger.info(f"Total flows processed: {total_flows}")
        logger.info(f"Total packets extracted: {total_packets}")

    except Exception as e:
        logger.error(f"Error in main processing: {e}")

if __name__ == "__main__":
    main()
# Out:
# INFO:__main__:Loaded 22979 flows from CSV
# Processing PCAP files:   0%|          | 0/7 [00:00<?, ?it/s]

# %%
import pandas as pd
from scapy.all import PcapReader, wrpcap
from scapy.layers.inet import IP, TCP, UDP
from datetime import datetime
import os

def parse_timestamp(timestamp_str):
    """Convert timestamp string to UNIX timestamp (seconds since epoch)."""
    dt = datetime.strptime(timestamp_str, "%d/%m/%Y %I:%M:%S %p")
    return dt.timestamp()  # Convert to UNIX timestamp (float)

def packet_matches_flow(packet, flow_info):
    """
    Check if a packet matches all flow constraints:
    - Protocol
    - Source/Destination IPs
    - Source/Destination Ports
    """
    if not (IP in packet and (TCP in packet or UDP in packet)):
        return False
    
    # Get packet protocol
    if TCP in packet:
        packet_proto = '6'  # TCP
    elif UDP in packet:
        packet_proto = '17'  # UDP
    else:
        return False
    
    # Basic protocol check
    if str(packet_proto) != str(flow_info['Protocol']):
        return False
    
    # Check IP addresses (in both directions)
    ip_match = (
        (packet[IP].src == flow_info['Src IP'] and packet[IP].dst == flow_info['Dst IP']) or
        (packet[IP].src == flow_info['Dst IP'] and packet[IP].dst == flow_info['Src IP'])
    )
    
    if not ip_match:
        return False
    
    # Check ports based on protocol
    if TCP in packet:
        port_match = (
            (packet[TCP].sport == int(flow_info['Src Port']) and 
             packet[TCP].dport == int(flow_info['Dst Port'])) or
            (packet[TCP].sport == int(flow_info['Dst Port']) and 
             packet[TCP].dport == int(flow_info['Src Port']))
        )
    elif UDP in packet:
        port_match = (
            (packet[UDP].sport == int(flow_info['Src Port']) and 
             packet[UDP].dport == int(flow_info['Dst Port'])) or
            (packet[UDP].sport == int(flow_info['Dst Port']) and 
             packet[UDP].dport == int(flow_info['Src Port']))
        )
    else:
        port_match = False
    
    return port_match

def analyze_flow(flow_row, pcap_base_dir):
    """
    Analyze a single flow:
    1. Extract time window information
    2. Read corresponding PCAP file
    3. Match packets based on time and constraints
    """
    flow_id = flow_row['Flow ID']
    print(f"\nProcessing flow: {flow_id}")
    
    # Convert timestamp and duration to UNIX timestamp format
    flow_start = parse_timestamp(flow_row['Timestamp'])  # In seconds (float)
    flow_duration = float(flow_row['Flow Duration']) / 1_000_000  # Convert microseconds to seconds
    flow_end = flow_start + flow_duration  # End time in UNIX timestamp
    
    print(f"Time window: {flow_start} to {flow_end} (UNIX timestamp)")
    
    # Get PCAP filename from the last column
    pcap_filename = flow_row.iloc[-1]
    pcap_path = os.path.join(pcap_base_dir, pcap_filename.replace('_Flow.csv', ''))
    
    if not os.path.exists(pcap_path):
        print(f"Warning: PCAP file not found: {pcap_path}")
        return []
    
    matching_packets = []
    forward_packets = 0
    backward_packets = 0
    
    try:
        print(f"Reading PCAP file: {pcap_path}")
        with PcapReader(pcap_path) as pcap_reader:
            for packet in pcap_reader:
                packet_time = float(packet.time)  # Already in UNIX timestamp format
                
                # First check time window
                if flow_start <= packet_time <= flow_end:
                    # Then check other constraints
                    if packet_matches_flow(packet, flow_row):
                        matching_packets.append(packet)
                        
                        # Count forward/backward packets
                        if IP in packet and packet[IP].src == flow_row['Src IP']:
                            forward_packets += 1
                        else:
                            backward_packets += 1
        
        # Write matching packets to output file
        if matching_packets:
            output_file = f"matched_{flow_id}.pcap"
            wrpcap(output_file, matching_packets)
            print(f"Created {output_file} with {len(matching_packets)} packets")
            
            # Validate packet counts
            print("\nPacket count validation:")
            print(f"Forward packets found: {forward_packets} (Expected: {flow_row['Total Fwd Packet']})")
            print(f"Backward packets found: {backward_packets} (Expected: {flow_row['Total Bwd packets']})")
            
            if forward_packets != int(flow_row['Total Fwd Packet']) or \
               backward_packets != int(flow_row['Total Bwd packets']):
                print("Warning: Packet count mismatch!")
        else:
            print("No matching packets found for this flow")
            
    except Exception as e:
        print(f"Error processing PCAP file: {str(e)}")
    
    return matching_packets

def main(csv_file, pcap_base_dir):
    """Main function to process all flows."""
    print(f"Reading flows from {csv_file}")
    df = pd.read_csv(csv_file)
    
    all_matching_packets = {}
    
    for _, flow in df.iterrows():
        matching_packets = analyze_flow(flow, pcap_base_dir)
        all_matching_packets[flow['Flow ID']] = matching_packets
    
    # Print summary
    print("\nProcessing complete!")
    print(f"Processed {len(df)} flows")
    print(f"Created {len([v for v in all_matching_packets.values() if v])} output PCAP files")
    
    return all_matching_packets

if __name__ == "__main__":
    # Example usage
    csv_file ="E:\\PFE2025\\Dataset\\Dataset_1\\combined_output.csv"
    pcap_base_dir = "E:\\DAPT\\pcap-data"
    matching_packets = main(csv_file, pcap_base_dir)
# Out:
# Reading flows from E:\PFE2025\Dataset\Dataset_1\combined_output.csv
#
# Processing flow: 192.168.3.29-209.147.138.38-9000-56646-6
# Time window: 1563456127.0 to 1563456133.878549 (UNIX timestamp)
# Reading PCAP file: E:\DAPT\pcap-data\enp0s3-public-thursday.pcap
# No matching packets found for this flow
#
# Processing flow: 192.168.3.29-209.147.138.38-9000-56646-6
# Time window: 1563456134.0 to 1563456134.000017 (UNIX timestamp)
# Reading PCAP file: E:\DAPT\pcap-data\enp0s3-public-thursday.pcap
# No matching packets found for this flow
#
# Processing flow: 192.168.3.29-209.147.138.38-9000-56656-6
# Time window: 1563456129.0 to 1563456134.044341 (UNIX timestamp)
# Reading PCAP file: E:\DAPT\pcap-data\enp0s3-public-thursday.pcap
# No matching packets found for this flow
#
# Processing flow: 192.168.3.29-209.147.138.38-9000-56653-6
# Time window: 1563456129.0 to 1563456134.049017 (UNIX timestamp)
# Reading PCAP file: E:\DAPT\pcap-data\enp0s3-public-thursday.pcap
# No matching packets found for this flow
#
# Processing flow: 192.168.3.29-209.147.138.38-9000-56654-6
# Time window: 1563456129.0 to 1563456134.045668 (UNIX timestamp)
# Reading PCAP file: E:\DAPT\pcap-data\enp0s3-public-thursday.pcap
# No matching packets found for this flow
#
# Processing flow: 192.168.3.29-209.147.138.38-9000-56656-6
# Time window: 1563456134.0 to 1563456134.000107 (UNIX timestamp)
# Reading PCAP file: E:\DAPT\pcap-data\enp0s3-public-thursday.pcap
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 154
#     152 csv_file ="E:\\PFE2025\\Dataset\\Dataset_1\\combined_output.csv"
#     153 pcap_base_dir = "E:\\DAPT\\pcap-data"
# --> 154 matching_packets = main(csv_file, pcap_base_dir)
#
# Cell In[1], line 140, in main(csv_file, pcap_base_dir)
#     137 all_matching_packets = {}
#     139 for _, flow in df.iterrows():
# --> 140     matching_packets = analyze_flow(flow, pcap_base_dir)
#     141     all_matching_packets[flow['Flow ID']] = matching_packets
#     143 # Print summary
#
# Cell In[1], line 95, in analyze_flow(flow_row, pcap_base_dir)
#      93 print(f"Reading PCAP file: {pcap_path}")
#      94 with PcapReader(pcap_path) as pcap_reader:
# ---> 95     for packet in pcap_reader:
#      96         packet_time = float(packet.time)  # Already in UNIX timestamp format
#      98         # First check time window
#
# File e:\PFE2025\venv\lib\site-packages\scapy\utils.py:1628, in PcapReader.__next__(self)
#    1625 def __next__(self):  # type: ignore
#    1626     # type: () -> Packet
#    1627     try:
# -> 1628         return self.read_packet()
#    1629     except EOFError:
#    1630         raise StopIteration
#
# File e:\PFE2025\venv\lib\site-packages\scapy\utils.py:1604, in PcapReader.read_packet(self, size, **kwargs)
#    1601 s, pkt_info = rp
#    1603 try:
# -> 1604     p = self.LLcls(s, **kwargs)  # type: Packet
#    1605 except KeyboardInterrupt:
#    1606     raise
#
# File e:\PFE2025\venv\lib\site-packages\scapy\base_classes.py:481, in Packet_metaclass.__call__(cls, *args, **kargs)
#     474         cls = config.conf.raw_layer
#     475 i = cls.__new__(
#     476     cls,  # type: ignore
#     477     cls.__name__,
#     478     cls.__bases__,
#     479     cls.__dict__  # type: ignore
#     480 )
# --> 481 i.__init__(*args, **kargs)
#     482 return i
#
# File e:\PFE2025\venv\lib\site-packages\scapy\packet.py:186, in Packet.__init__(self, _pkt, post_transform, _internal, _underlayer, _parent, stop_dissection_after, **fields)
#     184 self.stop_dissection_after = stop_dissection_after
#     185 if _pkt:
# --> 186     self.dissect(_pkt)
#     187     if not _internal:
#     188         self.dissection_done(self)
#
# File e:\PFE2025\venv\lib\site-packages\scapy\packet.py:1089, in Packet.dissect(self, s)
#    1086 s = self.post_dissect(s)
#    1088 payl, pad = self.extract_padding(s)
# -> 1089 self.do_dissect_payload(payl)
#    1090 if pad and conf.padding:
#    1091     self.add_payload(conf.padding_layer(pad))
#
# File e:\PFE2025\venv\lib\site-packages\scapy\packet.py:1059, in Packet.do_dissect_payload(self, s)
#    1057 cls = self.guess_payload_class(s)
#    1058 try:
# -> 1059     p = cls(
#    1060         s,
#    1061         stop_dissection_after=self.stop_dissection_after,
#    1062         _internal=1,
#    1063         _underlayer=self,
#    1064     )
#    1065 except KeyboardInterrupt:
#    1066     raise
#
# File e:\PFE2025\venv\lib\site-packages\scapy\base_classes.py:481, in Packet_metaclass.__call__(cls, *args, **kargs)
#     474         cls = config.conf.raw_layer
#     475 i = cls.__new__(
#     476     cls,  # type: ignore
#     477     cls.__name__,
#     478     cls.__bases__,
#     479     cls.__dict__  # type: ignore
#     480 )
# --> 481 i.__init__(*args, **kargs)
#     482 return i
#
# File e:\PFE2025\venv\lib\site-packages\scapy\packet.py:186, in Packet.__init__(self, _pkt, post_transform, _internal, _underlayer, _parent, stop_dissection_after, **fields)
#     184 self.stop_dissection_after = stop_dissection_after
#     185 if _pkt:
# --> 186     self.dissect(_pkt)
#     187     if not _internal:
#     188         self.dissection_done(self)
#
# File e:\PFE2025\venv\lib\site-packages\scapy\packet.py:1084, in Packet.dissect(self, s)
#    1080 def dissect(self, s):
#    1081     # type: (bytes) -> None
#    1082     s = self.pre_dissect(s)
# -> 1084     s = self.do_dissect(s)
#    1086     s = self.post_dissect(s)
#    1088     payl, pad = self.extract_padding(s)
#
# File e:\PFE2025\venv\lib\site-packages\scapy\packet.py:1022, in Packet.do_dissect(self, s)
#    1020 self.raw_packet_cache_fields = {}
#    1021 for f in self.fields_desc:
# -> 1022     s, fval = f.getfield(self, s)
#    1023     # Skip unused ConditionalField
#    1024     if isinstance(f, ConditionalField) and fval is None:
#
# File e:\PFE2025\venv\lib\site-packages\scapy\fields.py:566, in MultipleTypeField.getfield(self, pkt, s)
#     561 def getfield(self,
#     562              pkt,  # type: Packet
#     563              s,  # type: bytes
#     564              ):
#     565     # type: (...) -> Tuple[bytes, Any]
# --> 566     return self._find_fld_pkt(pkt).getfield(pkt, s)
#
# File e:\PFE2025\venv\lib\site-packages\scapy\fields.py:515, in MultipleTypeField._find_fld_pkt(self, pkt)
#     508     def _find_fld_pkt(self, pkt):
#     509         # type: (Optional[Packet]) -> Field[Any, Any]
#     510         """Given a Packet instance `pkt`, returns the Field subclass to be
#     511 used. If you know the value to be set (e.g., in .addfield()), use
#     512 ._find_fld_pkt_val() instead.
#     513
#     514         """
# --> 515         return self._iterate_fields_cond(pkt, None, False)
#
# File e:\PFE2025\venv\lib\site-packages\scapy\fields.py:504, in MultipleTypeField._iterate_fields_cond(self, pkt, val, use_val)
#     502         else:
#     503             cond = cond[0]
# --> 504     if cond(pkt):
#     505         return fld
#     506 return self.dflt
#
# File e:\PFE2025\venv\lib\site-packages\scapy\layers\l2.py:488, in ARP.<lambda>(pkt)
#     467 class ARP(Packet):
#     468     name = "ARP"
#     469     fields_desc = [
#     470         XShortEnumField("hwtype", 0x0001, HARDWARE_TYPES),
#     471         XShortEnumField("ptype", 0x0800, ETHER_TYPES),
#     472         FieldLenField("hwlen", None, fmt="B", length_of="hwsrc"),
#     473         FieldLenField("plen", None, fmt="B", length_of="psrc"),
#     474         ShortEnumField("op", 1, {
#     475             "who-has": 1,
#     476             "is-at": 2,
#     477             "RARP-req": 3,
#     478             "RARP-rep": 4,
#     479             "Dyn-RARP-req": 5,
#     480             "Dyn-RAR-rep": 6,
#     481             "Dyn-RARP-err": 7,
#     482             "InARP-req": 8,
#     483             "InARP-rep": 9
#     484         }),
#     485         MultipleTypeField(
#     486             [
#     487                 (SourceMACField("hwsrc"),
# --> 488                  (lambda pkt: pkt.hwtype == 1 and pkt.hwlen == 6,
#     489                   lambda pkt, val: pkt.hwtype == 1 and (
#     490                       pkt.hwlen == 6 or (pkt.hwlen is None and
#     491                                          (val is None or len(val) == 6 or
#     492                                           valid_mac(val)))
#     493                   ))),
#     494             ],
#     495             StrFixedLenField("hwsrc", None, length_from=lambda pkt: pkt.hwlen),
#     496         ),
#     497         MultipleTypeField(
#     498             [
#     499                 (SourceIPField("psrc"),
#     500                  (lambda pkt: pkt.ptype == 0x0800 and pkt.plen == 4,
#     501                   lambda pkt, val: pkt.ptype == 0x0800 and (
#     502                       pkt.plen == 4 or (pkt.plen is None and
#     503                                         (val is None or valid_net(val)))
#     504                   ))),
#     505                 (SourceIP6Field("psrc"),
#     506                  (lambda pkt: pkt.ptype == 0x86dd and pkt.plen == 16,
#     507                   lambda pkt, val: pkt.ptype == 0x86dd and (
#     508                       pkt.plen == 16 or (pkt.plen is None and
#     509                                          (val is None or valid_net6(val)))
#     510                   ))),
#     511             ],
#     512             StrFixedLenField("psrc", None, length_from=lambda pkt: pkt.plen),
#     513         ),
#     514         MultipleTypeField(
#     515             [
#     516                 (MACField("hwdst", ETHER_ANY),
#     517                  (lambda pkt: pkt.hwtype == 1 and pkt.hwlen == 6,
#     518                   lambda pkt, val: pkt.hwtype == 1 and (
#     519                       pkt.hwlen == 6 or (pkt.hwlen is None and
#     520                                          (val is None or len(val) == 6 or
#     521                                           valid_mac(val)))
#     522                   ))),
#     523             ],
#     524             StrFixedLenField("hwdst", None, length_from=lambda pkt: pkt.hwlen),
#     525         ),
#     526         MultipleTypeField(
#     527             [
#     528                 (IPField("pdst", "0.0.0.0"),
#     529                  (lambda pkt: pkt.ptype == 0x0800 and pkt.plen == 4,
#     530                   lambda pkt, val: pkt.ptype == 0x0800 and (
#     531                       pkt.plen == 4 or (pkt.plen is None and
#     532                                         (val is None or valid_net(val)))
#     533                   ))),
#     534                 (IP6Field("pdst", "::"),
#     535                  (lambda pkt: pkt.ptype == 0x86dd and pkt.plen == 16,
#     536                   lambda pkt, val: pkt.ptype == 0x86dd and (
#     537                       pkt.plen == 16 or (pkt.plen is None and
#     538                                          (val is None or valid_net6(val)))
#     539                   ))),
#     540             ],
#     541             StrFixedLenField("pdst", None, length_from=lambda pkt: pkt.plen),
#     542         ),
#     543     ]
#     545     def hashret(self):
#     546         # type: () -> bytes
#     547         return struct.pack(">HHH", self.hwtype, self.ptype,
#     548                            ((self.op + 1) // 2)) + self.payload.hashret()
#
# File e:\PFE2025\venv\lib\site-packages\scapy\packet.py:480, in Packet.__getattr__(self, attr)
#     477 def __getattr__(self, attr):
#     478     # type: (str) -> Any
#     479     try:
# --> 480         fld, v = self.getfield_and_val(attr)
#     481     except ValueError:
#     482         return self.payload.__getattr__(attr)
#
# File e:\PFE2025\venv\lib\site-packages\scapy\packet.py:467, in Packet.getfield_and_val(self, attr)
#     465 def getfield_and_val(self, attr):
#     466     # type: (str) -> Tuple[AnyField, Any]
# --> 467     if self.deprecated_fields and attr in self.deprecated_fields:
#     468         attr = self._resolve_alias(attr)
#     469     if attr in self.fields:
#
# KeyboardInterrupt:

# %%
import csv
from datetime import datetime, timedelta
import os
from scapy.all import *
from scapy.utils import PcapWriter
from tqdm import tqdm

PCAP_DIR = "E:\\DAPT\\pcap-data\\"

def sanitize_filename(name):
    # Remove "_Flow.csv" from the end of the filename if it exists
    return "".join(c if c.isalnum() or c in ('_', '-') else '_' for c in name)

def process_flow(row, output_dir):
    try:
        # Extract relevant fields from CSV row
        flow_id = row[0]
        src_ip = row[1]
        src_port = int(row[2])
        dst_ip = row[3]
        dst_port = int(row[4])
        protocol = int(row[5])
        timestamp_str = row[6]
        flow_duration = float(row[7])  # in microseconds
        pcap_file = row[-1]
        pcap_file = pcap_file[:-9]
        pcap_file = os.path.join(PCAP_DIR, pcap_file)

        # Parse timestamp and adjust for 1-hour shift
        datetime_obj = datetime.strptime(timestamp_str, "%d/%m/%Y %I:%M:%S %p")
        # Add one hour to compensate for PCAP being 1 hour behind
        datetime_obj = datetime_obj - timedelta(hours=1)
        start_time = datetime_obj.timestamp()
        
        # Convert flow duration to seconds
        duration_seconds = flow_duration / 1000000.0  # Convert microseconds to seconds
        end_time = start_time + duration_seconds

        # Check if we need to validate ports
        check_ports = protocol in (6, 17)  # TCP or UDP

        # Read pcap file
        if not os.path.exists(pcap_file):
            print(f"PCAP file not found: {pcap_file}")
            return None

        matching_packets = []
        with PcapReader(pcap_file) as pcap_reader:
            for pkt in tqdm(pcap_reader, desc=f"Processing packets", leave=False):
                try:
                    # Check timestamp first for efficiency
                    pkt_time = pkt.time
                    # Now the PCAP timestamp should align with our adjusted CSV timestamp
                    if not (start_time <= pkt_time <= end_time):
                        continue

                    # Check IP layer
                    if not pkt.haslayer(IP):
                        continue
                    ip = pkt[IP]

                    # Check protocol
                    if ip.proto != protocol:
                        continue

                    # Check IP addresses (both directions)
                    if not ((ip.src == src_ip and ip.dst == dst_ip) or 
                            (ip.src == dst_ip and ip.dst == src_ip)):
                        continue

                    # Check ports if applicable
                    if check_ports:
                        if protocol == 6 and pkt.haslayer(TCP):
                            tcp = pkt[TCP]
                            sport = tcp.sport
                            dport = tcp.dport
                        elif protocol == 17 and pkt.haslayer(UDP):
                            udp = pkt[UDP]
                            sport = udp.sport
                            dport = udp.dport
                        else:
                            continue  # Protocol mismatch

                        # Check ports (both directions)
                        if not ((sport == src_port and dport == dst_port) or 
                                (sport == dst_port and dport == src_port)):
                            continue

                    matching_packets.append(pkt)
                except Exception as e:
                    continue

        # Create output directory if needed
        os.makedirs(output_dir, exist_ok=True)

        # Write matching packets to new pcap
        if matching_packets:
            sanitized_id = sanitize_filename(flow_id)
            output_file = os.path.join(output_dir, f"flow_{sanitized_id}.pcap")
            wrpcap(output_file, matching_packets)
            return output_file
        return None

    except Exception as e:
        print(f"Error processing flow {flow_id}: {str(e)}")
        return None

def main(csv_path, output_dir="output_pcaps"):
    results = []
    with open(csv_path, 'r') as f:
        reader = csv.reader(f)
        headers = next(reader)
        total_rows = sum(1 for _ in reader)
        f.seek(0)
        next(reader)  # Skip header again

        for row in tqdm(reader, total=total_rows, desc="Processing flows"):
            result = process_flow(row, output_dir)
            if result:
                results.append(result)

    print("\nProcessing complete. Generated PCAP files:")
    for res in results:
        print(f"- {res}")

if __name__ == "__main__":

    csv_path = "E:\\PFE2025\\Dataset\\Dataset_1\\combined_output.csv"
    
    main(csv_path)
# Out:
# Processing flows:   0%|          | 0/39215 [00:00<?, ?it/s]
# Processing packets: 0it [00:00, ?it/s]
# Processing packets: 546it [00:00, 5278.70it/s]
# Processing packets: 1167it [00:00, 5742.22it/s]
# Processing packets: 1906it [00:00, 6462.84it/s]
# Processing packets: 2554it [00:00, 6457.23it/s]
# Processing packets: 3201it [00:00, 6279.36it/s]
# Processing packets: 3917it [00:00, 6488.63it/s]
# Processing packets: 4567it [00:00, 6395.27it/s]
# Processing packets: 5304it [00:00, 6521.26it/s]
# Processing packets: 5957it [00:00, 6387.93it/s]
# Processing packets: 6687it [00:01, 6415.50it/s]
# Processing packets: 7436it [00:01, 6721.75it/s]
# Processing packets: 8110it [00:01, 6403.70it/s]
# Processing packets: 8783it [00:01, 6296.44it/s]
# Processing packets: 9449it [00:01, 6352.02it/s]
# Processing packets: 10087it [00:01, 6316.45it/s]
# Processing packets: 10843it [00:01, 6420.36it/s]
# Processing packets: 11486it [00:01, 6375.39it/s]
# Processing packets: 12124it [00:01, 6371.71it/s]
# Processing packets: 12792it [00:02, 6458.97it/s]
# Processing packets: 13439it [00:02, 6158.16it/s]
# Processing packets: 14162it [00:02, 6268.24it/s]
# Processing packets: 14791it [00:02, 6228.96it/s]
# Processing packets: 15415it [00:02, 6179.62it/s]
# Processing packets: 16231it [00:02, 6509.81it/s]
# Processing packets: 16881it [00:02, 6446.15it/s]
# Processing packets: 17726it [00:02, 7021.14it/s]
# Processing packets: 18538it [00:02, 7340.18it/s]
# Processing packets: 19275it [00:02, 7346.73it/s]
# Processing packets: 20105it [00:03, 7356.80it/s]
# Processing packets: 20846it [00:03, 7317.93it/s]
# Processing packets: 21579it [00:03, 7000.12it/s]
# Processing packets: 22282it [00:03, 6967.19it/s]
# Processing packets: 22981it [00:03, 6963.32it/s]
# Processing packets: 23679it [00:03, 6478.10it/s]
# Processing packets: 24391it [00:03, 6636.04it/s]
# Processing packets: 25061it [00:03, 6579.83it/s]
# Processing packets: 25723it [00:03, 6448.12it/s]
# Processing packets: 26528it [00:04, 6738.10it/s]
# Processing packets: 27204it [00:04, 6467.19it/s]
# Processing packets: 27855it [00:04, 6469.75it/s]
# Processing packets: 28512it [00:04, 6456.10it/s]
# Processing packets: 29159it [00:04, 6156.00it/s]
# Processing packets: 29949it [00:04, 6432.29it/s]
# Processing packets: 30594it [00:04, 5989.64it/s]
# Processing packets: 31199it [00:04, 5946.42it/s]
# Processing packets: 31826it [00:04, 6033.37it/s]
# Processing packets: 32433it [00:05, 5835.07it/s]
# Processing packets: 33073it [00:05, 5879.96it/s]
# Processing packets: 33764it [00:05, 6105.88it/s]
# Processing packets: 34377it [00:05, 5953.36it/s]
# Processing packets: 35029it [00:05, 6103.66it/s]
# Processing packets: 35672it [00:05, 6105.84it/s]
# Processing packets: 36284it [00:05, 6042.28it/s]
# Processing packets: 37066it [00:05, 6348.39it/s]
# Processing packets: 37701it [00:05, 6289.46it/s]
# Processing packets: 38330it [00:05, 6141.93it/s]
# Processing packets: 38988it [00:06, 6265.00it/s]
# Processing packets: 39615it [00:06, 6120.64it/s]
# Processing packets: 40261it [00:06, 6215.35it/s]
# Processing packets: 40966it [00:06, 6450.39it/s]
# Processing packets: 41627it [00:06, 6475.79it/s]
# Processing packets: 42303it [00:06, 6537.64it/s]
# Processing packets: 43031it [00:06, 6595.20it/s]
# Processing packets: 43691it [00:06, 6492.36it/s]
# Processing packets: 44479it [00:06, 6604.38it/s]
# Processing packets: 45156it [00:07, 6647.78it/s]
# Processing packets: 45836it [00:07, 6679.55it/s]
# Processing packets: 46504it [00:07, 6673.68it/s]
# Processing packets: 47180it [00:07, 6697.86it/s]
# Processing packets: 47878it [00:07, 6634.12it/s]
# Processing packets: 48572it [00:07, 6617.98it/s]
# Processing packets: 49259it [00:07, 6627.34it/s]
# Processing packets: 49922it [00:07, 6596.03it/s]
# Processing packets: 50640it [00:07, 6557.94it/s]
# Processing packets: 51322it [00:07, 6626.38it/s]
# Processing packets: 51986it [00:08, 6248.17it/s]
# Processing packets: 52615it [00:08, 6218.24it/s]
# Processing packets: 53287it [00:08, 6345.19it/s]
# Processing packets: 53924it [00:08, 6030.89it/s]
# Processing packets: 54604it [00:08, 6170.41it/s]
# Processing packets: 55225it [00:08, 5842.03it/s]
# Processing packets: 55815it [00:08, 5810.99it/s]
# Processing packets: 56567it [00:08, 6033.50it/s]
# Processing packets: 57286it [00:08, 6343.18it/s]
# Processing packets: 57981it [00:09, 6513.76it/s]
# Processing packets: 58636it [00:09, 6222.61it/s]
# Processing packets: 59263it [00:09, 6139.36it/s]
# Processing packets: 59921it [00:09, 6181.61it/s]
# Processing packets: 60542it [00:09, 6074.08it/s]
# Processing packets: 61151it [00:09, 6076.77it/s]
# Processing packets: 61850it [00:09, 6178.93it/s]
# Processing packets: 62469it [00:09, 6055.43it/s]
# Processing packets: 63170it [00:09, 6327.78it/s]
# Processing packets: 63938it [00:09, 6686.63it/s]
# Processing packets: 64682it [00:10, 6889.20it/s]
# Processing packets: 65457it [00:10, 7122.19it/s]
# Processing packets: 66290it [00:10, 7317.53it/s]
# Processing packets: 67023it [00:10, 7255.19it/s]
# Processing packets: 67749it [00:10, 7106.78it/s]
# Processing packets: 68461it [00:10, 7091.13it/s]
# Processing packets: 69171it [00:10, 7002.60it/s]
# Processing packets: 69872it [00:10, 6564.91it/s]
# Processing packets: 70534it [00:10, 6567.90it/s]
# Processing packets: 71195it [00:11, 6091.31it/s]
# Processing packets: 71873it [00:11, 6265.89it/s]
# Processing packets: 72519it [00:11, 6290.74it/s]
# Processing packets: 73154it [00:11, 6298.83it/s]
# Processing packets: 73788it [00:11, 5901.42it/s]
# Processing packets: 74386it [00:11, 5918.14it/s]
# Processing packets: 74998it [00:11, 5914.04it/s]
# Processing packets: 75659it [00:11, 6006.47it/s]
# Processing packets: 76295it [00:11, 6078.20it/s]
# Processing packets: 76972it [00:12, 6205.21it/s]
# Processing packets: 77594it [00:12, 5871.33it/s]
# Processing packets: 78250it [00:12, 6021.64it/s]
# Processing packets: 78897it [00:12, 6127.28it/s]
# Processing packets: 79513it [00:12, 5605.45it/s]
# Processing packets: 80152it [00:12, 5799.98it/s]
# Processing packets: 80741it [00:12, 5824.74it/s]
# Processing packets: 81330it [00:12, 5683.44it/s]
# Processing packets: 82015it [00:12, 5991.10it/s]
# Processing packets: 82645it [00:12, 6033.99it/s]
# Processing packets: 83252it [00:13, 5842.47it/s]
# Processing packets: 83931it [00:13, 6092.06it/s]
# Processing packets: 84557it [00:13, 6066.41it/s]
# Processing packets: 85166it [00:13, 5884.56it/s]
# Processing packets: 85907it [00:13, 6240.99it/s]
# Processing packets: 86683it [00:13, 6600.66it/s]
# Processing packets: 87450it [00:13, 6875.79it/s]
# Processing packets: 88174it [00:13, 6976.84it/s]
# Processing packets: 88874it [00:13, 5961.59it/s]
# Processing packets: 89512it [00:14, 6064.24it/s]
# Processing packets: 90139it [00:14, 5940.43it/s]
# Processing packets: 90747it [00:14, 5696.23it/s]
# Processing packets: 91471it [00:14, 5984.26it/s]
# Processing packets: 92095it [00:14, 6036.16it/s]
# Processing packets: 92819it [00:14, 6325.68it/s]
# Processing packets: 93545it [00:14, 6563.50it/s]
# Processing packets: 94207it [00:14, 6308.86it/s]
# Processing packets: 94843it [00:14, 5782.74it/s]
# Processing packets: 95432it [00:15, 5798.54it/s]
# Processing packets: 96156it [00:15, 6008.89it/s]
# Processing packets: 96864it [00:15, 6304.68it/s]
# Processing packets: 97594it [00:15, 6567.84it/s]
# Processing packets: 98288it [00:15, 6661.11it/s]
# Processing packets: 98990it [00:15, 6727.88it/s]
# Processing packets: 99759it [00:15, 6998.10it/s]
# Processing packets: 100462it [00:15, 7002.18it/s]
# Processing packets: 101165it [00:15, 6866.02it/s]
# Processing packets: 101854it [00:16, 5624.96it/s]
# Processing packets: 102454it [00:16, 5447.20it/s]
# Processing packets: 103205it [00:16, 5783.76it/s]
# Processing packets: 103920it [00:16, 6135.28it/s]
# Processing packets: 104670it [00:16, 6503.54it/s]
# Processing packets: 105338it [00:16, 6546.59it/s]
# Processing packets: 106005it [00:16, 6564.30it/s]
# Processing packets: 106686it [00:16, 6597.86it/s]
# Processing packets: 107396it [00:16, 6722.39it/s]
# Processing packets: 108161it [00:17, 6878.08it/s]
# Processing packets: 108934it [00:17, 7095.17it/s]
# Processing packets: 109682it [00:17, 7111.79it/s]
# Processing packets: 110428it [00:17, 7206.29it/s]
# Processing packets: 111189it [00:17, 7324.51it/s]
# Processing packets: 111944it [00:17, 7348.68it/s]
# Processing packets: 112772it [00:17, 7368.78it/s]
# Processing packets: 113534it [00:17, 7437.89it/s]
# Processing packets: 114279it [00:17, 7413.00it/s]
# Processing packets: 115073it [00:17, 7548.99it/s]
# Processing packets: 115829it [00:18, 7516.02it/s]
# Processing packets: 116605it [00:18, 7336.78it/s]
# Processing packets: 117354it [00:18, 7359.89it/s]
# Processing packets: 118091it [00:18, 7068.04it/s]
# Processing packets: 118801it [00:18, 7075.18it/s]
# Processing packets: 119550it [00:18, 7148.68it/s]
# Processing packets: 120334it [00:18, 7346.68it/s]
# Processing packets: 121218it [00:18, 7538.82it/s]
# Processing packets: 122006it [00:18, 7547.98it/s]
# Processing packets: 122861it [00:18, 7563.10it/s]
# Processing packets: 123643it [00:19, 7502.58it/s]
# Processing packets: 124415it [00:19, 7410.19it/s]
# Processing packets: 125163it [00:19, 7341.04it/s]
# Processing packets: 125897it [00:19, 6516.42it/s]
# Processing packets: 126564it [00:19, 6498.93it/s]
# Processing packets: 127225it [00:19, 6447.26it/s]
# Processing packets: 127878it [00:19, 6467.82it/s]
# Processing packets: 128570it [00:19, 6542.65it/s]
# Processing packets: 129313it [00:19, 6742.63it/s]
# Processing packets: 130150it [00:20, 6998.35it/s]
# Processing packets: 130932it [00:20, 7147.03it/s]
# Processing packets: 131648it [00:20, 7025.69it/s]
# Processing packets: 132402it [00:20, 7143.40it/s]
# Processing packets: 133158it [00:20, 7060.46it/s]
# Processing packets: 133973it [00:20, 7145.80it/s]
# Processing packets: 134688it [00:20, 7114.83it/s]
# Processing packets: 135400it [00:20, 6945.02it/s]
# Processing packets: 136095it [00:20, 6805.64it/s]
# Processing packets: 136776it [00:21, 6690.08it/s]
# Processing packets: 137539it [00:21, 6851.15it/s]
# Processing packets: 138324it [00:21, 7044.05it/s]
# Processing packets: 139062it [00:21, 7130.94it/s]
# Processing packets: 139823it [00:21, 7234.83it/s]
# Processing packets: 140605it [00:21, 7383.95it/s]
# Processing packets: 141413it [00:21, 7321.29it/s]
# Processing packets: 142211it [00:21, 7404.04it/s]
# Processing packets: 142953it [00:21, 7392.93it/s]
# Processing packets: 143775it [00:21, 7393.47it/s]
# Processing packets: 144583it [00:22, 7504.34it/s]
# Processing packets: 145440it [00:22, 7555.43it/s]
# Processing packets: 146225it [00:22, 7565.96it/s]
# Processing packets: 146982it [00:22, 7523.59it/s]
# Processing packets: 147785it [00:22, 7472.39it/s]
# Processing packets: 148533it [00:22, 7382.89it/s]
# Processing packets: 149279it [00:22, 7384.11it/s]
# Processing packets: 150027it [00:22, 7314.79it/s]
# Processing packets: 150893it [00:22, 7460.22it/s]
# Processing packets: 151639it [00:23, 7370.19it/s]
# Processing packets: 152376it [00:23, 7127.92it/s]
# Processing packets: 153186it [00:23, 7171.17it/s]
# Processing packets: 153963it [00:23, 7230.47it/s]
# Processing packets: 154761it [00:23, 7359.00it/s]
# Processing packets: 155582it [00:23, 7347.50it/s]
# Processing packets: 156326it [00:23, 7350.28it/s]
# Processing packets: 157069it [00:23, 7363.46it/s]
# Processing packets: 157819it [00:23, 7334.72it/s]
# Processing packets: 158573it [00:23, 7387.84it/s]
# Processing packets: 159313it [00:24, 7348.29it/s]
# Processing packets: 160048it [00:24, 7348.35it/s]
# Processing packets: 160787it [00:24, 7319.25it/s]
# Processing packets: 161584it [00:24, 7339.48it/s]
# Processing packets: 162379it [00:24, 7449.36it/s]
# Processing packets: 163135it [00:24, 7479.20it/s]
# Processing packets: 163884it [00:24, 7476.51it/s]
# Processing packets: 164748it [00:24, 7531.27it/s]
# Processing packets: 165538it [00:24, 7535.54it/s]
# Processing packets: 166408it [00:25, 7614.28it/s]
# Processing packets: 167232it [00:25, 7575.98it/s]
# Processing packets: 168048it [00:25, 7618.56it/s]
# Processing packets: 168810it [00:25, 7444.85it/s]
# Processing packets: 169555it [00:25, 7327.00it/s]
# Processing packets: 170288it [00:25, 7177.41it/s]
# Processing packets: 171006it [00:25, 7029.49it/s]
# Processing packets: 171737it [00:25, 7052.33it/s]
# Processing packets: 172501it [00:25, 7131.41it/s]
# Processing packets: 173259it [00:25, 7028.19it/s]
# Processing packets: 173981it [00:26, 7000.23it/s]
# Processing packets: 174732it [00:26, 7091.98it/s]
# Processing packets: 175603it [00:26, 7288.21it/s]
# Processing packets: 176332it [00:26, 7209.96it/s]
# Processing packets: 177053it [00:26, 7136.85it/s]
# Processing packets: 177767it [00:26, 6928.56it/s]
# Processing packets: 178501it [00:26, 6998.41it/s]
# Processing packets: 179202it [00:26, 6923.70it/s]
# Processing packets: 179935it [00:26, 7011.84it/s]
# Processing packets: 180697it [00:27, 7171.92it/s]
# Processing packets: 181486it [00:27, 7299.35it/s]
# Processing packets: 182272it [00:27, 7384.55it/s]
# Processing packets: 183040it [00:27, 7412.22it/s]
# Processing packets: 183890it [00:27, 7471.58it/s]
# Processing packets: 184673it [00:27, 7511.09it/s]
# Processing packets: 185425it [00:27, 7396.02it/s]
# Processing packets: 186221it [00:27, 7349.21it/s]
# Processing packets: 186977it [00:27, 7371.01it/s]
# Processing packets: 187723it [00:27, 7371.53it/s]
# Processing packets: 188512it [00:28, 7325.38it/s]
# Processing packets: 189284it [00:28, 7342.70it/s]
# Processing packets: 190082it [00:28, 7468.46it/s]
# Processing packets: 190830it [00:28, 7414.48it/s]
# Processing packets: 191616it [00:28, 7426.56it/s]
# Processing packets: 192430it [00:28, 7515.69it/s]
# Processing packets: 193268it [00:28, 7524.49it/s]
# Processing packets: 194080it [00:28, 7611.46it/s]
# Processing packets: 194853it [00:28, 7613.14it/s]
# Processing packets: 195702it [00:29, 7616.76it/s]
# Processing packets: 196482it [00:29, 7566.53it/s]
# Processing packets: 197314it [00:29, 7539.29it/s]
# Processing packets: 198111it [00:29, 7555.33it/s]
# Processing packets: 198951it [00:29, 7553.51it/s]
# Processing packets: 199758it [00:29, 7590.45it/s]
# Processing packets: 200527it [00:29, 7557.59it/s]
# Processing packets: 201380it [00:29, 7582.42it/s]
# Processing packets: 202152it [00:29, 7535.16it/s]
# Processing packets: 203013it [00:30, 7582.86it/s]
# Processing packets: 203771it [00:30, 7504.66it/s]
# Processing packets: 204522it [00:30, 6589.19it/s]
# Processing packets: 205199it [00:30, 6417.41it/s]
# Processing packets: 205853it [00:30, 6302.99it/s]
# Processing packets: 206491it [00:30, 6319.43it/s]
# Processing packets: 207169it [00:30, 6447.66it/s]
# Processing packets: 207819it [00:30, 6239.15it/s]
# Processing packets: 208551it [00:30, 6514.88it/s]
# Processing packets: 209207it [00:30, 6511.14it/s]
# Processing packets: 209862it [00:31, 6500.15it/s]
# Processing packets: 210515it [00:31, 6505.39it/s]
# Processing packets: 211167it [00:31, 6307.91it/s]
# Processing packets: 211800it [00:31, 6283.98it/s]
# Processing packets: 212515it [00:31, 6524.67it/s]
# Processing packets: 213169it [00:31, 6459.76it/s]
# Processing packets: 213856it [00:31, 6367.75it/s]
# Processing packets: 214495it [00:31, 5564.52it/s]
# Processing packets: 215116it [00:31, 5716.87it/s]
# Processing packets: 215864it [00:32, 6154.52it/s]
# Processing packets: 216493it [00:32, 6113.02it/s]
# Processing packets: 217162it [00:32, 6206.46it/s]
# Processing packets: 217883it [00:32, 6394.04it/s]
# Processing packets: 218528it [00:32, 6283.28it/s]
# Processing packets: 219253it [00:32, 6556.86it/s]
# Processing packets: 219913it [00:32, 6438.66it/s]
# Processing packets: 220644it [00:32, 6622.74it/s]
# Processing packets: 221422it [00:32, 6929.73it/s]
# Processing packets: 222118it [00:33, 6535.88it/s]
# Processing packets: 222832it [00:33, 6551.00it/s]
# Processing packets: 223491it [00:33, 6489.58it/s]
# Processing packets: 224143it [00:33, 6201.60it/s]
# Processing packets: 224864it [00:33, 6477.71it/s]
# Processing packets: 225517it [00:33, 6323.01it/s]
# Processing packets: 226258it [00:33, 6552.43it/s]
# Processing packets: 227030it [00:33, 6851.09it/s]
# Processing packets: 227753it [00:33, 6956.66it/s]
# Processing packets: 228452it [00:33, 6899.43it/s]
# Processing packets: 229144it [00:34, 6672.15it/s]
# Processing packets: 229897it [00:34, 6889.62it/s]
# Processing packets: 230635it [00:34, 7005.64it/s]
# Processing packets: 231338it [00:34, 6809.86it/s]
# Processing packets: 232057it [00:34, 6893.51it/s]
# Processing packets: 232795it [00:34, 7004.32it/s]
# Processing packets: 233497it [00:34, 6596.30it/s]
# Processing packets: 234263it [00:34, 6733.47it/s]
# Processing packets: 234941it [00:34, 6723.03it/s]
# Processing packets: 235616it [00:35, 6601.63it/s]
# Processing packets: 236429it [00:35, 6810.05it/s]
# Processing packets: 237111it [00:35, 6566.59it/s]
# Processing packets: 237816it [00:35, 6633.29it/s]
# Processing packets: 238481it [00:35, 6597.88it/s]
# Processing packets: 239142it [00:35, 6477.31it/s]
# Processing packets: 239912it [00:35, 6740.44it/s]
# Processing packets: 240587it [00:35, 6638.93it/s]
# Processing packets: 241265it [00:35, 6642.24it/s]
# Processing packets: 242075it [00:36, 6816.33it/s]
# Processing packets: 242756it [00:36, 6780.12it/s]
# Processing packets: 243434it [00:36, 6770.62it/s]
# Processing packets: 244145it [00:36, 6655.51it/s]
# Processing packets: 244853it [00:36, 6707.62it/s]
# Processing packets: 245524it [00:36, 6603.03it/s]
# Processing packets: 246222it [00:36, 6697.41it/s]
# Processing packets: 246893it [00:36, 6585.99it/s]
# Processing packets: 247589it [00:36, 6621.06it/s]
# Processing packets: 248252it [00:36, 6576.56it/s]
# Processing packets: 248910it [00:37, 6175.56it/s]
# Processing packets: 249643it [00:37, 6419.42it/s]
# Processing packets: 250396it [00:37, 6648.40it/s]
# Processing packets: 251105it [00:37, 6751.66it/s]
# Processing packets: 251791it [00:37, 6778.71it/s]
# Processing packets: 252471it [00:37, 6236.59it/s]
# Processing packets: 253247it [00:37, 6605.02it/s]
# Processing packets: 253917it [00:37, 6505.59it/s]
# Processing packets: 254675it [00:37, 6773.49it/s]
# Processing packets: 255358it [00:38, 6638.62it/s]
# Processing packets: 256104it [00:38, 6557.24it/s]
# Processing packets: 256763it [00:38, 6375.80it/s]
# Processing packets: 257403it [00:38, 6164.04it/s]
# Processing packets: 258085it [00:38, 6317.18it/s]
# Processing packets: 258775it [00:38, 6460.03it/s]
# Processing packets: 259424it [00:38, 6328.59it/s]
# Processing packets: 260059it [00:38, 6057.18it/s]
# Processing packets: 260774it [00:38, 6332.22it/s]
# Processing packets: 261422it [00:38, 6372.54it/s]
# Processing packets: 262062it [00:39, 6128.98it/s]
# Processing packets: 262687it [00:39, 6142.73it/s]
# Processing packets: 263434it [00:39, 6283.28it/s]
# Processing packets: 264064it [00:39, 5957.06it/s]
# Processing packets: 264768it [00:39, 6113.11it/s]
# Processing packets: 265382it [00:39, 5794.94it/s]
# Processing packets: 265965it [00:39, 5744.67it/s]
# Processing packets: 266573it [00:39, 5837.87it/s]
# Processing packets: 267204it [00:39, 5972.12it/s]
# Processing packets: 267988it [00:40, 6463.33it/s]
# Processing packets: 268637it [00:40, 6339.38it/s]
# Processing packets: 269273it [00:40, 6189.22it/s]
# Processing packets: 269906it [00:40, 6103.92it/s]
# Processing packets: 270518it [00:40, 6047.33it/s]
# Processing packets: 271233it [00:40, 6294.45it/s]
# Processing packets: 271971it [00:40, 6586.19it/s]
# Processing packets: 272799it [00:40, 6831.05it/s]
# Processing packets: 273482it [00:40, 6822.89it/s]
# Processing packets: 274210it [00:41, 6908.55it/s]
# Processing packets: 274901it [00:41, 6901.54it/s]
# Processing packets: 275592it [00:41, 6901.14it/s]
# Processing packets: 276283it [00:41, 6581.23it/s]
# Processing packets: 276949it [00:41, 6603.19it/s]
# Processing packets: 277735it [00:41, 6684.83it/s]
# Processing packets: 278425it [00:41, 6716.41it/s]
# Processing packets: 279149it [00:41, 6867.16it/s]
# Processing packets: 279837it [00:41, 6812.60it/s]
# Processing packets: 280520it [00:41, 6725.68it/s]
# Processing packets: 281194it [00:42, 6255.01it/s]
# Processing packets: 281826it [00:42, 5858.39it/s]
# Processing packets: 282420it [00:42, 5810.41it/s]
# Processing packets: 283088it [00:42, 6050.07it/s]
# Processing packets: 283812it [00:42, 6381.92it/s]
# Processing packets: 284512it [00:42, 6513.20it/s]
# Processing packets: 285168it [00:42, 6162.62it/s]
# Processing packets: 285791it [00:42, 5644.77it/s]
# Processing packets: 286575it [00:42, 6099.71it/s]
# Processing packets: 287266it [00:43, 6245.56it/s]
# Processing packets: 288015it [00:43, 6545.61it/s]
# Processing packets: 288678it [00:43, 6313.90it/s]
# Processing packets: 289461it [00:43, 6457.13it/s]
# Processing packets: 290125it [00:43, 6498.46it/s]
# Processing packets: 290798it [00:43, 6547.17it/s]
# Processing packets: 291456it [00:43, 6420.22it/s]
# Processing packets: 292143it [00:43, 6546.34it/s]
# Processing packets: 292854it [00:43, 6583.28it/s]
# Processing packets: 293514it [00:44, 6516.13it/s]
# Processing packets: 294167it [00:44, 6517.16it/s]
# Processing packets: 294860it [00:44, 6622.75it/s]
# Processing packets: 295523it [00:44, 6461.34it/s]
# Processing packets: 296194it [00:44, 6452.62it/s]
# Processing packets: 296890it [00:44, 6591.49it/s]
# Processing packets: 297630it [00:44, 6789.85it/s]
# Processing packets: 298310it [00:44, 6755.13it/s]
# Processing packets: 298987it [00:44, 6757.89it/s]
# Processing packets: 299664it [00:44, 6446.86it/s]
# Processing packets: 300327it [00:45, 6353.13it/s]
# Processing packets: 300965it [00:45, 6100.04it/s]
# Processing packets: 301581it [00:45, 6021.97it/s]
# Processing packets: 302269it [00:45, 6252.93it/s]
# Processing packets: 302927it [00:45, 6345.09it/s]
# Processing packets: 303698it [00:45, 6489.28it/s]
# Processing packets: 304359it [00:45, 6520.28it/s]
# Processing packets: 305037it [00:45, 6594.31it/s]
# Processing packets: 305729it [00:45, 6634.27it/s]
# Processing packets: 306424it [00:46, 6723.65it/s]
# Processing packets: 307097it [00:46, 6717.24it/s]
# Processing packets: 307770it [00:46, 6416.61it/s]
# Processing packets: 308415it [00:46, 6171.03it/s]
# Processing packets: 309036it [00:46, 6109.50it/s]
# Processing packets: 309666it [00:46, 6073.12it/s]
# Processing packets: 310301it [00:46, 6148.53it/s]
# Processing packets: 310918it [00:46, 6075.91it/s]
# Processing packets: 311651it [00:46, 6357.60it/s]
# Processing packets: 312288it [00:46, 6351.61it/s]
# Processing packets: 312968it [00:47, 6448.47it/s]
# Processing packets: 313746it [00:47, 6642.96it/s]
# Processing packets: 314410it [00:47, 6557.28it/s]
# Processing packets: 315066it [00:47, 6357.11it/s]
# Processing packets: 315703it [00:47, 5973.62it/s]
# Processing packets: 316305it [00:47, 5099.99it/s]
# Processing packets: 316837it [00:47, 4772.94it/s]
# Processing packets: 317331it [00:47, 4751.20it/s]
# Processing packets: 317818it [00:48, 4652.63it/s]
# Processing packets: 318421it [00:48, 4997.62it/s]
# Processing packets: 319139it [00:48, 5566.74it/s]
# Processing packets: 319814it [00:48, 5862.91it/s]
# Processing packets: 320526it [00:48, 6220.55it/s]
# Processing packets: 321189it [00:48, 6331.74it/s]
# Processing packets: 321865it [00:48, 6255.37it/s]
# Processing packets: 322496it [00:48, 6135.28it/s]
# Processing packets: 323132it [00:48, 6117.72it/s]
# Processing packets: 323857it [00:48, 6301.07it/s]
# Processing packets: 324513it [00:49, 6351.04it/s]
# Processing packets: 325150it [00:49, 6348.26it/s]
# Processing packets: 325837it [00:49, 6454.06it/s]
# Processing packets: 326484it [00:49, 6432.79it/s]
# Processing packets: 327252it [00:49, 6571.00it/s]
# Processing packets: 327925it [00:49, 6608.04it/s]
# Processing packets: 328586it [00:49, 6537.13it/s]
# Processing packets: 329240it [00:49, 6243.11it/s]
# Processing packets: 329906it [00:49, 6353.59it/s]
# Processing packets: 330544it [00:50, 6223.05it/s]
# Processing packets: 331221it [00:50, 6302.40it/s]
# Processing packets: 331882it [00:50, 6357.34it/s]
# Processing packets: 332666it [00:50, 6549.50it/s]
# Processing packets: 333394it [00:50, 6757.75it/s]
# Processing packets: 334152it [00:50, 6939.63it/s]
# Processing packets: 334847it [00:50, 6931.92it/s]
# Processing packets: 335620it [00:50, 6889.02it/s]
# Processing packets: 336310it [00:50, 6767.07it/s]
# Processing packets: 336988it [00:50, 6574.21it/s]
# Processing packets: 337647it [00:51, 6386.27it/s]
# Processing packets: 338334it [00:51, 6458.95it/s]
# Processing packets: 339039it [00:51, 6565.35it/s]
# Processing packets: 339717it [00:51, 6601.74it/s]
# Processing packets: 340437it [00:51, 6770.21it/s]
# Processing packets: 341248it [00:51, 6951.80it/s]
# Processing packets: 341944it [00:51, 6776.32it/s]
# Processing packets: 342622it [00:51, 6588.79it/s]
# Processing packets: 343303it [00:51, 6587.53it/s]
# Processing packets: 343963it [00:52, 6229.17it/s]
# Processing packets: 344626it [00:52, 6341.18it/s]
# Processing packets: 345362it [00:52, 6469.58it/s]
# Processing packets: 346066it [00:52, 6606.80it/s]
# Processing packets: 346832it [00:52, 6854.76it/s]
# Processing packets: 347580it [00:52, 6980.82it/s]
# Processing packets: 348290it [00:52, 6845.84it/s]
# Processing packets: 348977it [00:52, 6665.09it/s]
# Processing packets: 349734it [00:52, 6702.48it/s]
# Processing packets: 350406it [00:53, 6392.54it/s]
# Processing packets: 351076it [00:53, 6471.10it/s]
# Processing packets: 351726it [00:53, 6340.66it/s]
# Processing packets: 352426it [00:53, 6448.40it/s]
# Processing packets: 353073it [00:53, 6378.51it/s]
# Processing packets: 353734it [00:53, 6379.43it/s]
# Processing packets: 354434it [00:53, 6554.29it/s]
# Processing packets: 355120it [00:53, 6487.94it/s]
# Processing packets: 355797it [00:53, 6502.04it/s]
# Processing packets: 356448it [00:53, 6488.27it/s]
# Processing packets: 357098it [00:54, 6482.06it/s]
# Processing packets: 357747it [00:54, 6133.96it/s]
# Processing packets: 358365it [00:54, 6142.76it/s]
# Processing packets: 358982it [00:54, 5917.11it/s]
# Processing packets: 359577it [00:54, 5662.51it/s]
# Processing packets: 360283it [00:54, 5861.32it/s]
# Processing packets: 361001it [00:54, 6149.23it/s]
# Processing packets: 361657it [00:54, 6264.03it/s]
# Processing packets: 362287it [00:54, 6141.47it/s]
# Processing packets: 362904it [00:55, 5993.38it/s]
# Processing packets: 363557it [00:55, 6143.45it/s]
# Processing packets: 364174it [00:55, 5874.84it/s]
# Processing packets: 364765it [00:55, 5606.57it/s]
# Processing packets: 365368it [00:55, 5574.68it/s]
# Processing packets: 366033it [00:55, 5811.20it/s]
# Processing packets: 366723it [00:55, 6083.60it/s]
# Processing packets: 367420it [00:55, 6325.80it/s]
# Processing packets: 368151it [00:55, 6412.05it/s]
# Processing packets: 368821it [00:55, 6445.08it/s]
# Processing packets: 369524it [00:56, 6582.37it/s]
# Processing packets: 370265it [00:56, 6806.98it/s]
# Processing packets: 371007it [00:56, 6690.64it/s]
# Processing packets: 371678it [00:56, 6632.86it/s]
# Processing packets: 372343it [00:56, 6437.69it/s]
# Processing packets: 372989it [00:56, 5820.70it/s]
# Processing packets: 373635it [00:56, 5825.46it/s]
# Processing packets: 374474it [00:56, 6465.79it/s]
# Processing packets: 375223it [00:56, 6734.45it/s]
# Processing packets: 375906it [00:57, 6590.82it/s]
# Processing packets: 376572it [00:57, 6574.25it/s]
# Processing packets: 377234it [00:57, 6490.02it/s]
# Processing packets: 377894it [00:57, 6347.41it/s]
# Processing packets: 378568it [00:57, 6429.74it/s]
# Processing packets: 379213it [00:57, 6421.57it/s]
# Processing packets: 379957it [00:57, 6689.76it/s]
# Processing packets: 380668it [00:57, 6794.30it/s]
# Processing packets: 381400it [00:57, 6914.29it/s]
# Processing packets: 382131it [00:58, 7000.98it/s]
# Processing packets: 382832it [00:58, 6908.91it/s]
# Processing packets: 383524it [00:58, 6869.79it/s]
# Processing packets: 384212it [00:58, 6664.18it/s]
# Processing packets: 384998it [00:58, 6989.53it/s]
# Processing packets: 385808it [00:58, 7293.32it/s]
# Processing packets: 386690it [00:58, 7585.59it/s]
# Processing packets: 387535it [00:58, 7753.54it/s]
# Processing packets: 388357it [00:58, 7848.22it/s]
# Processing packets: 389189it [00:58, 7982.50it/s]
# Processing packets: 389988it [00:59, 7968.46it/s]
# Processing packets: 390786it [00:59, 7618.42it/s]
# Processing packets: 391552it [00:59, 7578.11it/s]
# Processing packets: 392312it [00:59, 7302.77it/s]
# Processing packets: 393046it [00:59, 7073.17it/s]
# Processing packets: 393757it [00:59, 6983.43it/s]
# Processing flows:   0%|          | 1/39215 [00:59<650:40:57, 59.74s/it]
# Processing packets: 0it [00:00, ?it/s]
# Processing packets: 615it [00:00, 5896.49it/s]
# Processing packets: 1290it [00:00, 5981.65it/s]
# Processing packets: 2033it [00:00, 6493.77it/s]
# Processing packets: 2684it [00:00, 6218.91it/s]
# Processing packets: 3359it [00:00, 6361.05it/s]
# Processing packets: 4002it [00:00, 6347.65it/s]
# Processing packets: 4638it [00:00, 6241.70it/s]
# Processing packets: 5300it [00:00, 6263.03it/s]
# Processing packets: 5936it [00:00, 6272.68it/s]
# Processing packets: 6580it [00:01, 6229.96it/s]
# Processing packets: 7314it [00:01, 6495.91it/s]
# Processing packets: 7964it [00:01, 6340.09it/s]
# Processing packets: 8607it [00:01, 6334.98it/s]
# Processing packets: 9302it [00:01, 6501.85it/s]
# Processing packets: 9953it [00:01, 6278.26it/s]
# Processing packets: 10674it [00:01, 6515.65it/s]
# Processing packets: 11328it [00:01, 6372.06it/s]
# Processing packets: 11967it [00:01, 6221.48it/s]
# Processing packets: 12692it [00:01, 6481.36it/s]
# Processing packets: 13342it [00:02, 6325.20it/s]
# Processing packets: 14076it [00:02, 6370.70it/s]
# Processing packets: 14715it [00:02, 6373.22it/s]
# Processing packets: 15354it [00:02, 6323.57it/s]
# Processing packets: 15987it [00:02, 5948.06it/s]
# Processing packets: 16650it [00:02, 6058.78it/s]
# Processing packets: 17447it [00:02, 6590.21it/s]
# Processing packets: 18269it [00:02, 7044.91it/s]
# Processing packets: 19017it [00:02, 7125.17it/s]
# Processing packets: 19847it [00:03, 7437.16it/s]
# Processing packets: 20594it [00:03, 7163.19it/s]
# Processing packets: 21315it [00:03, 6969.77it/s]
# Processing packets: 22016it [00:03, 6662.70it/s]
# Processing packets: 22772it [00:03, 6886.59it/s]
# Processing packets: 23465it [00:03, 6616.21it/s]
# Processing packets: 24131it [00:03, 6534.22it/s]
# Processing packets: 24838it [00:03, 6623.53it/s]
# Processing packets: 25503it [00:03, 6413.34it/s]
# Processing packets: 26243it [00:04, 6607.39it/s]
# Processing packets: 26906it [00:04, 6434.41it/s]
# Processing packets: 27582it [00:04, 6362.95it/s]
# Processing packets: 28315it [00:04, 6634.44it/s]
# Processing packets: 28981it [00:04, 6338.32it/s]
# Processing packets: 29623it [00:04, 6358.17it/s]
# Processing packets: 30285it [00:04, 6401.15it/s]
# Processing packets: 30928it [00:04, 6147.02it/s]
# Processing packets: 31633it [00:04, 6400.41it/s]
# Processing packets: 32277it [00:05, 6186.86it/s]
# Processing packets: 32925it [00:05, 6225.35it/s]
# Processing packets: 33602it [00:05, 6363.67it/s]
# Processing packets: 34241it [00:05, 6093.02it/s]
# Processing packets: 34854it [00:05, 6076.73it/s]
# Processing packets: 35541it [00:05, 6080.67it/s]
# Processing packets: 36151it [00:05, 6009.86it/s]
# Processing packets: 36866it [00:05, 6187.54it/s]
# Processing packets: 37486it [00:05, 6058.29it/s]
# Processing packets: 38093it [00:05, 5994.03it/s]
# Processing packets: 38769it [00:06, 6179.96it/s]
# Processing packets: 39388it [00:06, 6147.15it/s]
# Processing packets: 40004it [00:06, 6008.39it/s]
# Processing packets: 40678it [00:06, 6213.73it/s]
# Processing packets: 41485it [00:06, 6486.58it/s]
# Processing packets: 42154it [00:06, 6534.31it/s]
# Processing packets: 42821it [00:06, 6551.07it/s]
# Processing packets: 43476it [00:06, 6540.06it/s]
# Processing packets: 44163it [00:06, 6482.40it/s]
# Processing packets: 44882it [00:07, 6612.49it/s]
# Processing packets: 45544it [00:07, 5709.53it/s]
# Processing packets: 46241it [00:07, 5874.45it/s]
# Processing packets: 46897it [00:07, 6009.50it/s]
# Processing packets: 47590it [00:07, 6225.23it/s]
# Processing packets: 48246it [00:07, 6317.19it/s]
# Processing packets: 48967it [00:07, 6412.58it/s]
# Processing packets: 49614it [00:07, 6408.04it/s]
# Processing packets: 50347it [00:07, 6549.27it/s]
# Processing packets: 51005it [00:07, 6557.07it/s]
# Processing packets: 51743it [00:08, 6500.18it/s]
# Processing packets: 52395it [00:08, 6416.37it/s]
# Processing packets: 53151it [00:08, 6556.47it/s]
# Processing packets: 53808it [00:08, 6460.89it/s]
# Processing packets: 54455it [00:08, 6450.48it/s]
# Processing packets: 55134it [00:08, 6538.78it/s]
# Processing packets: 55789it [00:08, 6333.05it/s]
# Processing packets: 56424it [00:08, 6236.73it/s]
# Processing packets: 57147it [00:08, 6446.26it/s]
# Processing packets: 57874it [00:09, 6597.33it/s]
# Processing packets: 58535it [00:09, 6504.71it/s]
# Processing packets: 59186it [00:09, 6237.16it/s]
# Processing packets: 59812it [00:09, 6005.36it/s]
# Processing packets: 60415it [00:09, 5939.36it/s]
# Processing packets: 61121it [00:09, 6067.02it/s]
# Processing packets: 61796it [00:09, 6240.45it/s]
# Processing packets: 62422it [00:09, 6047.58it/s]
# Processing packets: 63126it [00:09, 6303.72it/s]
# Processing packets: 63937it [00:10, 6698.65it/s]
# Processing packets: 64758it [00:10, 6905.88it/s]
# Processing packets: 65491it [00:10, 6993.24it/s]
# Processing packets: 66216it [00:10, 7062.68it/s]
# Processing packets: 66931it [00:10, 7065.05it/s]
# Processing packets: 67651it [00:10, 7087.93it/s]
# Processing packets: 68361it [00:10, 7059.96it/s]
# Processing packets: 69068it [00:10, 6845.31it/s]
# Processing packets: 69754it [00:10, 6277.24it/s]
# Processing packets: 70391it [00:10, 6092.97it/s]
# Processing packets: 71007it [00:11, 5686.90it/s]
# Processing packets: 71584it [00:11, 5643.68it/s]
# Processing packets: 72218it [00:11, 5799.63it/s]
# Processing packets: 72884it [00:11, 6038.66it/s]
# Processing packets: 73493it [00:11, 5821.74it/s]
# Processing packets: 74080it [00:11, 5748.44it/s]
# Processing packets: 74761it [00:11, 5941.68it/s]
# Processing packets: 75405it [00:11, 6049.68it/s]
# Processing packets: 76012it [00:11, 5936.80it/s]
# Processing packets: 76701it [00:12, 6073.39it/s]
# Processing packets: 77310it [00:12, 6033.11it/s]
# Processing packets: 77997it [00:12, 6056.02it/s]
# Processing packets: 78740it [00:12, 6397.88it/s]
# Processing packets: 79382it [00:12, 6071.97it/s]
# Processing packets: 80002it [00:12, 6061.51it/s]
# Processing packets: 80681it [00:12, 6114.47it/s]
# Processing packets: 81295it [00:12, 5930.21it/s]
# Processing packets: 82018it [00:12, 6288.80it/s]
# Processing packets: 82698it [00:13, 6303.70it/s]
# Processing packets: 83331it [00:13, 6293.29it/s]
# Processing packets: 84010it [00:13, 6436.88it/s]
# Processing packets: 84656it [00:13, 6328.96it/s]
# Processing packets: 85308it [00:13, 6238.93it/s]
# Processing packets: 86075it [00:13, 6617.53it/s]
# Processing packets: 86829it [00:13, 6751.47it/s]
# Processing packets: 87615it [00:13, 6938.79it/s]
# Processing packets: 88359it [00:13, 7042.64it/s]
# Processing packets: 89091it [00:13, 7102.41it/s]
# Processing packets: 89850it [00:14, 7239.24it/s]
# Processing packets: 90593it [00:14, 7288.99it/s]
# Processing packets: 91323it [00:14, 7288.87it/s]
# Processing packets: 92079it [00:14, 7340.06it/s]
# Processing packets: 92899it [00:14, 7350.87it/s]
# Processing packets: 93679it [00:14, 7412.06it/s]
# Processing packets: 94445it [00:14, 7479.96it/s]
# Processing packets: 95194it [00:14, 7439.29it/s]
# Processing packets: 96017it [00:14, 7416.64it/s]
# Processing packets: 96759it [00:15, 7339.69it/s]
# Processing packets: 97532it [00:15, 7184.22it/s]
# Processing packets: 98266it [00:15, 7169.44it/s]
# Processing packets: 99038it [00:15, 7285.32it/s]
# Processing packets: 99826it [00:15, 7319.73it/s]
# Processing packets: 100620it [00:15, 7404.35it/s]
# Processing packets: 101385it [00:15, 7468.24it/s]
# Processing packets: 102136it [00:15, 7478.45it/s]
# Processing packets: 102885it [00:15, 6760.61it/s]
# Processing packets: 103575it [00:15, 6798.20it/s]
# Processing packets: 104265it [00:16, 6812.95it/s]
# Processing packets: 105007it [00:16, 6807.72it/s]
# Processing packets: 105789it [00:16, 7027.13it/s]
# Processing packets: 106529it [00:16, 7127.86it/s]
# Processing packets: 107354it [00:16, 7127.34it/s]
# Processing packets: 108118it [00:16, 7244.70it/s]
# Processing packets: 108886it [00:16, 7366.81it/s]
# Processing packets: 109636it [00:16, 7370.76it/s]
# Processing packets: 110375it [00:16, 7362.98it/s]
# Processing packets: 111140it [00:17, 7160.92it/s]
# Processing packets: 111866it [00:17, 7164.27it/s]
# Processing packets: 112584it [00:17, 7009.12it/s]
# Processing packets: 113287it [00:17, 6898.52it/s]
# Processing packets: 113978it [00:17, 6764.47it/s]
# Processing packets: 114656it [00:17, 6616.73it/s]
# Processing packets: 115319it [00:17, 6562.26it/s]
# Processing packets: 115976it [00:17, 6505.81it/s]
# Processing packets: 116647it [00:17, 6560.23it/s]
# Processing packets: 117342it [00:17, 6610.82it/s]
# Processing packets: 118004it [00:18, 6326.18it/s]
# Processing packets: 118639it [00:18, 6266.84it/s]
# Processing packets: 119343it [00:18, 6354.76it/s]
# Processing packets: 120008it [00:18, 6384.83it/s]
# Processing packets: 120648it [00:18, 6291.13it/s]
# Processing packets: 121307it [00:18, 6271.56it/s]
# Processing packets: 122049it [00:18, 6513.50it/s]
# Processing packets: 122843it [00:18, 6680.84it/s]
# Processing packets: 123582it [00:18, 6800.73it/s]
# Processing packets: 124262it [00:19, 6664.81it/s]
# Processing packets: 124929it [00:19, 6558.33it/s]
# Processing packets: 125585it [00:19, 6531.15it/s]
# Processing packets: 126256it [00:19, 6543.76it/s]
# Processing packets: 126946it [00:19, 6639.64it/s]
# Processing packets: 127728it [00:19, 6680.56it/s]
# Processing packets: 128400it [00:19, 6670.46it/s]
# Processing packets: 129185it [00:19, 6725.61it/s]
# Processing packets: 129933it [00:19, 6901.10it/s]
# Processing packets: 130624it [00:20, 6296.07it/s]
# Processing packets: 131263it [00:20, 6313.45it/s]
# Processing packets: 131903it [00:20, 6310.18it/s]
# Processing packets: 132539it [00:20, 5943.02it/s]
# Processing packets: 133244it [00:20, 6161.73it/s]
# Processing packets: 133986it [00:20, 6488.27it/s]
# Processing packets: 134866it [00:20, 6858.10it/s]
# Processing packets: 135626it [00:20, 7066.44it/s]
# Processing packets: 136336it [00:20, 7075.57it/s]
# Processing packets: 137046it [00:20, 6952.43it/s]
# Processing packets: 137807it [00:21, 6993.13it/s]
# Processing packets: 138576it [00:21, 7107.09it/s]
# Processing packets: 139293it [00:21, 7122.74it/s]
# Processing packets: 140049it [00:21, 7157.59it/s]
# Processing packets: 140819it [00:21, 7203.75it/s]
# Processing packets: 141628it [00:21, 7346.36it/s]
# Processing packets: 142369it [00:21, 7296.81it/s]
# Processing packets: 143099it [00:21, 7096.93it/s]
# Processing packets: 143810it [00:21, 6766.48it/s]
# Processing packets: 144490it [00:22, 6764.01it/s]
# Processing packets: 145206it [00:22, 6851.82it/s]
# Processing packets: 145893it [00:22, 6584.96it/s]
# Processing packets: 146639it [00:22, 6804.33it/s]
# Processing packets: 147469it [00:22, 6994.61it/s]
# Processing packets: 148219it [00:22, 7115.39it/s]
# Processing packets: 148967it [00:22, 7206.60it/s]
# Processing packets: 149747it [00:22, 7281.75it/s]
# Processing packets: 150533it [00:22, 7347.19it/s]
# Processing packets: 151269it [00:22, 7035.70it/s]
# Processing packets: 151976it [00:23, 7001.89it/s]
# Processing packets: 152678it [00:23, 6682.67it/s]
# Processing packets: 153434it [00:23, 6695.20it/s]
# Processing packets: 154106it [00:23, 6600.37it/s]
# Processing packets: 154786it [00:23, 6512.12it/s]
# Processing packets: 155540it [00:23, 6770.70it/s]
# Processing packets: 156219it [00:23, 6713.05it/s]
# Processing packets: 156892it [00:23, 6659.60it/s]
# Processing packets: 157569it [00:23, 6683.75it/s]
# Processing packets: 158350it [00:24, 6925.64it/s]
# Processing packets: 159128it [00:24, 7069.04it/s]
# Processing packets: 159841it [00:24, 7069.62it/s]
# Processing packets: 160612it [00:24, 7224.92it/s]
# Processing packets: 161362it [00:24, 7288.99it/s]
# Processing packets: 162092it [00:24, 7245.95it/s]
# Processing packets: 162817it [00:24, 6920.90it/s]
# Processing packets: 163625it [00:24, 7082.77it/s]
# Processing packets: 164344it [00:24, 7049.71it/s]
# Processing packets: 165104it [00:24, 7129.29it/s]
# Processing packets: 165818it [00:25, 6615.37it/s]
# Processing packets: 166491it [00:25, 6605.06it/s]
# Processing packets: 167198it [00:25, 6728.44it/s]
# Processing packets: 168053it [00:25, 6967.10it/s]
# Processing packets: 168771it [00:25, 6918.01it/s]
# Processing packets: 169576it [00:25, 6996.97it/s]
# Processing packets: 170337it [00:25, 7076.33it/s]
# Processing packets: 171067it [00:25, 7118.83it/s]
# Processing packets: 171887it [00:25, 7133.56it/s]
# Processing packets: 172601it [00:26, 7077.87it/s]
# Processing packets: 173341it [00:26, 6957.50it/s]
# Processing packets: 174072it [00:26, 6997.54it/s]
# Processing packets: 174886it [00:26, 7071.84it/s]
# Processing packets: 175613it [00:26, 7039.38it/s]
# Processing packets: 176450it [00:26, 7170.28it/s]
# Processing packets: 177230it [00:26, 7273.21it/s]
# Processing packets: 178055it [00:26, 7308.57it/s]
# Processing packets: 178788it [00:26, 7226.66it/s]
# Processing packets: 179511it [00:27, 7198.91it/s]
# Processing packets: 180231it [00:27, 7064.44it/s]
# Processing packets: 180962it [00:27, 7066.49it/s]
# Processing packets: 181669it [00:27, 6980.20it/s]
# Processing packets: 182402it [00:27, 7075.02it/s]
# Processing packets: 183244it [00:27, 7185.49it/s]
# Processing packets: 184003it [00:27, 7261.49it/s]
# Processing packets: 184752it [00:27, 7316.51it/s]
# Processing packets: 185515it [00:27, 7310.38it/s]
# Processing packets: 186247it [00:27, 7145.45it/s]
# Processing packets: 186963it [00:28, 7142.71it/s]
# Processing packets: 187685it [00:28, 7148.64it/s]
# Processing packets: 188450it [00:28, 7251.39it/s]
# Processing packets: 189176it [00:28, 7237.39it/s]
# Processing packets: 189900it [00:28, 7134.44it/s]
# Processing packets: 190642it [00:28, 7217.76it/s]
# Processing packets: 191386it [00:28, 7283.39it/s]
# Processing packets: 192122it [00:28, 7281.86it/s]
# Processing packets: 192893it [00:28, 7310.90it/s]
# Processing packets: 193633it [00:28, 7336.98it/s]
# Processing packets: 194380it [00:29, 7371.72it/s]
# Processing packets: 195137it [00:29, 7400.36it/s]
# Processing packets: 195894it [00:29, 7437.45it/s]
# Processing packets: 196652it [00:29, 7457.66it/s]
# Processing packets: 197398it [00:29, 7371.41it/s]
# Processing packets: 198136it [00:29, 7118.18it/s]
# Processing packets: 198851it [00:29, 7064.92it/s]
# Processing packets: 199559it [00:29, 6945.84it/s]
# Processing packets: 200288it [00:29, 6931.69it/s]
# Processing packets: 200982it [00:30, 6830.87it/s]
# Processing packets: 201666it [00:30, 6445.00it/s]
# Processing packets: 202352it [00:30, 6554.20it/s]
# Processing packets: 203032it [00:30, 6621.23it/s]
# Processing packets: 203697it [00:30, 6489.66it/s]
# Processing packets: 204349it [00:30, 6160.77it/s]
# Processing packets: 205002it [00:30, 6198.18it/s]
# Processing packets: 205630it [00:30, 6206.30it/s]
# Processing packets: 206253it [00:30, 5736.19it/s]
# Processing packets: 206956it [00:30, 6015.93it/s]
# Processing packets: 207565it [00:31, 5982.87it/s]
# Processing packets: 208219it [00:31, 6132.34it/s]
# Processing packets: 209002it [00:31, 6467.33it/s]
# Processing packets: 209651it [00:31, 6252.61it/s]
# Processing packets: 210371it [00:31, 6455.37it/s]
# Processing packets: 211019it [00:31, 6371.60it/s]
# Processing packets: 211749it [00:31, 6436.36it/s]
# Processing packets: 212487it [00:31, 6624.74it/s]
# Processing packets: 213151it [00:31, 6409.79it/s]
# Processing packets: 213881it [00:32, 6582.74it/s]
# Processing packets: 214541it [00:32, 6549.56it/s]
# Processing packets: 215277it [00:32, 6496.34it/s]
# Processing packets: 215976it [00:32, 6635.26it/s]
# Processing packets: 216642it [00:32, 6371.28it/s]
# Processing packets: 217421it [00:32, 6512.81it/s]
# Processing packets: 218074it [00:32, 6412.33it/s]
# Processing packets: 218819it [00:32, 6517.35it/s]
# Processing packets: 219545it [00:32, 6646.42it/s]
# Processing packets: 220211it [00:33, 6442.38it/s]
# Processing packets: 220927it [00:33, 6637.92it/s]
# Processing packets: 221593it [00:33, 6603.76it/s]
# Processing packets: 222255it [00:33, 6563.85it/s]
# Processing packets: 222913it [00:33, 6532.11it/s]
# Processing packets: 223587it [00:33, 6336.37it/s]
# Processing packets: 224223it [00:33, 6271.03it/s]
# Processing packets: 224856it [00:33, 6283.79it/s]
# Processing packets: 225535it [00:33, 6198.94it/s]
# Processing packets: 226156it [00:33, 6116.29it/s]
# Processing packets: 226909it [00:34, 6280.69it/s]
# Processing packets: 227629it [00:34, 6528.48it/s]
# Processing packets: 228391it [00:34, 6573.12it/s]
# Processing packets: 229075it [00:34, 6410.03it/s]
# Processing packets: 229840it [00:34, 6556.35it/s]
# Processing packets: 230630it [00:34, 6780.55it/s]
# Processing packets: 231309it [00:34, 6720.01it/s]
# Processing packets: 232087it [00:34, 6776.92it/s]
# Processing packets: 232816it [00:34, 6787.69it/s]
# Processing packets: 233495it [00:35, 6555.15it/s]
# Processing packets: 234207it [00:35, 6692.63it/s]
# Processing packets: 234878it [00:35, 6638.76it/s]
# Processing packets: 235543it [00:35, 6406.96it/s]
# Processing packets: 236207it [00:35, 6460.56it/s]
# Processing packets: 236855it [00:35, 6418.88it/s]
# Processing packets: 237545it [00:35, 6397.90it/s]
# Processing packets: 238274it [00:35, 6652.23it/s]
# Processing packets: 238941it [00:35, 6329.37it/s]
# Processing packets: 239705it [00:36, 6623.13it/s]
# Processing packets: 240402it [00:36, 6686.38it/s]
# Processing packets: 241074it [00:36, 6471.85it/s]
# Processing packets: 241724it [00:36, 6373.21it/s]
# Processing packets: 242480it [00:36, 6547.71it/s]
# Processing packets: 243136it [00:36, 6467.92it/s]
# Processing packets: 243814it [00:36, 6553.38it/s]
# Processing packets: 244583it [00:36, 6852.83it/s]
# Processing packets: 245270it [00:36, 6501.95it/s]
# Processing packets: 245925it [00:36, 6465.36it/s]
# Processing packets: 246627it [00:37, 6529.10it/s]
# Processing packets: 247282it [00:37, 6391.33it/s]
# Processing packets: 247977it [00:37, 6398.24it/s]
# Processing packets: 248618it [00:37, 6259.53it/s]
# Processing packets: 249245it [00:37, 6253.98it/s]
# Processing packets: 250050it [00:37, 6558.77it/s]
# Processing packets: 250750it [00:37, 6659.49it/s]
# Processing packets: 251493it [00:37, 6819.25it/s]
# Processing packets: 252176it [00:37, 6310.98it/s]
# Processing packets: 252814it [00:38, 6267.19it/s]
# Processing packets: 253565it [00:38, 6419.24it/s]
# Processing packets: 254226it [00:38, 6420.58it/s]
# Processing packets: 254884it [00:38, 6460.54it/s]
# Processing packets: 255649it [00:38, 6533.30it/s]
# Processing packets: 256304it [00:38, 6299.16it/s]
# Processing packets: 256936it [00:38, 6128.07it/s]
# Processing packets: 257550it [00:38, 5960.68it/s]
# Processing packets: 258251it [00:38, 6236.53it/s]
# Processing packets: 258943it [00:39, 6216.88it/s]
# Processing packets: 259567it [00:39, 6106.38it/s]
# Processing packets: 260179it [00:39, 6053.20it/s]
# Processing packets: 260809it [00:39, 6102.15it/s]
# Processing packets: 261439it [00:39, 5991.14it/s]
# Processing packets: 262039it [00:39, 5629.32it/s]
# Processing packets: 262606it [00:39, 5556.29it/s]
# Processing packets: 263165it [00:39, 5406.62it/s]
# Processing packets: 263964it [00:39, 5871.17it/s]
# Processing packets: 264681it [00:40, 6040.59it/s]
# Processing packets: 265351it [00:40, 6026.41it/s]
# Processing packets: 265972it [00:40, 6058.74it/s]
# Processing packets: 266578it [00:40, 6058.65it/s]
# Processing packets: 267242it [00:40, 6200.59it/s]
# Processing packets: 267991it [00:40, 6464.31it/s]
# Processing packets: 268693it [00:40, 6416.52it/s]
# Processing packets: 269335it [00:40, 6159.77it/s]
# Processing packets: 269962it [00:40, 6186.23it/s]
# Processing packets: 270582it [00:40, 6099.44it/s]
# Processing packets: 271295it [00:41, 6373.11it/s]
# Processing packets: 271934it [00:41, 6266.04it/s]
# Processing packets: 272623it [00:41, 6423.05it/s]
# Processing packets: 273343it [00:41, 6580.72it/s]
# Processing packets: 274118it [00:41, 6839.64it/s]
# Processing packets: 274803it [00:41, 6811.49it/s]
# Processing packets: 275485it [00:41, 6752.48it/s]
# Processing packets: 276161it [00:41, 6483.52it/s]
# Processing packets: 276812it [00:41, 6415.08it/s]
# Processing packets: 277462it [00:42, 6416.08it/s]
# Processing packets: 278222it [00:42, 6614.59it/s]
# Processing packets: 278957it [00:42, 6776.14it/s]
# Processing packets: 279636it [00:42, 6721.11it/s]
# Processing packets: 280309it [00:42, 6570.37it/s]
# Processing packets: 280967it [00:42, 6272.64it/s]
# Processing packets: 281597it [00:42, 5905.84it/s]
# Processing packets: 282193it [00:42, 5890.49it/s]
# Processing packets: 282804it [00:42, 5885.15it/s]
# ...
# Processing packets: 47244it [00:07, 6109.14it/s]
# Processing packets: 47856it [00:07, 6104.61it/s]
# Processing packets: 48547it [00:08, 6069.31it/s]
# Processing packets: 49195it [00:08, 6173.10it/s]
# Processing packets: 49847it [00:08, 6263.87it/s]
# Processing packets: 50564it [00:08, 6317.76it/s]
# Processing packets: 51197it [00:08, 6255.40it/s]
# Processing packets: 51842it [00:08, 6299.02it/s]
# Processing packets: 52473it [00:08, 6248.25it/s]
# Processing packets: 53098it [00:08, 5998.84it/s]
# Processing packets: 53700it [00:08, 5868.40it/s]
# Processing packets: 54289it [00:09, 5736.41it/s]
# Processing packets: 54981it [00:09, 6071.56it/s]
# Processing packets: 55634it [00:09, 5975.53it/s]
# Processing packets: 56234it [00:09, 5657.21it/s]
# Processing packets: 56909it [00:09, 5736.56it/s]
# Processing packets: 57609it [00:09, 6057.23it/s]
# Processing packets: 58226it [00:09, 6082.44it/s]
# Processing packets: 58849it [00:09, 5965.81it/s]
# Processing packets: 59483it [00:09, 6005.26it/s]
# Processing packets: 60086it [00:10, 6011.69it/s]
# Processing packets: 60689it [00:10, 5966.72it/s]
# Processing packets: 61350it [00:10, 6149.84it/s]
# Processing packets: 61981it [00:10, 6193.67it/s]
# Processing packets: 62602it [00:10, 6198.21it/s]
# Processing packets: 63468it [00:10, 6666.16it/s]
# Processing packets: 64287it [00:10, 7050.48it/s]
# Processing packets: 65068it [00:10, 7270.78it/s]
# Processing packets: 65883it [00:10, 7469.50it/s]
# Processing packets: 66656it [00:10, 7461.33it/s]
# Processing packets: 67402it [00:11, 7339.59it/s]
# Processing packets: 68169it [00:11, 7364.20it/s]
# Processing packets: 68906it [00:11, 7335.59it/s]
# Processing packets: 69640it [00:11, 6679.51it/s]
# Processing packets: 70319it [00:11, 6633.19it/s]
# Processing packets: 70990it [00:11, 6439.44it/s]
# Processing packets: 71640it [00:11, 6280.69it/s]
# Processing packets: 72351it [00:11, 6496.52it/s]
# Processing packets: 73005it [00:11, 6399.81it/s]
# Processing packets: 73648it [00:12, 6089.68it/s]
# Processing packets: 74290it [00:12, 6132.33it/s]
# Processing packets: 74950it [00:12, 6171.73it/s]
# Processing packets: 75631it [00:12, 6287.00it/s]
# Processing packets: 76270it [00:12, 6305.48it/s]
# Processing packets: 76902it [00:12, 5920.59it/s]
# Processing packets: 77499it [00:12, 5678.04it/s]
# Processing packets: 78072it [00:12, 5660.62it/s]
# Processing packets: 78759it [00:12, 5951.65it/s]
# Processing packets: 79358it [00:13, 5567.56it/s]
# Processing packets: 80028it [00:13, 5878.30it/s]
# Processing packets: 80683it [00:13, 6017.90it/s]
# Processing packets: 81291it [00:13, 5842.26it/s]
# Processing packets: 81974it [00:13, 6099.98it/s]
# Processing packets: 82614it [00:13, 6180.89it/s]
# Processing packets: 83236it [00:13, 6073.36it/s]
# Processing packets: 83910it [00:13, 6130.52it/s]
# Processing packets: 84531it [00:13, 6127.45it/s]
# Processing packets: 85145it [00:13, 5999.43it/s]
# Processing packets: 85902it [00:14, 6295.69it/s]
# Processing packets: 86646it [00:14, 6603.49it/s]
# Processing packets: 87341it [00:14, 6671.63it/s]
# Processing packets: 88010it [00:14, 6671.15it/s]
# Processing packets: 88699it [00:14, 6532.12it/s]
# Processing packets: 89400it [00:14, 6606.23it/s]
# Processing packets: 90094it [00:14, 6690.43it/s]
# Processing packets: 90819it [00:14, 6845.63it/s]
# Processing packets: 91553it [00:14, 6956.64it/s]
# Processing packets: 92273it [00:14, 7010.10it/s]
# Processing packets: 92975it [00:15, 6744.93it/s]
# Processing packets: 93714it [00:15, 6927.46it/s]
# Processing packets: 94448it [00:15, 7043.47it/s]
# Processing packets: 95203it [00:15, 7156.80it/s]
# Processing packets: 95946it [00:15, 7232.46it/s]
# Processing packets: 96671it [00:15, 6927.43it/s]
# Processing packets: 97493it [00:15, 7086.62it/s]
# Processing packets: 98264it [00:15, 7185.33it/s]
# Processing packets: 99001it [00:15, 7209.89it/s]
# Processing packets: 99724it [00:16, 7202.18it/s]
# Processing packets: 100450it [00:16, 6988.43it/s]
# Processing packets: 101210it [00:16, 7143.77it/s]
# Processing packets: 101948it [00:16, 7156.67it/s]
# Processing packets: 102665it [00:16, 7133.84it/s]
# Processing packets: 103406it [00:16, 7153.70it/s]
# Processing packets: 104212it [00:16, 7240.33it/s]
# Processing packets: 104937it [00:16, 7197.04it/s]
# Processing packets: 105663it [00:16, 7179.46it/s]
# Processing packets: 106423it [00:16, 7284.56it/s]
# Processing packets: 107152it [00:17, 7209.50it/s]
# Processing packets: 107909it [00:17, 7198.12it/s]
# Processing packets: 108629it [00:17, 7042.69it/s]
# Processing packets: 109411it [00:17, 7191.84it/s]
# Processing packets: 110229it [00:17, 7274.14it/s]
# Processing packets: 110957it [00:17, 7212.49it/s]
# Processing packets: 111689it [00:17, 7240.76it/s]
# Processing packets: 112444it [00:17, 7328.12it/s]
# Processing packets: 113178it [00:17, 7284.34it/s]
# Processing packets: 113984it [00:17, 7357.83it/s]
# Processing packets: 114745it [00:18, 7339.59it/s]
# Processing packets: 115523it [00:18, 7414.81it/s]
# Processing packets: 116265it [00:18, 7052.11it/s]
# Processing packets: 117040it [00:18, 6989.71it/s]
# Processing packets: 117766it [00:18, 7031.01it/s]
# Processing packets: 118521it [00:18, 7166.30it/s]
# Processing packets: 119277it [00:18, 7279.56it/s]
# Processing packets: 120036it [00:18, 7370.37it/s]
# Processing packets: 120780it [00:18, 7387.70it/s]
# Processing packets: 121520it [00:19, 7376.28it/s]
# Processing packets: 122259it [00:19, 7190.51it/s]
# Processing packets: 123021it [00:19, 7254.64it/s]
# Processing packets: 123766it [00:19, 7227.88it/s]
# Processing packets: 124490it [00:19, 7229.74it/s]
# Processing packets: 125226it [00:19, 7258.73it/s]
# Processing packets: 126051it [00:19, 7338.58it/s]
# Processing packets: 126819it [00:19, 7370.92it/s]
# Processing packets: 127557it [00:19, 7299.56it/s]
# Processing packets: 128287it [00:19, 7293.47it/s]
# Processing packets: 129038it [00:20, 7094.75it/s]
# Processing packets: 129802it [00:20, 7183.11it/s]
# Processing packets: 130522it [00:20, 7187.11it/s]
# Processing packets: 131385it [00:20, 7269.17it/s]
# Processing packets: 132112it [00:20, 7252.18it/s]
# Processing packets: 132852it [00:20, 7244.19it/s]
# Processing packets: 133709it [00:20, 7350.44it/s]
# Processing packets: 134444it [00:20, 7323.00it/s]
# Processing packets: 135180it [00:20, 7330.26it/s]
# Processing packets: 135913it [00:21, 7302.79it/s]
# Processing packets: 136740it [00:21, 7363.41it/s]
# Processing packets: 137508it [00:21, 7364.91it/s]
# Processing packets: 138245it [00:21, 6825.52it/s]
# Processing packets: 138953it [00:21, 6835.28it/s]
# Processing packets: 139663it [00:21, 6851.45it/s]
# Processing packets: 140352it [00:21, 6829.81it/s]
# Processing packets: 141038it [00:21, 6829.09it/s]
# Processing packets: 141738it [00:21, 6702.95it/s]
# Processing packets: 142412it [00:21, 6699.34it/s]
# Processing packets: 143083it [00:22, 6547.78it/s]
# Processing packets: 143739it [00:22, 6412.77it/s]
# Processing packets: 144391it [00:22, 6441.90it/s]
# Processing packets: 145136it [00:22, 6708.49it/s]
# Processing packets: 145882it [00:22, 6880.22it/s]
# Processing packets: 146571it [00:22, 6846.45it/s]
# Processing packets: 147257it [00:22, 6843.59it/s]
# Processing packets: 148015it [00:22, 6780.73it/s]
# Processing packets: 148740it [00:22, 6888.87it/s]
# Processing packets: 149437it [00:23, 6901.09it/s]
# Processing packets: 150128it [00:23, 6891.60it/s]
# Processing packets: 150931it [00:23, 6930.67it/s]
# Processing packets: 151625it [00:23, 6930.92it/s]
# Processing packets: 152319it [00:23, 6891.57it/s]
# Processing packets: 153009it [00:23, 6510.14it/s]
# Processing packets: 153672it [00:23, 6454.56it/s]
# Processing packets: 154406it [00:23, 6623.20it/s]
# Processing packets: 155128it [00:23, 6741.69it/s]
# Processing packets: 155840it [00:23, 6791.70it/s]
# Processing packets: 156541it [00:24, 6743.21it/s]
# Processing packets: 157288it [00:24, 6878.95it/s]
# Processing packets: 157977it [00:24, 6471.33it/s]
# Processing packets: 158675it [00:24, 6608.75it/s]
# Processing packets: 159393it [00:24, 6758.09it/s]
# Processing packets: 160167it [00:24, 6877.14it/s]
# Processing packets: 160857it [00:24, 6717.73it/s]
# Processing packets: 161564it [00:24, 6784.26it/s]
# Processing packets: 162323it [00:24, 6844.23it/s]
# Processing packets: 163012it [00:25, 6794.40it/s]
# Processing packets: 163724it [00:25, 6872.93it/s]
# Processing packets: 164449it [00:25, 6947.69it/s]
# Processing packets: 165190it [00:25, 7070.05it/s]
# Processing packets: 165898it [00:25, 6880.77it/s]
# Processing packets: 166588it [00:25, 6857.01it/s]
# Processing packets: 167321it [00:25, 6935.86it/s]
# Processing packets: 168048it [00:25, 7028.23it/s]
# Processing packets: 168829it [00:25, 7050.32it/s]
# Processing packets: 169535it [00:25, 7052.68it/s]
# Processing packets: 170241it [00:26, 6917.13it/s]
# Processing packets: 170998it [00:26, 6864.79it/s]
# Processing packets: 171728it [00:26, 6912.37it/s]
# Processing packets: 172427it [00:26, 6933.36it/s]
# Processing packets: 173187it [00:26, 6986.13it/s]
# Processing packets: 173905it [00:26, 6889.48it/s]
# Processing packets: 174595it [00:26, 6781.86it/s]
# Processing packets: 175274it [00:26, 6615.82it/s]
# Processing packets: 175937it [00:26, 6248.78it/s]
# Processing packets: 176566it [00:27, 6171.21it/s]
# Processing packets: 177291it [00:27, 6320.27it/s]
# Processing packets: 178009it [00:27, 6512.58it/s]
# Processing packets: 178719it [00:27, 6674.43it/s]
# Processing packets: 179444it [00:27, 6781.94it/s]
# Processing packets: 180152it [00:27, 6866.73it/s]
# Processing packets: 180884it [00:27, 6981.51it/s]
# Processing packets: 181680it [00:27, 7103.43it/s]
# Processing packets: 182411it [00:27, 7143.06it/s]
# Processing packets: 183180it [00:27, 7235.82it/s]
# Processing packets: 183929it [00:28, 7243.33it/s]
# Processing packets: 184654it [00:28, 7220.65it/s]
# Processing packets: 185377it [00:28, 6969.22it/s]
# Processing packets: 186115it [00:28, 7049.54it/s]
# Processing packets: 186822it [00:28, 7051.12it/s]
# Processing packets: 187529it [00:28, 6938.41it/s]
# Processing packets: 188272it [00:28, 6994.90it/s]
# Processing packets: 189008it [00:28, 7017.77it/s]
# Processing packets: 189752it [00:28, 7134.61it/s]
# Processing packets: 190472it [00:28, 7152.70it/s]
# Processing packets: 191208it [00:29, 7210.44it/s]
# Processing packets: 192023it [00:29, 7285.97it/s]
# Processing packets: 192772it [00:29, 7269.93it/s]
# Processing packets: 193499it [00:29, 7250.49it/s]
# Processing packets: 194252it [00:29, 7286.01it/s]
# Processing packets: 194981it [00:29, 7280.42it/s]
# Processing packets: 195742it [00:29, 7197.27it/s]
# Processing packets: 196463it [00:29, 6708.23it/s]
# Processing packets: 197205it [00:29, 6743.87it/s]
# Processing packets: 197933it [00:30, 6891.28it/s]
# Processing packets: 198709it [00:30, 7041.37it/s]
# Processing packets: 199519it [00:30, 7112.86it/s]
# Processing packets: 200275it [00:30, 7164.25it/s]
# Processing packets: 201048it [00:30, 7251.52it/s]
# Processing packets: 201775it [00:30, 7243.98it/s]
# Processing packets: 202501it [00:30, 7247.30it/s]
# Processing packets: 203227it [00:30, 7024.22it/s]
# Processing packets: 203931it [00:30, 6876.65it/s]
# Processing packets: 204620it [00:31, 6541.82it/s]
# Processing packets: 205321it [00:31, 6671.58it/s]
# Processing packets: 205992it [00:31, 6385.54it/s]
# Processing packets: 206703it [00:31, 6388.99it/s]
# Processing packets: 207345it [00:31, 6314.22it/s]
# Processing packets: 207979it [00:31, 5902.44it/s]
# Processing packets: 208714it [00:31, 6225.43it/s]
# Processing packets: 209342it [00:31, 5870.65it/s]
# Processing packets: 209936it [00:31, 5865.80it/s]
# Processing packets: 210624it [00:32, 6131.99it/s]
# Processing packets: 211242it [00:32, 6086.36it/s]
# Processing packets: 211911it [00:32, 6180.52it/s]
# Processing packets: 212532it [00:32, 5874.56it/s]
# Processing packets: 213124it [00:32, 5733.15it/s]
# Processing packets: 213836it [00:32, 6116.67it/s]
# Processing packets: 214465it [00:32, 6094.83it/s]
# Processing packets: 215081it [00:32, 6083.35it/s]
# Processing packets: 215777it [00:32, 6330.76it/s]
# Processing packets: 216413it [00:32, 6227.24it/s]
# Processing packets: 217092it [00:33, 6251.87it/s]
# Processing packets: 217809it [00:33, 6502.19it/s]
# Processing packets: 218461it [00:33, 6252.49it/s]
# Processing packets: 219153it [00:33, 6396.70it/s]
# Processing packets: 219795it [00:33, 6309.13it/s]
# Processing packets: 220428it [00:33, 6208.09it/s]
# Processing packets: 221147it [00:33, 6427.15it/s]
# Processing packets: 221800it [00:33, 6391.48it/s]
# Processing packets: 222440it [00:33, 6285.75it/s]
# Processing packets: 223195it [00:34, 6455.98it/s]
# Processing packets: 223841it [00:34, 6181.42it/s]
# Processing packets: 224517it [00:34, 6332.92it/s]
# Processing packets: 225153it [00:34, 6331.94it/s]
# Processing packets: 225817it [00:34, 6410.96it/s]
# Processing packets: 226514it [00:34, 6542.15it/s]
# Processing packets: 227317it [00:34, 6777.96it/s]
# Processing packets: 228023it [00:34, 6837.97it/s]
# Processing packets: 228707it [00:34, 6460.33it/s]
# Processing packets: 229434it [00:34, 6642.82it/s]
# Processing packets: 230102it [00:35, 6400.17it/s]
# Processing packets: 230746it [00:35, 6405.44it/s]
# Processing packets: 231389it [00:35, 6361.09it/s]
# Processing packets: 232097it [00:35, 6473.96it/s]
# Processing packets: 232810it [00:35, 6592.69it/s]
# Processing packets: 233471it [00:35, 6263.84it/s]
# Processing packets: 234180it [00:35, 6442.96it/s]
# Processing packets: 234897it [00:35, 6412.94it/s]
# Processing packets: 235541it [00:35, 6345.79it/s]
# Processing packets: 236177it [00:36, 5469.38it/s]
# Processing packets: 236745it [00:36, 5119.41it/s]
# Processing packets: 237273it [00:36, 5014.19it/s]
# Processing packets: 237864it [00:36, 5247.66it/s]
# Processing packets: 238458it [00:36, 5425.32it/s]
# Processing packets: 239028it [00:36, 5472.13it/s]
# Processing packets: 239778it [00:36, 5928.44it/s]
# Processing packets: 240434it [00:36, 5978.77it/s]
# Processing packets: 241036it [00:36, 5918.25it/s]
# Processing flows:   0%|          | 2/39215 [02:36<852:52:33, 78.30s/it]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[13], line 132
#     128 if __name__ == "__main__":
#     130     csv_path = "E:\\PFE2025\\Dataset\\Dataset_1\\combined_output.csv"
# --> 132     main(csv_path)
#
# Cell In[13], line 120, in main(csv_path, output_dir)
#     117 next(reader)  # Skip header again
#     119 for row in tqdm(reader, total=total_rows, desc="Processing flows"):
# --> 120     result = process_flow(row, output_dir)
#     121     if result:
#     122         results.append(result)
#
# Cell In[13], line 51, in process_flow(row, output_dir)
#      49 matching_packets = []
#      50 with PcapReader(pcap_file) as pcap_reader:
# ---> 51     for pkt in tqdm(pcap_reader, desc=f"Processing packets", leave=False):
#      52         try:
#      53             # Check timestamp first for efficiency
#      54             pkt_time = pkt.time
#
# File e:\PFE2025\venv\lib\site-packages\tqdm\std.py:1181, in tqdm.__iter__(self)
#    1178 time = self._time
#    1180 try:
# -> 1181     for obj in iterable:
#    1182         yield obj
#    1183         # Update and possibly print the progressbar.
#    1184         # Note: does not call self.update(1) for speed optimisation.
#
# File e:\PFE2025\venv\lib\site-packages\scapy\utils.py:1628, in PcapReader.__next__(self)
#    1625 def __next__(self):  # type: ignore
#    1626     # type: () -> Packet
#    1627     try:
# -> 1628         return self.read_packet()
#    1629     except EOFError:
#    1630         raise StopIteration
#
# File e:\PFE2025\venv\lib\site-packages\scapy\utils.py:1598, in PcapReader.read_packet(self, size, **kwargs)
#    1596 def read_packet(self, size=MTU, **kwargs):
#    1597     # type: (int, **Any) -> Packet
# -> 1598     rp = super(PcapReader, self)._read_packet(size=size)
#    1599     if rp is None:
#    1600         raise EOFError
#
# File e:\PFE2025\venv\lib\site-packages\scapy\utils.py:1505, in RawPcapReader._read_packet(self, size)
#    1502 sec, usec, caplen, wirelen = struct.unpack(self.endian + "IIII", hdr)
#    1504 try:
# -> 1505     data = self.f.read(caplen)[:size]
#    1506 except OverflowError as e:
#    1507     warning(f"Pcap: {e}")
#
# KeyboardInterrupt:

# %%
# Out:
# Starting packet extraction process...
# Reading CSV file...
# Reading PCAP file...
# Total packets in PCAP: 1566798
#
# Processing packets...
# Analyzing packets:   1%|          | 9170/1566798 [17:05<48:23:20,  8.94packet/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[32], line 105
#     102     print(f"Output saved to: {output_file}")
#     104 if __name__ == "__main__":
# --> 105     main()
#
# Cell In[32], line 91, in main()
#      89 output_file = "E:\\PFE2025\\Hamza\\enp0s3-public-tuesday.pcap_Flow\\extracted_MALICIOUS_packets.pcap"
#      90 print("\nStarting packet extraction process...")
# ---> 91 flow_stats, total_packets = extract_flow_packets(pcap_file, csv_file, output_file)
#      93 # Print summary
#      94 print("\nExtraction Summary:")
#
# Cell In[32], line 55, in extract_flow_packets(pcap_file, csv_file, output_file)
#      46 backward_flow = (
#      47     ip_layer.dst,
#      48     transport_layer.dport,
#    (...)
#      51     protocol
#      52 )
#      54 # Check if packet belongs to any flow in CSV
# ---> 55 for _, flow in df.iterrows():
#      56     if (str(flow['Src IP']) == forward_flow[0] and
#      57         int(flow['Src Port']) == forward_flow[1] and
#      58         str(flow['Dst IP']) == forward_flow[2] and
#      59         int(flow['Dst Port']) == forward_flow[3] and
#      60         int(flow['Protocol']) == forward_flow[4]):
#      62         flow_id = flow['Flow ID']
#
# File e:\PFE2025\venv\lib\site-packages\pandas\core\frame.py:1554, in DataFrame.iterrows(self)
#    1552 using_cow = using_copy_on_write()
#    1553 for k, v in zip(self.index, self.values):
# -> 1554     s = klass(v, index=columns, name=k).__finalize__(self)
#    1555     if using_cow and self._mgr.is_single_block:
#    1556         s._mgr.add_references(self._mgr)  # type: ignore[arg-type]
#
# File e:\PFE2025\venv\lib\site-packages\pandas\core\series.py:588, in Series.__init__(self, data, index, dtype, name, copy, fastpath)
#     586 manager = _get_option("mode.data_manager", silent=True)
#     587 if manager == "block":
# --> 588     data = SingleBlockManager.from_array(data, index, refs=refs)
#     589 elif manager == "array":
#     590     data = SingleArrayManager.from_array(data, index)
#
# File e:\PFE2025\venv\lib\site-packages\pandas\core\internals\managers.py:1872, in SingleBlockManager.from_array(cls, array, index, refs)
#    1870 array = maybe_coerce_values(array)
#    1871 bp = BlockPlacement(slice(0, len(index)))
# -> 1872 block = new_block(array, placement=bp, ndim=1, refs=refs)
#    1873 return cls(block, index)
#
# File e:\PFE2025\venv\lib\site-packages\pandas\core\internals\blocks.py:2727, in new_block(values, placement, ndim, refs)
#    2716 def new_block(
#    2717     values,
#    2718     placement: BlockPlacement,
#    (...)
#    2725     # - check_ndim/ensure_block_shape already checked
#    2726     # - maybe_coerce_values already called/unnecessary
# -> 2727     klass = get_block_type(values.dtype)
#    2728     return klass(values, ndim=ndim, placement=placement, refs=refs)
#
# File e:\PFE2025\venv\lib\site-packages\pandas\core\internals\blocks.py:2688, in get_block_type(dtype)
#    2686 if isinstance(dtype, DatetimeTZDtype):
#    2687     return DatetimeTZBlock
# -> 2688 elif isinstance(dtype, PeriodDtype):
#    2689     return NDArrayBackedExtensionBlock
#    2690 elif isinstance(dtype, ExtensionDtype):
#    2691     # Note: need to be sure NumpyExtensionArray is unwrapped before we get here
#
# KeyboardInterrupt:

# %% [markdown]
# # CSV Matcher

# %%
import pandas as pd
import ipaddress
import os

def normalize_flow(row):
    """Normalize flow direction by always putting the lower IP address as source"""
    try:
        src_ip = ipaddress.ip_address(row['Src IP'])
        dst_ip = ipaddress.ip_address(row['Dst IP'])
        
        if src_ip > dst_ip:
            # Swap source and destination
            return {
                'Src IP': str(dst_ip),
                'Dst IP': str(src_ip),
                'Src Port': row['Dst Port'],
                'Dst Port': row['Src Port'],
                'Protocol': row['Protocol']
            }
    except:
        pass
    
    return {
        'Src IP': row['Src IP'],
        'Dst IP': row['Dst IP'],
        'Src Port': row['Src Port'],
        'Dst Port': row['Dst Port'],
        'Protocol': row['Protocol']
    }

def create_flow_key(row):
    """Create a unique key for a flow based on its 5-tuple"""
    normalized = normalize_flow(row)
    return (
        f"{normalized['Src IP']}_{normalized['Src Port']}_"
        f"{normalized['Dst IP']}_{normalized['Dst Port']}_{normalized['Protocol']}"
    )

def aggregate_flows(df):
    """Aggregate split flows into single entries"""
    # Create flow keys
    df['flow_key'] = df.apply(create_flow_key, axis=1)
    
    # Group by flow key and aggregate
    aggregated = df.groupby('flow_key').agg({
        'Src IP': 'first',
        'Dst IP': 'first',
        'Src Port': 'first',
        'Dst Port': 'first',
        'Protocol': 'first'
    }).reset_index()
    
    return aggregated

def find_matching_flows(csv1_path, csv2_path, output_dir):
    """Find matching flows between two CSV files and save detailed output"""
    # Create output directory if it doesn't exist
    os.makedirs(output_dir, exist_ok=True)
    
    # Read CSV files
    print(f"Reading CSV files...")
    df1 = pd.read_csv(csv1_path)
    df2 = pd.read_csv(csv2_path)
    
    print(f"File 1 shape: {df1.shape}")
    print(f"File 2 shape: {df2.shape}")
    
    # Ensure column names are consistent
    required_columns = ['Src IP', 'Dst IP', 'Src Port', 'Dst Port', 'Protocol']
    for col in required_columns:
        if col not in df1.columns or col not in df2.columns:
            raise ValueError(f"Missing required column: {col}")
    
    # Aggregate split flows in both dataframes
    print("Aggregating flows...")
    df1_agg = aggregate_flows(df1)
    df2_agg = aggregate_flows(df2)
    
    # Find matching flows
    print("Finding matching flows...")
    matching_flows = pd.merge(
        df1_agg,
        df2_agg,
        on=['flow_key'],
        suffixes=('_v1', '_v2')
    )
    
    # Count statistics
    total_flows_v1 = len(df1_agg)
    total_flows_v2 = len(df2_agg)
    matching_count = len(matching_flows)
    
    # Save detailed outputs
    print("\nSaving output files...")
    
    # 1. Save statistics to a text file
    stats_path = os.path.join(output_dir, "matching_statistics.txt")
    with open(stats_path, 'w') as f:
        f.write("Flow Matching Statistics\n")
        f.write("=======================\n\n")
        f.write(f"CSV File 1: {csv1_path}\n")
        f.write(f"CSV File 2: {csv2_path}\n\n")
        f.write(f"Total flows in version 1: {total_flows_v1}\n")
        f.write(f"Total flows in version 2: {total_flows_v2}\n")
        f.write(f"Matching flows: {matching_count}\n")
        f.write(f"Match percentage: {(matching_count/min(total_flows_v1, total_flows_v2))*100:.2f}%\n")
    
    # 2. Save matching flows data
    # Get original rows from both files that match
    df1['flow_key'] = df1.apply(create_flow_key, axis=1)
    df2['flow_key'] = df2.apply(create_flow_key, axis=1)
    
    matching_flows_v1 = df1[df1['flow_key'].isin(matching_flows['flow_key'])]
    matching_flows_v2 = df2[df2['flow_key'].isin(matching_flows['flow_key'])]
    
    # Save the matching flows
    matching_flows_v1[required_columns].to_csv(
        os.path.join(output_dir, "matching_flows_version1.csv"), 
        index=False
    )
    matching_flows_v2[required_columns].to_csv(
        os.path.join(output_dir, "matching_flows_version2.csv"), 
        index=False
    )
    
    # Print summary
    print(f"\nFlow Matching Statistics:")
    print(f"Total flows in version 1: {total_flows_v1}")
    print(f"Total flows in version 2: {total_flows_v2}")
    print(f"Matching flows: {matching_count}")
    print(f"Match percentage: {(matching_count/min(total_flows_v1, total_flows_v2))*100:.2f}%")
    
    print(f"\nOutput files saved in: {output_dir}")
    print(f"1. Statistics: matching_statistics.txt")
    print(f"2. Original matching rows from version 1: matching_flows_version1.csv")
    print(f"3. Original matching rows from version 2: matching_flows_version2.csv")
    
    return matching_flows

def main():
    # Example usage
    csv1_path = "/media/brahim/New Volume/PFE2025/Hamza/enp0s3-public-tuesday.pcap_Flow/enp0s3-public-tuesday.pcap_Flow_non_benign.csv"
    csv2_path = "/media/brahim/New Volume/PFE2025/Hamza/enp0s3-public-tuesday.pcap_Flow/extracted_MALICIOUS_packets.pcap_Flow.csv"
    output_dir = "/media/brahim/New Volume/PFE2025/Hamza/enp0s3-public-tuesday.pcap_Flow/"
    
    
    try:
        matching_flows = find_matching_flows(csv1_path, csv2_path, output_dir)
        
        # Display sample of matching flows
        print("\nSample of matching flows:")
        print(matching_flows.head())
        
    except Exception as e:
        print(f"Error processing files: {str(e)}")

if __name__ == "__main__":
    main()
# Out:
# Reading CSV files...
# File 1 shape: (11865, 84)
# File 2 shape: (13752, 84)
# Aggregating flows...
# Finding matching flows...
#
# Saving output files...
#
# Flow Matching Statistics:
# Total flows in version 1: 6320
# Total flows in version 2: 6296
# Matching flows: 6296
# Match percentage: 100.00%
#
# Output files saved in: /media/brahim/New Volume/PFE2025/Hamza/enp0s3-public-tuesday.pcap_Flow/
# 1. Statistics: matching_statistics.txt
# 2. Original matching rows from version 1: matching_flows_version1.csv
# 3. Original matching rows from version 2: matching_flows_version2.csv
#
# Sample of matching flows:
#                                   flow_key      Src IP_v1     Dst IP_v1  \
# 0  184.98.36.245_44662_192.168.3.29_9000_6  184.98.36.245  192.168.3.29
# 1  184.98.36.245_44663_192.168.3.29_9001_6  184.98.36.245  192.168.3.29
# 2  184.98.36.245_44664_192.168.3.29_9002_6  184.98.36.245  192.168.3.29
# 3    184.98.36.245_44665_192.168.3.29_80_6  184.98.36.245  192.168.3.29
# 4  184.98.36.245_44688_192.168.3.29_9001_6  184.98.36.245  192.168.3.29
#
#    Src Port_v1  Dst Port_v1  Protocol_v1      Src IP_v2      Dst IP_v2  \
# 0        44662         9000            6   192.168.3.29  184.98.36.245
# 1        44663         9001            6   192.168.3.29  184.98.36.245
# 2        44664         9002            6   192.168.3.29  184.98.36.245
# 3        44665           80            6   192.168.3.29  184.98.36.245
# 4        44688         9001            6  184.98.36.245   192.168.3.29
#
#    Src Port_v2  Dst Port_v2  Protocol_v2
# 0         9000        44662            6
# 1         9001        44663            6
# 2         9002        44664            6
# 3           80        44665            6
# 4        44688         9001            6
